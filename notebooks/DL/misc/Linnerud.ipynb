# %%
# Load Linnerud using sklearn.datasets.load_linnerud

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.DataFrame(columns=['Chins', 'Situps', 'Jumps'])
df['Chins'] = X_[:, 0]
df['Situps'] = X_[:, 1]
df['Jumps'] = X_[:, 2]

df.head()
# Out:
#    Chins  Situps  Jumps
# 0    5.0   162.0   60.0
# 1    2.0   110.0   60.0
# 2   12.0   101.0  101.0
# 3   12.0   105.0   37.0
# 4   13.0   155.0   58.0

# %%
threedee = plt.figure().gca(projection='3d')
threedee.scatter(df['Chins'], df['Situps'], df['Jumps'])
threedee.set_xlabel('Chins')
threedee.set_ylabel('Situps')
threedee.set_zlabel('Jumps')
plt.show()
