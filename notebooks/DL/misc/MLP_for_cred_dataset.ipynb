# %%
# %matplotlib inline

# join one or more path components intelligently
from os.path import join

#torch import
import torch
from torch.utils.data import random_split
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split

# Interface com o sistema operacional
import os

# Manipulação de dataframes
import pandas as pd

# Manipulação de dados tabulares
import numpy as np

# Normalização das características
from sklearn.preprocessing import StandardScaler

# visualização de dados baseada no matplotlib
import seaborn as sns

# Esboço de gráficos
from matplotlib import pyplot as plt

# %% [markdown]
# # Classificação de clientes

# %% [markdown]
# ## Carga e inspeção dos dados

# %%
# Definição dos nomes das variáveis (conforme a tabela contida no enunciado)
colnames = ['ESCT', 'NDEP', 'RENDA', 'TIPOR', 'VBEM', 'NPARC',
            'VPARC', 'TEL', 'IDADE', 'RESMS', 'ENTRADA', 'CLASSE']

# %%
# Leitura dos dados de treino
arquivo = '/content/sample_data/credtrain.txt'
data_train = pd.read_csv(arquivo, sep='\t', header=None, names = colnames)

# Leitura dos dados de teste
arquivo = '/content/sample_data/credtest.txt'
data_test = pd.read_csv(arquivo, sep='\t', header=None, names = colnames)

# %% [markdown]
# **Inspeção dos dados**

# %%
# Inspeção da dimensão do dataset
print(data_train.shape, data_test.shape)
# Out:
# (1500, 12) (577, 12)

# %%
# Inspeção das primeiras linhas do conjunto de treinamento
data_train.head()
# Out:
#    ESCT  NDEP  RENDA  TIPOR  VBEM  ...  TEL  IDADE  RESMS  ENTRADA  CLASSE
# 0     1     0    360      0   313  ...    0     25     48        0       1
# 1     0     0    350      1   468  ...    0     33      6        0       1
# 2     0     0   1100      0   829  ...    0     56     48        0       1
# 3     0     0   3000      0   552  ...    1     31     60        0       1
# 4     1     0   1000      0   809  ...    0     24      7        0       1
#
# [5 rows x 12 columns]

# %%
# Inspeção das primeiras linhas do conjunto de teste
data_test.head()
# Out:
#    ESCT  NDEP  RENDA  TIPOR  VBEM  ...  TEL  IDADE  RESMS  ENTRADA  CLASSE
# 0     0     2    500      1   618  ...    0     36      6        0       0
# 1     1     0    813      0   552  ...    0     43     48      119       1
# 2     3     0    350      0   488  ...    0     43      0        0       1
# 3     1     0   1530      0   381  ...    0     28     48        0       1
# 4     0     0    688      1   396  ...    0     49     72        0       1
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Pré-processamento dos dados

# %% [markdown]
# ### Transformação de variáveis não-numéricas
#
# É importante observar que a variável ESCT (Estado Civil) é do tipo categórica, podendo assumir 4 valores diferentes (cada valor corresponde a um estado civil). Assim, diferentemente de NDEP (onde cada valor corresponde a uma quantidade de dependentes), na variável ESCT cada valor corresponde a uma categoria. Contudo, este fato pode trazer inconsistências na criação e treinamento de modelos.
#
# Para mitigar este problema, uma alternativa é tranformar a variável ESCT em uma variável *dummy* (variável binária). Neste sentido, cada categoria da variável ESCT corresponderá a uma variável. Visto que há 4 possíveis categorias para a variável ESCT, obteremos 4 variáveis ESCT binárias.
#
# Uma variável *dummy* é uma variável binária utilizadas para representar categorias. Neste sentido, em um caso de uma variável com 3 ou mais categorias, recomenda-se a criação de $n-1$ dummies. Diante disso, a variável ESCT será transformada em 4 "variantes dummy", onde o valor 1 corresponderá à ocorrência de determinada categoria e o valor 0 corresponderá à não ocorrência.

# %%
# Aplicação no conjunto de treinamento
data_train_new = pd.get_dummies(data = data_train, 
                                prefix='ESCT', 
                                columns=['ESCT'], 
                                drop_first=True)

"""
pd.get_dummies: Convert categorical variable into dummy/indicator variables.
"""

# Inspeção das primeiras linhas
data_train_new.head()
# Out:
#    NDEP  RENDA  TIPOR  VBEM  NPARC  ...  ENTRADA  CLASSE  ESCT_1  ESCT_2  ESCT_3
# 0     0    360      0   313      9  ...        0       1       1       0       0
# 1     0    350      1   468     10  ...        0       1       0       0       0
# 2     0   1100      0   829      9  ...        0       1       0       0       0
# 3     0   3000      0   552     12  ...        0       1       0       0       0
# 4     0   1000      0   809     12  ...        0       1       1       0       0
#
# [5 rows x 14 columns]

# %%
# Aplicação da transformação sobre o conjunto de teste
data_test_new = pd.get_dummies(data = data_test, prefix='ESCT', columns=['ESCT'], drop_first=True)

"""
pd.get_dummies: Convert categorical variable into dummy/indicator variables
"""

# Inspeção das primeiras linhas
data_test_new.head()
# Out:
#    NDEP  RENDA  TIPOR  VBEM  NPARC  ...  ENTRADA  CLASSE  ESCT_1  ESCT_2  ESCT_3
# 0     2    500      1   618     10  ...        0       0       0       0       0
# 1     0    813      0   552      4  ...      119       1       1       0       0
# 2     0    350      0   488     12  ...        0       1       0       0       1
# 3     0   1530      0   381      1  ...        0       1       1       0       0
# 4     0    688      1   396     10  ...        0       1       0       0       0
#
# [5 rows x 14 columns]

# %% [markdown]
# **Separação do conjunto de dados em rótulo ($\mathrm{y}$) e features ($\mathrm{x}$)**
#
# O rótulo ($\mathrm{y}$) corresponde ao vetor contendo a variável alvo (CLASSE), enquanto que features ($\mathrm{x}$) corresponde à matriz de dados.

# %%
# Transformação da variável alvo do conjunto de treinamento em vetor
y_train = np.array(data_train_new['CLASSE'])

# Inspeção das primeira linhas
y_train[:5]
# Out:
# array([1, 1, 1, 1, 1])

# %%
# Transformação da variável alvo do conjunto de teste em vetor
y_test = np.array(data_test_new['CLASSE'])

# Inspeção das primeiras linhas
y_test[:5]
# Out:
# array([0, 1, 1, 1, 1])

# %%
# Transformação do conjunto de treinamento remanescente em matriz de dados
features_name_train = list(data_train_new.columns)               # nomes das colunas
features_name_train.remove('CLASSE')                             # remove variável "CLASSE"
X_train = np.array(data_train_new.loc[:, features_name_train])   # Transformação em matriz de dados

# Inspeção da matriz resultante
X_train
# Out:
# array([[   0,  360,    0, ...,    1,    0,    0],
#        [   0,  350,    1, ...,    0,    0,    0],
#        [   0, 1100,    0, ...,    0,    0,    0],
#        ...,
#        [   0,  570,    0, ...,    0,    0,    0],
#        [   0,  360,    0, ...,    0,    0,    0],
#        [   4,  501,    1, ...,    0,    0,    0]])

# %%
# Transformação do conjunto de teste remanescente em matriz de dados
features_name_test = list(data_test_new.columns)               # Recuperação dos nomes das colunas
features_name_test.remove('CLASSE')                            # Remoção da variável "CLASSE"
X_test = np.array(data_test_new.loc[:, features_name_test])   # Transformação em matriz

# Inspeção da matriz resultante
X_test
# Out:
# array([[   2,  500,    1, ...,    0,    0,    0],
#        [   0,  813,    0, ...,    1,    0,    0],
#        [   0,  350,    0, ...,    0,    0,    1],
#        ...,
#        [   3, 1200,    0, ...,    0,    0,    0],
#        [   0,  600,    0, ...,    1,    0,    0],
#        [   0,  800,    1, ...,    0,    0,    0]])

# %% [markdown]
# ### Normalização das features
#
# Antes de iniciar o treinamento, é também necessário realizar a *normalização* das características a fim de evitar problemas decorrentes à discrepância nas ordens de grandeza das features.

# %%
# Criação do objeto para a padronização das features
scaler = StandardScaler()

# Ajustamento do StandardScaler ao conjunto de dados de treino e padronização dos dados de treino
X_train_norm = scaler.fit_transform(X_train)

# Transformação dos dados de teste com os parâmetros ajustados a partir dos dados de treino
X_test_norm = scaler.transform(X_test)

# %%
# Dimensões dos datasets
print(X_train_norm.shape, X_test_norm.shape, y_train.shape, y_test.shape)
# Out:
# (1500, 13) (577, 13) (1500,) (577,)

# %% [markdown]
# ## Treinamento do modelo

# %% [markdown]
# No trecho de código a seguir, foi realizada uma transformação dos dados em vetores para tensores.
# Esses dados ficaram armazenados nas variáveis x_train, y_train, x_test, y_test.
#
# Essa transformação foi feita porque posteriormente iremos utiliza-las como parâmetro para nosso dataloader.

# %%
y_train.shape
# Out:
# (1500,)

# %%
# y_train.reshape(-1, 1)
# y_test.reshape(-1, 1)

# print(y_train.shape, y_test.shape)

# %%
x_train = torch.from_numpy(X_train_norm)
x_test = torch.from_numpy(X_test_norm)

y_train = torch.from_numpy(y_train)
y_test = torch.from_numpy(y_test)

xtr, ytr, xte, yte = x_train.float(), y_train.float(), x_test.float(), y_test.float()

print(xtr.shape)
print(ytr.shape)

print(xte.shape)
print(yte.shape)
# Out:
# torch.Size([1500, 13])
# torch.Size([1500])
# torch.Size([577, 13])
# torch.Size([577])

# %%
# Criação do objeto para a padronização das features
scaler_for_y = StandardScaler()

# Ajuste do StandardScaler ao conjunto de dados de treino e padronização dos dados de treino
#y_train_norm = scaler_for_y.fit_transform(y_train)

# Transformação dos dados de teste com os parâmetros ajustados a partir dos dados de treino
#y_test_norm = scaler_for_y.transform(y_test)

# %% [markdown]
# A seguir, importamos a classe `TensorDataset`, responsável por criar as instancias do tipo tensor para os vetores x_train, y_train e x_test, y_test. Os `TensorDataset` ficaram armezenados nas variáveis train_ds e val_ds, que são respectivamente, datasets de treinamento e avaliação.

# %%
from torch.utils.data.dataset import TensorDataset

train_ds = TensorDataset(xtr, ytr)
val_ds = TensorDataset(xte, yte)

# %% [markdown]
# Abaixo temos o código necessário para verificar a taxa de acurácia da nossa rede. Esse método será necessário para verificar quão bom foi o processo de aprendizado da rede. Ele será invocado a partir do método `fit`, que será implementado mais a frente.

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %% [markdown]
# Abaixo, temos um código que realiza a criação dos batchs de dados. Um batch de dados é basicamente um conjunto menor de dados.
# Passamos como parâmetro um dataset inteiro, e criamos inúmeros datasets menores de tamanho N, onde N corresponde ao valor da váriavel batch_size do código abaixo. Com o objeto DataLoader conseguimos criar batchs de tamanho N a partir de um conjunto de dados de entrada. O parâmetro `shuffle = True` signfica que os dados de treinamento serão embaralhados para garantir que os lotes gerados em cada época sejam diferentes.

# %%
batch_size = 40
train_loader = DataLoader(train_ds, batch_size, shuffle=True)
val_loader = DataLoader(val_ds, batch_size)

# %% [markdown]
# Abaixo temos a implementação da classe LogisticModel, que estende a classe Module do pacote nn. Essa classe carrega a lógica de treinamento e avaliação da rede, e apresenta uma lista de métodos:
#
# - `training_step`: realiza as predições e calcula as perdas durante a fase de treinamento.
#
# - `validation_step`: realiza as predições, calcula as perdas e verifica a taxa de acurácia durante a fase de avaliação.
#
# - `validation_epoch_end`: retornar as perdas e as acurácias.
#
# - `epoch_end`: imprime as perdas e acurácias obtidas ao fim de uma época de treinamento.

# %%
input_size = 13
num_classes = 2

# %%
class LogisticModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(input_size, num_classes).float()
        
    def forward(self, xb):
        
        out = self.linear(xb)
        return out
    
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  

        # Veja https://discuss.pytorch.org/t/runtimeerror-expected-object-of-scalar-type-long-but-got-scalar-type-float-when-using-crossentropyloss/30542
        labels = labels.long()

        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    

        # Veja https://discuss.pytorch.org/t/runtimeerror-expected-object-of-scalar-type-long-but-got-scalar-type-float-when-using-crossentropyloss/30542
        labels = labels.long()

        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss, 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['val_loss'], result['val_acc']))

# %%
model = LogisticModel()
print(model.parameters)
# Out:
# <bound method Module.parameters of LogisticModel(
#   (linear): Linear(in_features=13, out_features=2, bias=True)
# )>

# %%
def evaluate(model, val_loader):
  outputs = [model.validation_step(batch) for batch in val_loader]
  return model.validation_epoch_end(outputs)

# %% [markdown]
# A função `fit` registra o custo medido sobre o conjunto de validação e a métrica de cada época. Ele retorna um histórico do treinamento, útil para depuração e visualização. Nesse método passamos configurações iniciais como taxa de aprendizado, tamanho de lote e etc. Essas configurações são denominadas hiperparâmetros. Esses hiperparâmetros possuem uma relevância muito grande no contexto de aprendizado de máquina. Dentro deste método fit, há ainda o método `evaluate`, responsável por avaliar a rede neural durante a fase de validação.

# %%
def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    optimizer = opt_func(model.parameters(), lr)
    history = [] # for recording epoch-wise results
    
    for epoch in range(epochs):
        
        # Training Phase 
        for batch in train_loader:
            loss = model.training_step(batch)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        # Validation phase
        result = evaluate(model, val_loader)
        model.epoch_end(epoch, result)
        history.append(result)

    return history

# %%
result0 = evaluate(model, val_loader)
result0
# Out:
# {'val_acc': 0.3329411745071411, 'val_loss': 0.8614569902420044}

# %%
history1 = fit(300, 0.001, model, train_loader, val_loader)
# Out:
# Epoch [0], val_loss: 0.8432, val_acc: 0.3363
# Epoch [1], val_loss: 0.8257, val_acc: 0.3346
# Epoch [2], val_loss: 0.8091, val_acc: 0.3379
# Epoch [3], val_loss: 0.7932, val_acc: 0.3613
# Epoch [4], val_loss: 0.7778, val_acc: 0.3863
# Epoch [5], val_loss: 0.7632, val_acc: 0.4029
# Epoch [6], val_loss: 0.7493, val_acc: 0.4213
# Epoch [7], val_loss: 0.7360, val_acc: 0.4452
# Epoch [8], val_loss: 0.7233, val_acc: 0.4752
# Epoch [9], val_loss: 0.7111, val_acc: 0.4885
# Epoch [10], val_loss: 0.6994, val_acc: 0.5069
# Epoch [11], val_loss: 0.6883, val_acc: 0.5285
# Epoch [12], val_loss: 0.6777, val_acc: 0.5652
# Epoch [13], val_loss: 0.6676, val_acc: 0.6141
# Epoch [14], val_loss: 0.6578, val_acc: 0.6453
# Epoch [15], val_loss: 0.6485, val_acc: 0.6686
# Epoch [16], val_loss: 0.6396, val_acc: 0.6903
# Epoch [17], val_loss: 0.6311, val_acc: 0.7103
# Epoch [18], val_loss: 0.6230, val_acc: 0.7253
# Epoch [19], val_loss: 0.6152, val_acc: 0.7375
# Epoch [20], val_loss: 0.6078, val_acc: 0.7604
# Epoch [21], val_loss: 0.6006, val_acc: 0.7671
# Epoch [22], val_loss: 0.5937, val_acc: 0.7787
# Epoch [23], val_loss: 0.5871, val_acc: 0.7904
# Epoch [24], val_loss: 0.5808, val_acc: 0.7937
# Epoch [25], val_loss: 0.5747, val_acc: 0.7987
# Epoch [26], val_loss: 0.5688, val_acc: 0.8071
# Epoch [27], val_loss: 0.5632, val_acc: 0.8137
# Epoch [28], val_loss: 0.5577, val_acc: 0.8137
# Epoch [29], val_loss: 0.5525, val_acc: 0.8187
# Epoch [30], val_loss: 0.5475, val_acc: 0.8237
# Epoch [31], val_loss: 0.5426, val_acc: 0.8310
# Epoch [32], val_loss: 0.5380, val_acc: 0.8326
# Epoch [33], val_loss: 0.5335, val_acc: 0.8343
# Epoch [34], val_loss: 0.5291, val_acc: 0.8326
# Epoch [35], val_loss: 0.5249, val_acc: 0.8416
# Epoch [36], val_loss: 0.5208, val_acc: 0.8416
# Epoch [37], val_loss: 0.5169, val_acc: 0.8416
# Epoch [38], val_loss: 0.5131, val_acc: 0.8399
# Epoch [39], val_loss: 0.5094, val_acc: 0.8432
# Epoch [40], val_loss: 0.5058, val_acc: 0.8449
# Epoch [41], val_loss: 0.5024, val_acc: 0.8449
# Epoch [42], val_loss: 0.4991, val_acc: 0.8449
# Epoch [43], val_loss: 0.4958, val_acc: 0.8432
# Epoch [44], val_loss: 0.4927, val_acc: 0.8466
# Epoch [45], val_loss: 0.4897, val_acc: 0.8482
# Epoch [46], val_loss: 0.4867, val_acc: 0.8482
# Epoch [47], val_loss: 0.4839, val_acc: 0.8482
# Epoch [48], val_loss: 0.4811, val_acc: 0.8482
# Epoch [49], val_loss: 0.4785, val_acc: 0.8532
# Epoch [50], val_loss: 0.4758, val_acc: 0.8516
# Epoch [51], val_loss: 0.4733, val_acc: 0.8516
# Epoch [52], val_loss: 0.4708, val_acc: 0.8516
# Epoch [53], val_loss: 0.4684, val_acc: 0.8532
# Epoch [54], val_loss: 0.4661, val_acc: 0.8532
# Epoch [55], val_loss: 0.4638, val_acc: 0.8532
# Epoch [56], val_loss: 0.4615, val_acc: 0.8549
# Epoch [57], val_loss: 0.4594, val_acc: 0.8549
# Epoch [58], val_loss: 0.4572, val_acc: 0.8549
# Epoch [59], val_loss: 0.4552, val_acc: 0.8549
# Epoch [60], val_loss: 0.4532, val_acc: 0.8549
# Epoch [61], val_loss: 0.4512, val_acc: 0.8549
# Epoch [62], val_loss: 0.4493, val_acc: 0.8549
# Epoch [63], val_loss: 0.4474, val_acc: 0.8549
# Epoch [64], val_loss: 0.4456, val_acc: 0.8582
# Epoch [65], val_loss: 0.4439, val_acc: 0.8582
# Epoch [66], val_loss: 0.4421, val_acc: 0.8582
# Epoch [67], val_loss: 0.4404, val_acc: 0.8599
# Epoch [68], val_loss: 0.4388, val_acc: 0.8599
# Epoch [69], val_loss: 0.4372, val_acc: 0.8599
# Epoch [70], val_loss: 0.4356, val_acc: 0.8599
# Epoch [71], val_loss: 0.4341, val_acc: 0.8599
# Epoch [72], val_loss: 0.4326, val_acc: 0.8616
# Epoch [73], val_loss: 0.4311, val_acc: 0.8616
# Epoch [74], val_loss: 0.4297, val_acc: 0.8616
# Epoch [75], val_loss: 0.4283, val_acc: 0.8616
# Epoch [76], val_loss: 0.4269, val_acc: 0.8616
# Epoch [77], val_loss: 0.4256, val_acc: 0.8632
# Epoch [78], val_loss: 0.4242, val_acc: 0.8649
# Epoch [79], val_loss: 0.4229, val_acc: 0.8649
# Epoch [80], val_loss: 0.4217, val_acc: 0.8666
# Epoch [81], val_loss: 0.4204, val_acc: 0.8682
# Epoch [82], val_loss: 0.4192, val_acc: 0.8682
# Epoch [83], val_loss: 0.4180, val_acc: 0.8699
# Epoch [84], val_loss: 0.4169, val_acc: 0.8699
# Epoch [85], val_loss: 0.4157, val_acc: 0.8699
# Epoch [86], val_loss: 0.4146, val_acc: 0.8699
# Epoch [87], val_loss: 0.4135, val_acc: 0.8716
# Epoch [88], val_loss: 0.4124, val_acc: 0.8716
# Epoch [89], val_loss: 0.4114, val_acc: 0.8716
# Epoch [90], val_loss: 0.4104, val_acc: 0.8732
# Epoch [91], val_loss: 0.4093, val_acc: 0.8732
# Epoch [92], val_loss: 0.4083, val_acc: 0.8732
# Epoch [93], val_loss: 0.4074, val_acc: 0.8732
# Epoch [94], val_loss: 0.4064, val_acc: 0.8732
# Epoch [95], val_loss: 0.4055, val_acc: 0.8732
# Epoch [96], val_loss: 0.4046, val_acc: 0.8732
# Epoch [97], val_loss: 0.4037, val_acc: 0.8732
# Epoch [98], val_loss: 0.4028, val_acc: 0.8732
# Epoch [99], val_loss: 0.4019, val_acc: 0.8732
# Epoch [100], val_loss: 0.4011, val_acc: 0.8732
# Epoch [101], val_loss: 0.4002, val_acc: 0.8732
# Epoch [102], val_loss: 0.3994, val_acc: 0.8732
# Epoch [103], val_loss: 0.3986, val_acc: 0.8716
# Epoch [104], val_loss: 0.3978, val_acc: 0.8716
# Epoch [105], val_loss: 0.3970, val_acc: 0.8716
# Epoch [106], val_loss: 0.3962, val_acc: 0.8716
# Epoch [107], val_loss: 0.3955, val_acc: 0.8716
# Epoch [108], val_loss: 0.3947, val_acc: 0.8755
# Epoch [109], val_loss: 0.3940, val_acc: 0.8755
# Epoch [110], val_loss: 0.3933, val_acc: 0.8755
# Epoch [111], val_loss: 0.3926, val_acc: 0.8755
# Epoch [112], val_loss: 0.3919, val_acc: 0.8755
# Epoch [113], val_loss: 0.3912, val_acc: 0.8755
# Epoch [114], val_loss: 0.3906, val_acc: 0.8755
# Epoch [115], val_loss: 0.3899, val_acc: 0.8755
# Epoch [116], val_loss: 0.3892, val_acc: 0.8755
# Epoch [117], val_loss: 0.3886, val_acc: 0.8755
# Epoch [118], val_loss: 0.3880, val_acc: 0.8755
# Epoch [119], val_loss: 0.3873, val_acc: 0.8755
# Epoch [120], val_loss: 0.3867, val_acc: 0.8755
# Epoch [121], val_loss: 0.3861, val_acc: 0.8755
# Epoch [122], val_loss: 0.3855, val_acc: 0.8755
# Epoch [123], val_loss: 0.3850, val_acc: 0.8755
# Epoch [124], val_loss: 0.3844, val_acc: 0.8755
# Epoch [125], val_loss: 0.3838, val_acc: 0.8755
# Epoch [126], val_loss: 0.3833, val_acc: 0.8755
# Epoch [127], val_loss: 0.3827, val_acc: 0.8755
# Epoch [128], val_loss: 0.3822, val_acc: 0.8755
# Epoch [129], val_loss: 0.3816, val_acc: 0.8755
# Epoch [130], val_loss: 0.3811, val_acc: 0.8755
# Epoch [131], val_loss: 0.3806, val_acc: 0.8755
# Epoch [132], val_loss: 0.3801, val_acc: 0.8755
# Epoch [133], val_loss: 0.3796, val_acc: 0.8755
# Epoch [134], val_loss: 0.3791, val_acc: 0.8755
# Epoch [135], val_loss: 0.3786, val_acc: 0.8755
# Epoch [136], val_loss: 0.3782, val_acc: 0.8738
# Epoch [137], val_loss: 0.3777, val_acc: 0.8738
# Epoch [138], val_loss: 0.3772, val_acc: 0.8772
# Epoch [139], val_loss: 0.3768, val_acc: 0.8772
# Epoch [140], val_loss: 0.3763, val_acc: 0.8772
# Epoch [141], val_loss: 0.3759, val_acc: 0.8772
# Epoch [142], val_loss: 0.3754, val_acc: 0.8788
# Epoch [143], val_loss: 0.3750, val_acc: 0.8788
# Epoch [144], val_loss: 0.3746, val_acc: 0.8788
# Epoch [145], val_loss: 0.3741, val_acc: 0.8788
# Epoch [146], val_loss: 0.3737, val_acc: 0.8788
# Epoch [147], val_loss: 0.3733, val_acc: 0.8788
# Epoch [148], val_loss: 0.3729, val_acc: 0.8788
# Epoch [149], val_loss: 0.3725, val_acc: 0.8788
# Epoch [150], val_loss: 0.3721, val_acc: 0.8788
# Epoch [151], val_loss: 0.3717, val_acc: 0.8788
# Epoch [152], val_loss: 0.3714, val_acc: 0.8788
# Epoch [153], val_loss: 0.3710, val_acc: 0.8788
# Epoch [154], val_loss: 0.3706, val_acc: 0.8788
# Epoch [155], val_loss: 0.3703, val_acc: 0.8788
# Epoch [156], val_loss: 0.3699, val_acc: 0.8788
# Epoch [157], val_loss: 0.3695, val_acc: 0.8788
# Epoch [158], val_loss: 0.3692, val_acc: 0.8788
# Epoch [159], val_loss: 0.3688, val_acc: 0.8788
# Epoch [160], val_loss: 0.3685, val_acc: 0.8788
# Epoch [161], val_loss: 0.3682, val_acc: 0.8788
# Epoch [162], val_loss: 0.3678, val_acc: 0.8788
# Epoch [163], val_loss: 0.3675, val_acc: 0.8788
# Epoch [164], val_loss: 0.3671, val_acc: 0.8788
# Epoch [165], val_loss: 0.3668, val_acc: 0.8788
# Epoch [166], val_loss: 0.3665, val_acc: 0.8788
# Epoch [167], val_loss: 0.3662, val_acc: 0.8788
# Epoch [168], val_loss: 0.3659, val_acc: 0.8788
# Epoch [169], val_loss: 0.3656, val_acc: 0.8788
# Epoch [170], val_loss: 0.3653, val_acc: 0.8788
# Epoch [171], val_loss: 0.3650, val_acc: 0.8788
# Epoch [172], val_loss: 0.3647, val_acc: 0.8788
# Epoch [173], val_loss: 0.3644, val_acc: 0.8788
# Epoch [174], val_loss: 0.3641, val_acc: 0.8788
# Epoch [175], val_loss: 0.3638, val_acc: 0.8788
# Epoch [176], val_loss: 0.3635, val_acc: 0.8788
# Epoch [177], val_loss: 0.3632, val_acc: 0.8788
# Epoch [178], val_loss: 0.3629, val_acc: 0.8788
# Epoch [179], val_loss: 0.3627, val_acc: 0.8788
# Epoch [180], val_loss: 0.3624, val_acc: 0.8788
# Epoch [181], val_loss: 0.3621, val_acc: 0.8788
# Epoch [182], val_loss: 0.3619, val_acc: 0.8788
# Epoch [183], val_loss: 0.3616, val_acc: 0.8788
# Epoch [184], val_loss: 0.3613, val_acc: 0.8788
# Epoch [185], val_loss: 0.3611, val_acc: 0.8805
# Epoch [186], val_loss: 0.3608, val_acc: 0.8788
# Epoch [187], val_loss: 0.3606, val_acc: 0.8788
# Epoch [188], val_loss: 0.3603, val_acc: 0.8788
# Epoch [189], val_loss: 0.3601, val_acc: 0.8788
# Epoch [190], val_loss: 0.3599, val_acc: 0.8788
# Epoch [191], val_loss: 0.3596, val_acc: 0.8788
# Epoch [192], val_loss: 0.3594, val_acc: 0.8788
# Epoch [193], val_loss: 0.3591, val_acc: 0.8805
# Epoch [194], val_loss: 0.3589, val_acc: 0.8805
# Epoch [195], val_loss: 0.3587, val_acc: 0.8805
# Epoch [196], val_loss: 0.3585, val_acc: 0.8805
# Epoch [197], val_loss: 0.3582, val_acc: 0.8805
# Epoch [198], val_loss: 0.3580, val_acc: 0.8805
# Epoch [199], val_loss: 0.3578, val_acc: 0.8805
# Epoch [200], val_loss: 0.3576, val_acc: 0.8805
# Epoch [201], val_loss: 0.3574, val_acc: 0.8805
# Epoch [202], val_loss: 0.3572, val_acc: 0.8822
# Epoch [203], val_loss: 0.3569, val_acc: 0.8822
# Epoch [204], val_loss: 0.3567, val_acc: 0.8822
# Epoch [205], val_loss: 0.3565, val_acc: 0.8822
# Epoch [206], val_loss: 0.3563, val_acc: 0.8822
# Epoch [207], val_loss: 0.3561, val_acc: 0.8822
# Epoch [208], val_loss: 0.3559, val_acc: 0.8822
# Epoch [209], val_loss: 0.3557, val_acc: 0.8822
# Epoch [210], val_loss: 0.3556, val_acc: 0.8822
# Epoch [211], val_loss: 0.3554, val_acc: 0.8822
# Epoch [212], val_loss: 0.3552, val_acc: 0.8822
# Epoch [213], val_loss: 0.3550, val_acc: 0.8822
# Epoch [214], val_loss: 0.3548, val_acc: 0.8822
# Epoch [215], val_loss: 0.3546, val_acc: 0.8822
# Epoch [216], val_loss: 0.3544, val_acc: 0.8822
# Epoch [217], val_loss: 0.3543, val_acc: 0.8822
# Epoch [218], val_loss: 0.3541, val_acc: 0.8822
# Epoch [219], val_loss: 0.3539, val_acc: 0.8822
# Epoch [220], val_loss: 0.3537, val_acc: 0.8822
# Epoch [221], val_loss: 0.3536, val_acc: 0.8822
# Epoch [222], val_loss: 0.3534, val_acc: 0.8822
# Epoch [223], val_loss: 0.3532, val_acc: 0.8822
# Epoch [224], val_loss: 0.3531, val_acc: 0.8822
# Epoch [225], val_loss: 0.3529, val_acc: 0.8822
# Epoch [226], val_loss: 0.3527, val_acc: 0.8822
# Epoch [227], val_loss: 0.3526, val_acc: 0.8822
# Epoch [228], val_loss: 0.3524, val_acc: 0.8822
# Epoch [229], val_loss: 0.3523, val_acc: 0.8822
# Epoch [230], val_loss: 0.3521, val_acc: 0.8822
# Epoch [231], val_loss: 0.3520, val_acc: 0.8822
# Epoch [232], val_loss: 0.3518, val_acc: 0.8822
# Epoch [233], val_loss: 0.3516, val_acc: 0.8822
# Epoch [234], val_loss: 0.3515, val_acc: 0.8822
# Epoch [235], val_loss: 0.3513, val_acc: 0.8822
# Epoch [236], val_loss: 0.3512, val_acc: 0.8822
# Epoch [237], val_loss: 0.3510, val_acc: 0.8822
# Epoch [238], val_loss: 0.3509, val_acc: 0.8822
# Epoch [239], val_loss: 0.3508, val_acc: 0.8822
# Epoch [240], val_loss: 0.3506, val_acc: 0.8822
# Epoch [241], val_loss: 0.3505, val_acc: 0.8822
# Epoch [242], val_loss: 0.3503, val_acc: 0.8822
# Epoch [243], val_loss: 0.3502, val_acc: 0.8822
# Epoch [244], val_loss: 0.3501, val_acc: 0.8822
# Epoch [245], val_loss: 0.3499, val_acc: 0.8822
# Epoch [246], val_loss: 0.3498, val_acc: 0.8822
# Epoch [247], val_loss: 0.3497, val_acc: 0.8822
# Epoch [248], val_loss: 0.3496, val_acc: 0.8822
# Epoch [249], val_loss: 0.3494, val_acc: 0.8822
# Epoch [250], val_loss: 0.3493, val_acc: 0.8838
# Epoch [251], val_loss: 0.3492, val_acc: 0.8838
# Epoch [252], val_loss: 0.3490, val_acc: 0.8838
# Epoch [253], val_loss: 0.3489, val_acc: 0.8838
# Epoch [254], val_loss: 0.3488, val_acc: 0.8838
# Epoch [255], val_loss: 0.3486, val_acc: 0.8838
# Epoch [256], val_loss: 0.3485, val_acc: 0.8838
# Epoch [257], val_loss: 0.3484, val_acc: 0.8838
# Epoch [258], val_loss: 0.3483, val_acc: 0.8838
# Epoch [259], val_loss: 0.3482, val_acc: 0.8838
# Epoch [260], val_loss: 0.3481, val_acc: 0.8838
# Epoch [261], val_loss: 0.3480, val_acc: 0.8838
# Epoch [262], val_loss: 0.3478, val_acc: 0.8838
# Epoch [263], val_loss: 0.3477, val_acc: 0.8838
# Epoch [264], val_loss: 0.3476, val_acc: 0.8838
# Epoch [265], val_loss: 0.3475, val_acc: 0.8838
# Epoch [266], val_loss: 0.3474, val_acc: 0.8838
# Epoch [267], val_loss: 0.3473, val_acc: 0.8838
# Epoch [268], val_loss: 0.3472, val_acc: 0.8838
# Epoch [269], val_loss: 0.3471, val_acc: 0.8838
# Epoch [270], val_loss: 0.3470, val_acc: 0.8838
# Epoch [271], val_loss: 0.3468, val_acc: 0.8838
# Epoch [272], val_loss: 0.3467, val_acc: 0.8838
# Epoch [273], val_loss: 0.3466, val_acc: 0.8838
# Epoch [274], val_loss: 0.3465, val_acc: 0.8838
# Epoch [275], val_loss: 0.3464, val_acc: 0.8838
# Epoch [276], val_loss: 0.3463, val_acc: 0.8838
# Epoch [277], val_loss: 0.3462, val_acc: 0.8838
# Epoch [278], val_loss: 0.3461, val_acc: 0.8838
# Epoch [279], val_loss: 0.3460, val_acc: 0.8838
# Epoch [280], val_loss: 0.3459, val_acc: 0.8838
# Epoch [281], val_loss: 0.3458, val_acc: 0.8838
# Epoch [282], val_loss: 0.3457, val_acc: 0.8838
# Epoch [283], val_loss: 0.3456, val_acc: 0.8838
# Epoch [284], val_loss: 0.3455, val_acc: 0.8838
# Epoch [285], val_loss: 0.3454, val_acc: 0.8838
# Epoch [286], val_loss: 0.3453, val_acc: 0.8838
# Epoch [287], val_loss: 0.3452, val_acc: 0.8838
# Epoch [288], val_loss: 0.3451, val_acc: 0.8838
# Epoch [289], val_loss: 0.3451, val_acc: 0.8838
# Epoch [290], val_loss: 0.3450, val_acc: 0.8838
# Epoch [291], val_loss: 0.3449, val_acc: 0.8838
# Epoch [292], val_loss: 0.3448, val_acc: 0.8838
# Epoch [293], val_loss: 0.3447, val_acc: 0.8838
# Epoch [294], val_loss: 0.3446, val_acc: 0.8838
# Epoch [295], val_loss: 0.3446, val_acc: 0.8838
# Epoch [296], val_loss: 0.3445, val_acc: 0.8838
# Epoch [297], val_loss: 0.3444, val_acc: 0.8838
# Epoch [298], val_loss: 0.3443, val_acc: 0.8838
# Epoch [299], val_loss: 0.3442, val_acc: 0.8838

# %%
history2 = fit(20, 0.001, model, train_loader, val_loader)
# Out:
# Epoch [0], val_loss: 0.5816, val_acc: 0.7910
# Epoch [1], val_loss: 0.5753, val_acc: 0.7960
# Epoch [2], val_loss: 0.5691, val_acc: 0.8076
# Epoch [3], val_loss: 0.5632, val_acc: 0.8093
# Epoch [4], val_loss: 0.5575, val_acc: 0.8126
# Epoch [5], val_loss: 0.5520, val_acc: 0.8160
# Epoch [6], val_loss: 0.5467, val_acc: 0.8210
# Epoch [7], val_loss: 0.5416, val_acc: 0.8226
# Epoch [8], val_loss: 0.5366, val_acc: 0.8260
# Epoch [9], val_loss: 0.5318, val_acc: 0.8293
# Epoch [10], val_loss: 0.5272, val_acc: 0.8310
# Epoch [11], val_loss: 0.5228, val_acc: 0.8343
# Epoch [12], val_loss: 0.5185, val_acc: 0.8343
# Epoch [13], val_loss: 0.5144, val_acc: 0.8360
# Epoch [14], val_loss: 0.5104, val_acc: 0.8343
# Epoch [15], val_loss: 0.5065, val_acc: 0.8376
# Epoch [16], val_loss: 0.5028, val_acc: 0.8466
# Epoch [17], val_loss: 0.4992, val_acc: 0.8449
# Epoch [18], val_loss: 0.4957, val_acc: 0.8466
# Epoch [19], val_loss: 0.4923, val_acc: 0.8482

# %%
history3 = fit(20, 0.001, model, train_loader, val_loader)
# Out:
# Epoch [0], val_loss: 0.4891, val_acc: 0.8499
# Epoch [1], val_loss: 0.4859, val_acc: 0.8482
# Epoch [2], val_loss: 0.4828, val_acc: 0.8532
# Epoch [3], val_loss: 0.4798, val_acc: 0.8549
# Epoch [4], val_loss: 0.4770, val_acc: 0.8588
# Epoch [5], val_loss: 0.4742, val_acc: 0.8588
# Epoch [6], val_loss: 0.4715, val_acc: 0.8588
# Epoch [7], val_loss: 0.4688, val_acc: 0.8605
# Epoch [8], val_loss: 0.4663, val_acc: 0.8622
# Epoch [9], val_loss: 0.4638, val_acc: 0.8622
# Epoch [10], val_loss: 0.4615, val_acc: 0.8605
# Epoch [11], val_loss: 0.4591, val_acc: 0.8638
# Epoch [12], val_loss: 0.4568, val_acc: 0.8638
# Epoch [13], val_loss: 0.4546, val_acc: 0.8638
# Epoch [14], val_loss: 0.4525, val_acc: 0.8672
# Epoch [15], val_loss: 0.4504, val_acc: 0.8672
# Epoch [16], val_loss: 0.4484, val_acc: 0.8672
# Epoch [17], val_loss: 0.4464, val_acc: 0.8672
# Epoch [18], val_loss: 0.4445, val_acc: 0.8655
# Epoch [19], val_loss: 0.4426, val_acc: 0.8672

# %% [markdown]
# ## Validação do modelo

# %%
test_dataset = TensorDataset(xte, yte)
test_loader = DataLoader(test_dataset, batch_size=40)
result = evaluate(model, test_loader)
result
# Out:
# {'val_acc': 0.883823573589325, 'val_loss': 0.34420245885849}
