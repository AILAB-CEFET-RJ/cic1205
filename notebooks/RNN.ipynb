# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

# One hot encoding for each char in 'hello'
h = [1, 0, 0, 0]
e = [0, 1, 0, 0]
l = [0, 0, 1, 0]
o = [0, 0, 0, 1]

# One cell RNN input_dim (4) -> output_dim (2). sequence: 5
cell = nn.RNN(input_size=4, hidden_size=2, batch_first=True)

# (num_layers * num_directions, batch, hidden_size) whether batch_first=True or False
hidden = Variable(torch.randn(1, 1, 2))

# Propagate input through RNN
# Input: (batch, seq_len, input_size) when batch_first=True
inputs = Variable(torch.Tensor([h, e, l, l, o]))
for one in inputs:
    one = one.view(1, 1, -1)
    # Input: (batch, seq_len, input_size) when batch_first=True
    out, hidden = cell(one, hidden)
    print("one input size", one.size(), "out size", out.size())

# We can do the whole at once
# Propagate input through RNN
# Input: (batch, seq_len, input_size) when batch_first=True
inputs = inputs.view(1, 5, -1)
out, hidden = cell(inputs, hidden)
print("sequence input size", inputs.size(), "out size", out.size())


# hidden : (num_layers * num_directions, batch, hidden_size) whether batch_first=True or False
hidden = Variable(torch.randn(1, 3, 2))

# One cell RNN input_dim (4) -> output_dim (2). sequence: 5, batch 3
# 3 batches 'hello', 'eolll', 'lleel'
# rank = (3, 5, 4)
inputs = Variable(torch.Tensor([[h, e, l, l, o],
                                [e, o, l, l, l],
                                [l, l, e, e, l]]))

# Propagate input through RNN
# Input: (batch, seq_len, input_size) when batch_first=True
# B x S x I
out, hidden = cell(inputs, hidden)
print("batch input size", inputs.size(), "out size", out.size())


# One cell RNN input_dim (4) -> output_dim (2)
cell = nn.RNN(input_size=4, hidden_size=2)

# The given dimensions dim0 and dim1 are swapped.
inputs = inputs.transpose(dim0=0, dim1=1)
# Propagate input through RNN
# Input: (seq_len, batch_size, input_size) when batch_first=False (default)
# S x B x I
out, hidden = cell(inputs, hidden)
print("batch input size", inputs.size(), "out size", out.size())
# Out:
# one input size torch.Size([1, 1, 4]) out size torch.Size([1, 1, 2])
# one input size torch.Size([1, 1, 4]) out size torch.Size([1, 1, 2])
# one input size torch.Size([1, 1, 4]) out size torch.Size([1, 1, 2])
# one input size torch.Size([1, 1, 4]) out size torch.Size([1, 1, 2])
# one input size torch.Size([1, 1, 4]) out size torch.Size([1, 1, 2])
# sequence input size torch.Size([1, 5, 4]) out size torch.Size([1, 5, 2])
# batch input size torch.Size([3, 5, 4]) out size torch.Size([3, 5, 2])
# batch input size torch.Size([5, 3, 4]) out size torch.Size([5, 3, 2])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

lstm = nn.LSTM(3, 3)  # Input dim is 3, output dim is 3
inputs = [torch.randn(1, 3) for _ in range(5)]  # make a sequence of length 5

# initialize the hidden state.
bck = hidden = (torch.randn(1, 1, 3),
          torch.randn(1, 1, 3))
for i in inputs:
    # Step through the sequence one element at a time.
    # after each step, hidden contains the hidden state.
    out, hidden = lstm(i.view(1, 1, -1), hidden)
    print("-out")
    print(out)
    print("-hidden")
    print(hidden)

print("---")
torch.manual_seed(1)

# alternatively, we can do the entire sequence all at once.
# the first value returned by LSTM is all of the hidden states throughout
# the sequence. the second is just the most recent hidden state
# (compare the last slice of "out" with "hidden" below, they are the same)
# The reason for this is that:
# "out" will give you access to all hidden states in the sequence
# "hidden" will allow you to continue the sequence and backpropagate,
# by passing it as an argument  to the lstm at a later time
# Add the extra 2nd dimension
inputs = torch.cat(inputs).view(len(inputs), 1, -1)
hidden = bck
#hidden = (torch.randn(1, 1, 3), torch.randn(1, 1, 3))  # clean out hidden state
out, hidden = lstm(inputs, hidden)
print("-out")
print(out)
print("-hidden")
print(hidden)
# Out:
# -out
# tensor([[[-0.2682,  0.0304, -0.1526]]], grad_fn=<StackBackward>)
# -hidden
# (tensor([[[-0.2682,  0.0304, -0.1526]]], grad_fn=<StackBackward>), tensor([[[-1.0766,  0.0972, -0.5498]]], grad_fn=<StackBackward>))
# -out
# tensor([[[-0.5370,  0.0346, -0.1958]]], grad_fn=<StackBackward>)
# -hidden
# (tensor([[[-0.5370,  0.0346, -0.1958]]], grad_fn=<StackBackward>), tensor([[[-1.1552,  0.1214, -0.2974]]], grad_fn=<StackBackward>))
# -out
# tensor([[[-0.3947,  0.0391, -0.1217]]], grad_fn=<StackBackward>)
# -hidden
# (tensor([[[-0.3947,  0.0391, -0.1217]]], grad_fn=<StackBackward>), tensor([[[-1.0727,  0.1104, -0.2179]]], grad_fn=<StackBackward>))
# -out
# tensor([[[-0.1854,  0.0740, -0.0979]]], grad_fn=<StackBackward>)
# -hidden
# (tensor([[[-0.1854,  0.0740, -0.0979]]], grad_fn=<StackBackward>), tensor([[[-1.0530,  0.1836, -0.1731]]], grad_fn=<StackBackward>))
# -out
# tensor([[[-0.3600,  0.0893,  0.0215]]], grad_fn=<StackBackward>)
# -hidden
# (tensor([[[-0.3600,  0.0893,  0.0215]]], grad_fn=<StackBackward>), tensor([[[-1.1298,  0.4467,  0.0254]]], grad_fn=<StackBackward>))
# ---
# -out
# tensor([[[-0.2682,  0.0304, -0.1526]],
#
#         [[-0.5370,  0.0346, -0.1958]],
#
#         [[-0.3947,  0.0391, -0.1217]],
#
#         [[-0.1854,  0.0740, -0.0979]],
#
#         [[-0.3600,  0.0893,  0.0215]]], grad_fn=<StackBackward>)
# -hidden
# (tensor([[[-0.3600,  0.0893,  0.0215]]], grad_fn=<StackBackward>), tensor([[[-1.1298,  0.4467,  0.0254]]], grad_fn=<StackBackward>))

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)


training_data = [
    ("The dog ate the apple".split(), ["DET", "NN", "V", "DET", "NN"]),
    ("Everybody read that book".split(), ["NN", "V", "DET", "NN"]),
    ("The fox ate the chicken".split(), ["DET", "NN", "V", "DET", "NN"])
]
word_to_ix = {}
for sent, tags in training_data:
    for word in sent:
        if word not in word_to_ix:
            word_to_ix[word] = len(word_to_ix)
print(word_to_ix)
tag_to_ix = {"DET": 0, "NN": 1, "V": 2}

# These will usually be more like 32 or 64 dimensional.
# We will keep them small, so we can see how the weights change as we train.
EMBEDDING_DIM = 6
HIDDEN_DIM = 6
# Out:
# {'The': 0, 'dog': 1, 'ate': 2, 'the': 3, 'apple': 4, 'Everybody': 5, 'read': 6, 'that': 7, 'book': 8, 'fox': 9, 'chicken': 10}

# %%
class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim

        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1))
        tag_space = self.hidden2tag(lstm_out.view(len(sentence), -1))
        tag_scores = F.log_softmax(tag_space, dim=1)
        return tag_scores

# %% [markdown]
# Credits: Andery Karpathy (https://gist.github.com/karpathy/d4dee566867f8291f086)

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('/tmp/input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print ('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 1918 characters, 56 unique.
# ----
#  OnpaãU!d;«êoN-_eSjR»fmmO,fx f»ãóbeOé.bbRV-qnnUpç.«Mx_Aé
# jSq!ENJéDojçExc_et êAMSquO'AqrngORAé;êCé,u;ç'MdHSahMçv:DadV,tP
# b.s-.ROCfovjC-NxdSEfa
# áflgébqéé;ssArEaTOOgCenó-«Nov:;hHz C
# EVjáqUrOTUáV;dvã!CqNaH
# ----
# iter 0, loss: 100.633790
# ----
#  .eimnoei
# ao
# i
#  nm
# susz.
# lleo
# aa-o.
# . r-ze
# hA g armauol
# . a e he ti .rere a orumoone -hat
# nelie i
# teeies
#
#  i .oodor m aiiuneddo c
# o zuo temm
# iuoi ms
# e i.mda pte
#
# hiolszll
# -a.om
# -,.n
#  plrm
# h.s uai
# ----
# iter 100, loss: 101.102123
# ----
#  Dtuua«oi«. azemánPoEmiuu;«mauhesreb.eca-ziumi tiiVaVvmmhe gi,eá-h
# . sideuadeeminuise juumM u a«-nnoCcuideeieando há-voocgo gut-».acet«m«nccD«seiuoxnu».iih
# zu-zmeiq-elMe ameri N.  o ãereimainua-ee M»-f
# ----
# iter 200, loss: 99.124738
# ----
#  acre puap ene loha ço doseanãa oede danvo oorouénfo, feu  oip, ãommtro euhnho
# npee nortth.
# corhO, pouEaeãourqfoãres
#  eOçensos,
# quennmo de ro q
# oneoçfisrense Tosnuonbomoleroe nãou heo-eia  eororer eore
# ----
# iter 300, loss: 96.631851
# ----
#  tanoassl
# s
#  alssheséets
# pa vomro m sstr mfrrf- albe cos o.l esuu
# çavgurasct. m prão
# llsuSsssonosssa sos,szm s
# sibelmes lvess
# Cnãosasbamdoh, onsln! abo
# lertostess
# torsutre valbossestmusvolslnote s  stl
# ----
# iter 400, loss: 93.960196
# ----
#  -a cussos, Ca da iala mss do au, peo almu  o, po o-ce oou«ha  arama
# golasma_«ema arasça as s a aso. asue out--a olze ra ge
# -a; ca; aepa, e-te  o
# adara a a crdoapa do  a, qãa as da da ha gom asça ricas
# ----
# iter 500, loss: 91.383883
# ----
#  pas é pos doua di fa; e, irirrãoalhir elfitido a do ho.
# misivo ror lmo e virNo a, quenastaz e vm
# baro, vait
# ti mo  o ginta pi _lco tão vão a ea dirmoint; pou vicuroo aite ço movoMara oão vorsilirtrros
# ----
# iter 600, loss: 89.230459
# ----
#  se manos pos es eçauçedoo em,, quo ema ese fe ceu aheu astossa,
# qua re, que, e o vho, vom que pos dá as ésso. te la messopolgeroisapes olta-po portodoe costenéanhorêoc a eradei não o
# go. os va eaco, v
# ----
# iter 700, loss: 86.705738
# ----
#  iguitm:msl. amms, aamel :m, : eus mu
#  cu gegssmtss _á a;s vigcigmslmegodare v doe, cimungde, la
# paccis elga, a
# me, fess, deinlirtas mis rsestesteldozcida-mem qu s paços cilgo, ma
# zi, vala slchisflNuut
# ----
# iter 800, loss: 84.298511
# ----
#  lheldinoramnnoidado, mum uirrartde imitos n-imoras e
# ro
# tom panou-Tado nouançudo _ richo inf jondominte ro
# ão veigamamslastraler do dimrelhe do ficortalre mu-cri couvam par: posou rouridé _ ozemgocdo
# ----
# iter 900, loss: 81.950269
# ----
#  ue a mos ié do vosgór pemnr vem vere ceqçe a asvor para que e do doss o ver, condoo nrá ponios da; ssaças. ceu esroai sse a Ver,, codo  oA pess pho «e mai a, cerivem O iido uu e  o divesmess pitus
# e d
# ----
# iter 1000, loss: 79.687597
# ----
#   que tui aro; po -os uu ndo bii murs ca, Nenmu Noisuuamésame me Daruuro Eutou pou. cuido ve. cunmo
# so Ce Sarcuipas ee bu-miuultro, a e-se dou. demer, Neaseuab erra
# se ou cos quasiu:carro.gam. dou faqu
# ----
# iter 1100, loss: 77.642776
# ----
#  Equa pãa lhim do ertanhou-ze ho munhe, hede nmesso Cem vam
# de so. ze que aldo de do que
# tei _ido dode mez veste; que m dem da que dom, que aCoi cendo phadmadlle dome vos, de te damu, qPe do
# lhe vhe  i
# ----
# iter 1200, loss: 75.594134
# ----
#  rá _seê pirov peutedes e Ca
# io. fargo, daame sonte, iinhou dodunE memarapora pansonssenipaCas o, peno toçostamanão Naa. to pontou»s enzapemeiapera tanoigom me mová menhen-inou nalEi eltou re se do de
# ----
# iter 1300, loss: 73.664783
# ----
#  strz
# znão do, anitilmitllao dom, mumsivadvalqua de go. pem não _o, cam fes ralranhim nos rstisna gestilhisrospolho eosto orros dosaas; ou pasa o domes
# --«iau do
# quem . CantonNo, cacgontrmu n, bos
#
# do
# ----
# iter 1400, loss: 71.818755
# ----
#  ão do.»-sáo _ão vinilorotá Phositrom
# deiluurra
# -sV
# musa eimuetarou o,
# Sái nhiqucrecldo curroc rirrro, dãoudod--scerrescangospoportom Castio a cque deitiniom e rosamamis.»-
# Mãiseinuu Cmusigui lhe não i
# ----
# iter 1500, loss: 70.010817
# ----
#  , se-«Vea aça a dons ferfisales a da na perso do que
#
#  es vintee poutroe didu se
# mente a a
# do qui né
# poré ni eni não er pell'us au-maciro
# qua e meé de nlnh polgoitundo piraginm
# nrttrs se lãi nhe conãr
# ----
# iter 1600, loss: 68.274300
# ----
#  eu zente do
# cara vantetro,
#  ema vechisuinso ou vis e esa
# ---adrondo a fegentaitalao doo e e vinte., aiatuiça, asso conoo estos radeu asso e tos ssabrada catas va dolho, au-cadouto
# te ou cicaldo.
# costa
# ----
# iter 1700, loss: 66.670199
# ----
#  Cade _Dontubra
# taidadom nhenhe canhadesmerso, larsinos ómiaminlhe nitirtêsaçadooinida de
# dou cos.i anoa Não era euinho vida io dos asinmetro diaroumus Cos-lCe citidiuuicuiainará; andoetCadalluende cim
# ----
# iter 1800, loss: 65.177993
# ----
#  o tisem e esserra dou, não relsdo. eunão que serterteimalapêusrar queo.
# écsoro.»
# saor cualandourra
# ton.
# E samrão Cos emoCous ditusi entouirorrrão e aelou rros adorra
#  Têuçia enouo.»mum dientririha lhe
# ----
# iter 1900, loss: 63.691024
# ----
#  i-icull---os uicacao hadamrr--Sãoisuideu dos e lTusmurlvi murtde
# vou imida eicanhorNo gendo Sutro ectá ol e som ninhoro ;
# bidi lha alengou-lieuivas ais. Suzo tatem em
# deslleão
# Ee,nnão outrs; , pim van
# ----
# iter 2000, loss: 62.261683
# ----
#   soça A i que tida ous Ca, vêa uarase mers qua do gaicas nhasma de voro E conbro o e dos itá em fag.s do som»voso, Taram, do cassas penheqse
# xosá venter do maras es Rurraqui aqualsá asm;.»--«Vo ta ch«
# ----
# iter 2100, loss: 60.952473
# ----
#  do, Tontue tó cera mom da cee e de vouipar de masti alou.
# é veité pãonguinfeçholanou reimus e do famutoo dorço.
#  ao o, seros.i , al viada vuço dos. sos. verotdo Cento, sara.RDes_não não tera ennou co,
# ----
# iter 2200, loss: 59.688156
# ----
#  -le a a atr so _: lcas ou varoa ara se isoi e meltou pere e tesstem ça se de bou
#
# tze ros á e do so.
#
# --si es o tros usso os que e me a teri eus i de ventrentavarro co.; que es a os verse vo ou mer ou
# ----
# iter 2300, loss: 58.547029
# ----
#  mrecam_
# a , «Do dimurr que zercanarrro, Camerm
# Erapeoço es: memma; ; per O para veu dam a
#  é a pê mim que do cinso. vercagi do pos zara do lho
# lo Dazê veummina, seá dovraba sa a. Ca ceé do cim las, o
# ----
# iter 2400, loss: 57.491879
# ----
#  lá poipoh en vo toc-midasmolti nãe facpom ma vinhe Cilro do cam tara e roéo permom Om,s que do litrra o. Colhante a do gemeitre voro do
# E dono do ei oi atroão peda  u vo de lão lhe fado.
#
# -ve pera miv
# ----
# iter 2500, loss: 56.373222
# ----
#   dos giclde «hebe.m Carammersque aqui cDgindo hom, dosmesso, e as do e Oonêse-me ctre cussomecaqum asem que engou cetlontaldolse
# pos,
# Ehade hão
# fommem conao, dóde vemmulauritem degsenmenhoinhoma, pDod
# ----
# iter 2600, loss: 55.375822
# ----
#  ougimengu, amasgigo-molhesro_ e ida
# Em qua da
# lar
# -me gees, mis Oitazengum, Calca ige
# Caz: binmpa
# gos
# a oi ammigenhamige, _Dom
# Colgem, «Dam, om rhrrtrra».
#
# demu táiique ei antenhagé se, jechem, nou el
# ----
# iter 2700, loss: 54.448731
# ----
#  çá qui do goma o healão alartou _he não _ venmerro_ Pe não es Dom ciderti no do dicaltor tiv iraliizertos dã co, sencidaté a civar e do civsibutis.
# á vhrsa oo pordopem p'omictradado tro, pórallinêlcun
# ----
# iter 2800, loss: 53.529598
# ----
#  ue no cis. Co Ness as se e--«Meuo peraro, O, oa, a as mes. ma ther arabai o tivmisinhe manta, diiam e to, sez tues para para pere femenãostinis de cuiro
# do a mado bo-le tuimentoe có casa vic ae Neemen
# ----
# iter 2900, loss: 52.602737
# ----
#   Sugustiga
# go. de hos;s, algolhom famuem Casmira
# -ro dia tino bilondorori
#  e ngou padi dou, essalnar zesmas.
#
# --le es «Migo
#
#
# me vesmulso Cimuitonsu mezis, dous deguimue da cinanhocgu-go.
#
# se ninhov D
# ----
# iter 3000, loss: 51.758950
# ----
#  te do ama; dos_nve-mo vendou dó -Cac-e telhe não fim
# de.»-
# «-l
# e vo
# do dasa dermi.»--«Meu; o; de tot que não dona cale, pirsu dos-slhf cara vha Cittrr c-llou. A qua do lha mismei mesdo
# do que lão qulo
# ----
# iter 3100, loss: 50.889323
# ----
#  s. se dinsi e dos, menho imestos pe
# Sutia, dou_ peitas vernoq atos amenho e tus, pou milhes er le
# inTulteita Snom_ ou pa e a vontore tenho derm nare de fovo senta lho fum, povo ná e ttel ca doçasa vem
# ----
# iter 3200, loss: 50.090427
# ----
#  s, -la« não _çves du casmiratlis mu gontangom doças padou mattibismingo.
#
# --«Meufidos nguSusmenha Rue
# e-ce tusminos em coCana cas e
# do
# cim hom pazaus sulha; que gu manhor mulmn-motto do, se que
# a com
#
# ----
# iter 3300, loss: 49.395307
# ----
#  o; ná nha
# lhuo, endo de
# Ré surro, enserrovoz vêzaes.
# E suiro cotinhe cá ros.
# _
# que atouro; , e asanãão No.»--hãe mom
# poutorsalhãrruldaque zius coe não lheiNo
# -menhãaclivouda erasra Rhes hevrisa éuE cu
# ----
# iter 3400, loss: 48.680728
# ----
#  ro. deulo pe que que eça; orá
# ação entepa
# es per ne z a de fada a a darro Nos Do trro, ha tuendo a vou pão _ge a o dinnreinão mertá pevsento vito Po
#
# a doutreu dabdas o dos.
#
# Vem
# de datn.é a carou faz
# ----
# iter 3500, loss: 48.002066
# ----
#  e; ser ontem não i do balbo. as fitrrigos ertae to--oto, vorsemca
# vou do de,, vrabitro paro vinho eratrous, Nostrosbenáo
# gu, Cassitapo bivort, des, perso--JVeus. elatém, e toigulgouagolgom nado, podo
# ----
# iter 3600, loss: 47.409935
# ----
#  lge que amo, sá arasmanhão da
# Nã; nha do lat que de
# xassondom_ vitáe dra, e nhas jos não civaditim entro, coster mus verse Ca cadeté o as ango-mis memange dão dolgesss merzeze
#  denmenda
# Nos-uhmela den
# ----
# iter 3700, loss: 46.708543
# ----
#  o tit-lhe grros inteniguenas dermem uico.
# dostalcoitando. sencuro essue. por encade deufide, saque menta nsoutre; lhe orasa. --ho ihabenão lhe ou aleu aadaatrostaratluroçãos chlhe fachituu dorrronourr
# ----
# iter 3800, loss: 46.074601
# ----
#  ou, que
# noléo, eimar jan.e-me fuldo.»
# Umipasso airaritatem pados, e nho, merros posbencompo, ques coss; que so tidou
# rapetos e murrabeu.
# E cuo ou entira
# eu fitter tro, para aitar: Sco ouisoo.
# -me que
#
# ----
# iter 3900, loss: 45.503616
# ----
#  calde vinho a a doma a es em nom_ do catdo xas, para da civilge, fa, na_ esta sonteu do gom dapxoshom, verçostros ides deuxle, so boa es que a, sime tio furéná -mi a menhão selfo. Cas-uitoe.
# -Ve bo.»o
# ----
# iter 4000, loss: 44.965112
# ----
#  de di clzentá euno vorou enros do que lhesa pocinhe aua a á a molhempester melae do pendo tetliimero e chemrar ando colé hhrrome a fagunão em re_ regem fenfis, vino, fantivuré que não t'eochara elto o
# ----
# iter 4100, loss: 44.429933
# ----
#  -mo, gos pó-mentevo; meg sepobe fummisseu vaza e se vónanarabo.re, que cle aelhou melhes eoma abresstos mer ou por os enté a se diagoço aes. Nsmensade
# dos e de Echaitastoo.
# çose tou macunditanous vue
# ----
# iter 4200, loss: 43.921339
# ----
#  No aa dos.
# mos pódeum Ca
# mui
# de diimita»se mul omas
# hesim, mo, das-le bom
#  e,nDos poz idas poigum namengo, da gom gos
# do es_ veia e caram CaCansa fafmitur ou-me
# do.
# Cosi genhou
# gosi _ doum da
# bo.
#
# ---
# ----
# iter 4300, loss: 43.419201
# ----
#  a detulco, pozaitio do dcaroa-me che dorago cada demá hado para paratá e titu de
# deu, Perroutra cidolhei Dibuitor paiéutrra muntre o a lhuurrs, date. Cati aidosçardasso a damui menhade Pevrr que a éão
# ----
# iter 4400, loss: 42.798106
# ----
#  ume falae aleu e ceita dosirão sda cua, que co ves o polte camem, A Ento s euro; napoubolom que
#
# qui aques, poe
# pecous não aento the, de cuse e es e
# do genho, seroia veicentos, Sos emanto e coqunho do
# ----
# iter 4500, loss: 42.307279
# ----
#  om_ Não que dis, delmer ques
# que es s. que em que es elna iagrabiinho gonhariguigu
#
# T-lhatram esse co, mam da cicalhom taratreuro melhongus asme de empanNu-mando, fince ai Do, se mim dangorr
#  c-mrmiss
# ----
# iter 4600, loss: 41.810796
# ----
#  nro Nundou cesherá cidou on omo, vhe estirão _utcam paro do mulondo! mem padou. que e cidos dogpo mentitrão que veccurtu, poramgro, dodos fur estu; a; filhe firam-lhe ostessa clle diimiv; com daateu d
# ----
# iter 4700, loss: 41.209282
# ----
#  ue oroçia; siglse e civaro para diamitntié e querá abos asso do! mem, ha do e aresiá, tivaro didnto his, secmemtros_ estonoo.
#
# Nlou mel nou_ a ade que edestavraque doe docdosdo E que
# drasolhenho
# -he
# d
# ----
# iter 4800, loss: 40.742490
# ----
#   vrasem, fumos, quu em Casso, poz fusta Cammismesto, sitallunhamesso manha acas amitusmou mel,u mesmessontesse
# senho e lanhasao, que ou mimê, elze fimlo tanhabeussou
# lhe fulhou vis nhos sem Cam iadou-
# ----
# iter 4900, loss: 40.398787
# ----
#  aN om nallisinlheme não; Oo Ddatlur ou vernompoão, dou-me-Ce ado
# e
# sVcunme
# lhe covor quesa etmum não, miz nambescom visso olle dae-lão goldo
#
# ospemá am memanho Nomé doim tá am ceste do bom-me lom pezm
# ----
# iter 5000, loss: 39.940592
# ----
#  que
# de mirale didegenterdis, pade tirrrs lhe nafe ostesmara eonoraro e ê ee _Com varvne por-usbe vrrau o! Casco  querEtro, daquinno tivurdeutovenadeu fo
# -os suaro Nová aCesto
# bena epaz não do.
# Ha; aar
# ----
# iter 5100, loss: 39.534491
# ----
#  s, vendou-sabo.
#
# --Jãonndo _ qui do dimuiismissso diburos em ses, _Dom Oa o bou o om melhro. N eu melhos vecbntout os cadame milhe não
#
# os esmenhou da bias aque que ense sou da guu. _Cas do
# bo dasteul
# ----
# iter 5200, loss: 39.246129
# ----
#  o, sabmide, fesmei celgo
# Costeu a de Noão
# E
# -ão tasmar feses; Dome,
# Mes diiuara não mitadeu, fade.»
#
# Nos, mesma
# do! na ahacacirão  lhamerro; iidortondou-ge, cheta; allom
#
#
# -Cengemada
# -é
# dos a
# mesas al
# ----
# iter 5300, loss: 38.818443
# ----
#   vem aano.
#  er pena. Ha qui che ano.»
# e tera de se thar mes. _ nãostendo do mello; ver as não que
# no, : o mentou da crafengo ço penatinatrolio a virfesfinana se phe fanhor quitra na mirrontade, seré._
# ----
# iter 5400, loss: 38.397204
# ----
#  em ou da lgu
# de camo.»
# _ o trouis e antesma
# do pora attou pa tatou e ados.
#
#
# doisentou verdantaDo, melhesto bus a bincor ver os.ntolho.
#
# --co caro do doz_ ou ses mesmo. Tuto.
#  O , amicas seré gou, ell
# ----
# iter 5500, loss: 38.058040
# ----
#  lhe cade Dom vara , engo.
# Ces dos es mizem
# Caz feraté de catras a dadas tam colhenha manha Novam cara nancomilhe por araqui as alcanha Nanm idas, fe menhal-unses que a
# a ins. _Dosi eque; menhas mostra
# ----
# iter 5600, loss: 37.641403
# ----
#  o titul astur, melhos do ge, pou sernouirão tinão que
# doital-srates á abase melheragro_ e ou rodeido, santelro asso acirá a no na e do d'aque. No aenão es idatrou pare sera e matrostesso do por eot nã
# ----
# iter 5700, loss: 37.265984
# ----
#  uelho. A que
# a
# o asse faré erotitullo eunconom; dostatsou e-merapadeleç-o fever-umo tomtra e que senta octes nãa, . de fes. A trou ou nomeset_Casitarão alairarspeilhesa vizes não, mesmentou miralo dad
# ----
# iter 5800, loss: 36.916874
# ----
#   ou
# , que vou estoi ca cur a caveu, vres Os uis e de, CazDo. N--«Vo-meimpa, es.pEngunhaquio prra a cutanta do vis, que aços segs nom vora vrrdo, mui do banto iute chrs porren no.
#  de segu dos iizer m
# ----
# iter 5900, loss: 36.544510
# ----
#  antrratrou seuinão molhe cou permintra, e mentido
# do-mi acabro, que não tivero a feverter quabne e trrogiditora voinhe não smamem do vecharro.»-ue e tá calgontro, pozarmenhor-lhe firstro, qle noiserou
# ----
# iter 6000, loss: 36.235925
# ----
#  -São isse, para a que o percos póratses sebro. A que se sentoo ia; milhe camo os em lezar; em do da com
# paraussou versos vóccassueta, ches oitaro; vintetro
# bou bara i ze que
# que estaos aocgoso _ eltor
# ----
# iter 6100, loss: 35.909464
# ----
#  cirado;, o vrabeu, Comm mulha, Ca No.
#
# -«VTudo do e a manha
# tos.
#
# os discros vicgom Cammem ; burçe, para que na baz zer naoço, mese.»-re sirs
# cam e cara sentru ia, desllie, que
# a a abau deu miraguiãã;
# ----
# iter 6200, loss: 35.581608
# ----
#  lhe diache e peicanmuittao tor dos de
# cacaratro diimerro; curoi a; que allo do! cicae doutriçavou enmars._ livelte masmou catniraliurlos a angoithe llá anti am nar er or-mitro não , vinganho; me gou r
# ----
# iter 6300, loss: 35.143849
# ----
#  ugo.ço de muros.
# -«Viom de xisou pere avendo doum, focheitoi am, e do-me uusde que
#  fe checfonto, secactem po e fo, seuso que
# el;o rare asol Ha cos. ve-me tontrerão amiraquincorare
# calco. pena oidou-m
# ----
# iter 6400, loss: 34.767327
# ----
#  om ia, sua pó, essalcunharam e zeros, veisam nara selhe e e
# do
# gislitrami as a casafo hiteu fasse canter:te
#  dram Casmui o iompe e dontue, dr-me vhana e mestaoso aque de que de gam,
# lám vis, e que a
# ----
# iter 6500, loss: 34.507601
# ----
#  s ce ao. O com lhe lhe a os persmur Do vavanva cuité doram nhmpCizmurdo, cho gum, Tom i com percosmum,  hesmim domano_ es, vou eu deu ques a chá Rhetanirem dadRor per trou que a está aqui não ticam ca
# ----
# iter 6600, loss: 34.265330
# ----
#  ue
# no.
# pou viral ue ata; para doçfis, fere eu leusi»-lher: endes-le, o
# do po dotass o vrabitro-; ao dacom_ a dou racairarrandou, não, fa vique mames e varto, pora veerou os esso do fis, vos am não, fa
# ----
# iter 6700, loss: 34.013395
# ----
#  , quana es eitar cum nho astrou. O ná a a mu não caqui nasser quiontou velgom visu para para mibmira tiratro a
# go.»
#  disu saccsa, muiha enze dinsitze
#  e tavez cum,sça se son, _lou se civuis do po- alc
# ----
# iter 6800, loss: 33.908128
# ----
#  Coss uotaiou
# g-me am iss emasim, tou diigem domenha e hacgueta; clde do-le xozanha costas om não cudo anacabou imtinVou pade, o é gom_ ves. -Calluralli ales esmes goitrosilhe dou-lhe cem came, são gov
# ----
# iter 6900, loss: 33.673374
# ----
#  ndo do que
# á e dou, e, ueqle paimi andono ves de cidapéo. eu e que não ifa a perro amis, melheça voe. Nole do, mem femuto e a erdo, faroi, e ventoi-uh au velhoçra
# do do lhararor é es enco, a vera dint
# ----
# iter 7000, loss: 33.423150
# ----
#   cadetro daccus, fenha-mocé.»--«Vou paraos
#
# Vquinas unthe
#  os, a dou-me, fo bou pora para sangestoumir, e tataso bem, fos sentitra om
# senattros ver os pera , pave vessou para batto-me poitor em, vou d
# ----
# iter 7100, loss: 33.113241
# ----
#  o_ omisndoa dialeu olcsmuquideramimui
# deibisminhopé
# á tros Tuccae titá
#
# dengom. NCda clccavou ancaiminão que
# alluitassaté a
# tos
# munho, do bum iges dom
# cazou; e esmei a cuntres bos nos lão Donvou, qua
#
# ----
# iter 7200, loss: 32.727411
# ----
#   asmiia. Hamonter vello dasCetirão , tidaro para vique que a vendou semue qui na a isnans ecde vismer pe entento gontr-ódeida cidade e tissDondo Dom do camuitti am Cazani que não, para pers ortar a vD
# ----
# iter 7300, loss: 32.377698
# ----
#  es.»--«Meu olEm itro vamallsa viituos olha vizaria dom
# Dompontal-o; cuo
# aVi tem, fanhe
# Turmue do bamu «ão gonte
# me lou versos vóat tro, falhutro_
# não amavou; que
# alcumá. quenvo xate com los.
#
# Vscos. _
# ----
# iter 7400, loss: 32.154727
# ----
#  lhe «hasui adou tenho nomunho
#
# peg erá imhe
# cor ua, dou-lhe dos do.
# Colae do caqui ao, o didiracé.»
# --lha geacuitaCombinminha abussigemVia; uuiges ancom
# jenhars; veroo. Noc-quingenho
# Nave deixacha
#  ab
# ----
# iter 7500, loss: 31.844364
# ----
#  o tita detro ouro poz diguis. Nove ao diago._ Tuus detros bettis tore sou ia, por eitrra ao. Nodo perss, e se crra naro a o eates com o do dis-lhe, quá afo asro. ve-lhe que ou vêes irro por que do gem
# ----
# iter 7600, loss: 31.515956
# ----
#  cara save
# do berço.
#
# hSinou dortrema voua não inso dou, a es.
# S-smurro, que
# a eu di cis, mem secso dou- e im e lou vecdo; secasé oltes eu cão uassor elouira
# éus dottelhe Rostiverros esta s ques, a em
# ----
# iter 7700, loss: 31.311004
# ----
#   mello. A e loi uitia fos af não i ta e nibuiratra«éo.
#
# -«Ve doitade cam calte tade sintllig em do-me na Dom
# Casmando! som seu dos seg seraté a a do
# pacio vom e e corso do
# Enge, chas. -as dou-ha Nmor
# ----
# iter 7800, loss: 30.977406
# ----
#  antrem ilge chem pave Penhopéo. Os e que não lolpé e braçates de bes quesmeita. No do.
#
# -lJitarã;
# vondouo. _ou mecfirmor fa minhabulhor Jáda menho
# do! lho tres nouçave colher lem velarão e gem não deu
# ----
# iter 7900, loss: 30.719176
# ----
#  -Conto.
#
# --Já estenhe covoe olhera e ores tor ara e não qua
# dostre á ve dou ca cão
# tos vórtos eutfo tames do guaté tessos e camer»
# os persou que ef
# se sess cum, mezinte
# a
# bemo fe lismer de crrrr perra
# ----
# iter 8000, loss: 30.430157
# ----
#  crm-mo.»--«Meu as do
# E
# nocda, mosm viagom Cacanao, pa, e á aça e nam, vepou para que ol-is da
# lhe
# do para dem do gontrro aro di
# acé co dou, a ecllitave micasmparstrou
# de Niver parão! lhm da No. Na mer
# ----
# iter 8100, loss: 30.172612
# ----
#  não buiso por dem iandá-me aque e, s per u do bames_ om sa; calai aecara
# Cosirdo bolge harom rade e que
# do pura sou cara dinas ouismpestalcaossaita cacaro porsabravimsiláe fa gibuitaquibniz compolgant
# ----
# iter 8200, loss: 29.864225
# ----
#   das de canouira omrigei e dou-me, mes, »isilhe onaenhe
# No; , que doubro, que não cos, para atrroçam
# cusmirá, que a nculhettidafetando b'aquo do pororá, que e
# costas chccacgerou eha no bem
# velao péra
# ----
# iter 8300, loss: 29.634858
# ----
#  om iachitgo vae, ou nãogrmanha
# Cassar tado
# bembrazeu am, aia. denmum ios_ que
# e accara; sencom, que abendo vinse diaqui não, morrospor-me
# te, e es jangentursm esmara adeclom sentres anau dianhocimnigm
# ----
# iter 8400, loss: 29.516543
# ----
#  m lou gom, thestou dou malhodom, posbeiro ellendos-lhe quinnte o abro mas jo cate da Ridalgumrcho porê
# leu. Cum raccinco.-lhenmiam dou-lhe queses cocher quigum dou, para que lho gemhongulho, mestoo Ce
# ----
# iter 8500, loss: 29.228453
# ----
#  ue a melhede verses pe lor, e não que á as de cidaré vem, _ es vicnadiobeido varé races, para antrom Cara serso dana do
# bos ortes anta do! não gontrro aanho émos
# fise de es e se santurendo que portuit
# ----
# iter 8600, loss: 28.976800
# ----
#   Succastava cummitá esfadado mame. douquempom não amui a euncou doelha Canha dou-«Meu peram, vue ermuita co.
# He fapar amminzeunitá, panmo.
# Cazes se não viro. _uangu
# ho Caquio.; ou, fhccrou hadeu, que
# ----
# iter 8700, loss: 28.757856
# ----
#  Ense
# do-me fochoitat:
# U ventimam dechondoums á á acccismelho Rhea menmui nlhe parcorstro povas; deum manhasNlo bos, pocam elgem ma-lo, que
# tenzer que eu o-te filha e elgempaia licabes; Dam cambenteque
# ----
# iter 8800, loss: 28.491755
# ----
#  não querro asitro dianto fulindou da Ceum não gunta smui o veis dia se pera o varéo, deralimete. eu hez nartor que aha, uuz zeruida-te ame tedeu, elainarou da á e o de
# -ão apesi de s cê
# co os. A qui o
# ----
# iter 8900, loss: 28.223553
# ----
#   bou
# de
# aitaram, vuisanão vouto; vinso pasmanhou-mabisseisbem gem, fumuita Scoão , ma sou se fismenlou melco, Cezmoste dou, e conhos não urou facos. A vatao palaos gu com mas nãome; fa bivres, pocmost
# ----
# iter 9000, loss: 27.966271
# ----
#  o; vê
# apostatá alle do comprilhenanrozitne: So- adou vantentos jaccage dontivequi ná a
# do do chabéo. polando
# bou mados- do diamei to dos, elle dou-lhe fimadotanhá amoi mizar se dirolom menho
# -lho dolo
# ----
# iter 9100, loss: 27.659135
# ----
#  cher Cesgo poz esta
# do do E não d'aque ião tonçaverm nho gontenha chvrlviz.
# -Tuiro. A bus não que de que a os vaete. fulheidostra, poreu e me cos natgo.
# Cam re didará e de che, manto mento parso, que
# ----
# iter 9200, loss: 27.372068
# ----
#  ou. Cossenf.
# Nospassoliesos pastedo
# -lho ora, facanto distros Oi, Doma gundo do verta, sósmasse que e endo ques femosteu osminhor cecaitadet, doma; só agos o pera dou, pora senlhe, ostenso focça e fon
# ----
# iter 9300, loss: 27.198058
# ----
#  libelgundo-me o er cida ca ciino dinçades, quendo Contrratado, mas dou zera com
# rom quenze
# de qua ano, á as haço dom
# Ceslim vorsos.
# e buls cada vira do! noctos do
# bol o a amibor diraté dasmirá a atas
# ----
# iter 9400, loss: 26.935809
# ----
#  o tisu ont'iz
# tera oinher no the
# los ae finhet quigo doma; cua es po fur que a tira viraliseitá e tenho Novou de xoso por tivuro pare versofivae ostrapalisse fudassou jentirra d'aqui comor «óe erdo do
# ----
# iter 9500, loss: 26.677245
# ----
#  não, que elle poza hanéo, varacivel es. Susteu dotos: a não
# Engenção, fanas ento, vesterta eum fenhai ao fua..
#
# No aro, dersos ertol omamenhe cuidida cuera, sabé do xattis, e
# fo tivarso, que
# aros.peu
# ----
# iter 9600, loss: 26.477118
# ----
#   melgom
# pequentuiz dá che, peramssenlou vasmurso, e o da civei ana camavis; sou
# caltas vez estarram calbessa dontrom Casmurre; chetgo am ios. A viades; para a es o belculhotrou pazmuss.»e casso, a aca
# ----
# iter 9700, loss: 26.232701
# ----
#  a ca ciostesstrou por via, soutro_ veemostresdo dou-menhaz que a es dis lerros e dou-me tina om da jlhe codoinamentede, mem do fimaros; por uutoui ao selhe dret ue estar lo d'aquinaços os rero, da Nde
# ----
# iter 9800, loss: 25.984552
# ----
#  Tuinurrou para Endos e pormará eu outno tossontenhontos ouallo.»--São vrra colhetesse os pez uuttos perso o. Nab ouinão m dadeu, e que
# dous vurdos losé eo eitrou cadeu, pozarrou otorro, nacara que e v
# ----
# iter 9900, loss: 25.799341
# ----
#  Rhoça tanhabenso para sivro, vae os em nos minha dosmig io, para vira cam-m ia, mirato. _Dom mess pes dos, tiram nadaiccicacontrem va, da faca., smango.
#
# -llom ve, pade sical inha dou, a esa, e acco p
# ----
# iter 10000, loss: 25.644019
# ----
#  ar vienlhe deusinão cuncnttesso. Cacmurrnta éortulhotos. Nonter: «Dom
# Cesso ao.»--«Meu merdo d'aqui nção a mibrio, ilaCéaros ilhe veasanhave, se que não lcidadese matasso esta ios. Nov-mo fulhesonou-s
# ----
# iter 10100, loss: 25.509591
# ----
#   porm
# nou
# melano e teres, dão, menmurra, fadespe sontee poitava canhantora teccontaro eateu, e vedso.
#
# --Já acabou alhas uete
# f-mes; e taros, e veu o Ebgos vers es A -los pazeu.
#
# -lVcabo ea fe fochess
# ----
# iter 10200, loss: 25.407342
# ----
#  om
# Casmurro_ não
# gostenha Napor ae, da go.peosuus accugo.
#
# -llimeças naitava gumigos. Nontor jas vermesilhe
# a menhas com nadeu, Pem: se doram itab que douinhos gom vhemos.
#
# Vi, peracheu ditalicus, dia
# ----
# iter 10300, loss: 25.327787
# ----
#  re. Nencolcinhaná alcunho, dhanlo dazinhopé senão Nuicom racachabolhabulo por estolsoninzetrio, am Rho gemanvo-to-te amm ioté do caqui abos; vem lhabuti em igo. Onmes a ocos dizulhnisse do que e es nã
# ----
# iter 10400, loss: 25.092860
# ----
#  ue o. , quo ende mem do
# Es, pora ibntess dom
# pera e por.
# a bestave salhanhcenho, seroo. E cous a cortisso pova aonre! lhe porará
# enfo fidoro, aliss, sou versosse e jestaesa aalhe melhe entem, e a afit
# ----
# iter 10500, loss: 24.861290
# ----
#   Nondo- e para diundo pade pers sucontes vez os.
# Tudou mallom vingothou Dom mecho ou. eu oss vhemo, não gmar.
#
# enhes ae es e che
# s_ vus, peram iacaiter teu.pes u cuum, paza o estenmom Callis, tessondo
# ----
# iter 10600, loss: 24.662754
# ----
#  Enhobrom masmus a que não calenro
# E; elte douechei sotra não tonboldo! não gundo femsrodesso para seche! «ho
# do-me abesso. O coz ro em cadaitavem, vardostavenlher la melhena pirmez facam d'oque eu ost
# ----
# iter 10700, loss: 24.393094
# ----
#  maro, da
# bantuei uetro dis, dou ro, mas de les, por eibro, qua não que poe a es o vers uidos nhe, portros e por a caré ava, ou
#  no inse tirotro do para setro
# pera daze. _ da fiter pez u-ze-me ou dãom
# ----
# iter 10800, loss: 24.224201
# ----
#  ctossendou pacgontus, vento sos. A viguitto  mem lho vaenantros diacundo-Cessentou-mengonhostom Casmurra verdo-ê.»i cuu deça doço, s vuutolam cazeu, ma murrotte fara e que
# doutro. O zeu. _ do gralo.
#
#
# ----
# iter 10900, loss: 24.132560
# ----
#  o denhongossonfunha, chá, dos-lhe a tirarão pos: «Dom
# Cameis.
# _ do chcinte ontassou, a muegou camamos da
# citaf deu, para a conter vo-no
# do
# ara cara o
# Engo tidadou; douta; dou cassorra; smuivou pada, o
# ----
# iter 11000, loss: 23.863565
# ----
#  de não lão bulha e tingo.
#
# --Já
# genho Nontida lho
# dos routrou vee o viraré zirro, que a os meita. Coss; do bales, Nuvideis de aio pera o es e fermes mos e entideto do
# Enhe onte
# de da leu fenfo, para e
# ----
# iter 11100, loss: 23.722369
# ----
#  ou seu fa cormissou mes s desta zalde fanasrou am role  ultiss.
# do canzetro tera ourre, cara senso dasminha lantave datalo borsonta; quera; versos em não norará
# rontresse de que come. e deu, vhetes: q
# ----
# iter 11200, loss: 23.675954
# ----
#  me Cussom da
# cidades paitao a mes do catacoquennou
# caquino nraper eina soniam Cassar lom iape caquinzanzou da
# mem da
# coches qua e que do badada Dom
# Tuzel ndo-me junda, dou com im, dou-lhe a calconhapa
# ----
# iter 11300, loss: 23.493652
# ----
#  o titulcuutro, dão gentá, qua não cuis Caquitros, tudi Penhopéos de
# lhesro, tis, que mortre ficusso a lhei lesso. Cantidota, olidotrrapou eu cão.»---ão pera ou sóas isse se do e tersda lhe zerou deu,
# ----
# iter 11400, loss: 23.222687
# ----
#  não alão tera; anabeso dos, e aenhe mam no, sacê.»ó genha Nos omare es e muuçou jarsou janto Camae eu cidaréos.
#
# Umabas: e tivar outreVialo do Cote euma dou seum que não tenho  eitrou mez ze por into
# ----
# iter 11500, loss: 23.058458
# ----
#   jundeates; mom cacasso-minos ou veisro.
#
# --Já apenvara guz docgusta camanha ago. do que em não amicalcos pera nãos-moça, am nar es do ram igro dasmurro, que mu-tio finhen fe ltrouro. e verso, mema _e
# ----
# iter 11600, loss: 22.879920
# ----
#  dou malho-le
# do por erdesto; eu per trdo, malho o verço, der-lhe fara sens para para para.pNr não bra, mus pera dia fentro, dou-lhe chetá eu outra; chá a murto; que elle dou dão, de. os elae fuação a
# ----
# iter 11700, loss: 22.684419
# ----
#  -São muitresraos ae, dessensontoulfes e possos_ A vidouça
# conterso _meituo vuedosso.
#
# --Contida
# é versondo que
#  ouira
# -lhe chabessou mallenfuranteuro por es e que em secaro ará eu de que
# porsmui erro
# ----
# iter 11800, loss: 22.454987
# ----
#  Rhocos, poz vuetes as o senha, goss se não vo! tara valgoz
#
#
# que a ou vara milhos da
# lus; tenhanto, de qupo, e ve, e camor. No. No sente massa avos ou da fimatas a calao para Pem, tussos veano virabos
# ----
# iter 11900, loss: 22.250382
# ----
#  que a es de lhe doibuitus au feubos, que e abou alha tade cos diabcisgo dou meuto; versosita
# é de se e tira
# cor vio vuegondos, _ e lhe
# dou caquenzo do que atos. Cum ilou a cho, e e dom de thaslão que
# ----
# iter 12000, loss: 22.004033
# ----
#   vers retass piratá
# am ne tra
# da tadeus am, elvenhetiro e aenho Novo, pare senfança
# no dontesmos
# cacosi uecheros dacido tro-io e terero; alcuns de lissenda Cestru-mermae fora.»--«Vou parada
# Co d'aqui
# ----
# iter 12100, loss: 21.836964
# ----
#  omir do ainha murrou dicclou para querou casmes do filhe por isse calada geum sende que
# alles do Rherdou não zeu diam esso doui secade pou sópados eutro romprisseleu, Dom
# Cos p
# cgo. Coss a mes a seu m
# ----
# iter 12200, loss: 21.716463
# ----
#  lhe lus a chá com ques ficanituingenhorimoitro
# pantou va; a combenso dontas o meihorilhe fam iotosss; a comti a calgomsrá
# allideto, paranr elheq voro de quos o bontro, e a chão vaz zenfivarsos, que
# so
# ----
# iter 12300, loss: 21.591601
# ----
#  ue a eundo que
#  liranão pera o Engenho Nontre am nado d'alli.
# Cosparé que não Contrrapé sança
# Nos recaro padso, persos endes, Nense do lem, felada mintrendo Engenho, que enta simira em Castide
# E nou s
# ----
# iter 12400, loss: 21.435894
# ----
#   Coztra amuinte nabrasstrou paz uusos
#  emasmuinou da lis asse mesmes
# o; om mem ro binçou ja daposso veas pegempege lhe do tana dottido, aa bessou meu deunm nlão valinsondos o pazendesm do bou dosmes v
# ----
# iter 12500, loss: 21.297629
# ----
#  Enho da
# lls grala, ente se pochoze de chccos elsenhandos, Dom deste á colcodo
# E asma cazelcumolhã; hem parapa sess; felheta.»
# ---JM am chá afinasmo.
# dostue a euale. A vram que não lhe a ve dão verdos
# ----
# iter 12600, loss: 21.081206
# ----
#  nso d'aquino; vêra ma cammerou em nou mas no que
# enve dos, e
# aro Dom-Tuss; vee ostrra não, de que doise menho Nove, para dazes o dertro pare dirro, que afibuido; seaseu que doitae que
# afinalgos. _ vo
# ----
# iter 12700, loss: 21.159878
# ----
#  , fabues que
# dosbalhe, sempeges o amira; que
# a os melhem nhablhe coubatá aqus nho buades, versos.
# T euto pegettos, que el-uro para a es e falaima dos micheitue aCas ou detos. fumaro
# esbos do
# bomprr-ls
# ----
# iter 12800, loss: 20.990168
# ----
#  o, nlhe de
# lou deccuisse. pegom
#
# adiussor hom dadgra es a canmurropé a taro, da
# cuituis, ea cissa com taquinão mimapé aclhacou; qua
# do por viccer pe, es, destavau ese de que ua não visa; só nanda
# por
# ----
# iter 12900, loss: 20.703349
# ----
#  beter; disser «Domas., e ou pera e
# coss uros a cinae a estov ra eia da eitere querntitros atá afenauiro
# idão fuitrouinão calel; tena. o trom Casmuit.e doitaro, ta, sortro, que a es e do same ao dealo
# ----
# iter 13000, loss: 20.505590
# ----
#  ou chos pez uu, e es versos o. Nuoro, entaes ;
# tou vees estarstrou eu, de nostas: oo o veltinho, para a menhardoz não lhe, pe, dis, _Dom Ca lia, e por.
# Ense denmitro péme vua, e es o bol oz
# caques cas
# ----
# iter 13100, loss: 20.499776
# ----
#  me, de
# fidada cissa cavei, doma; ser es ense dão, da thor os e hara por essuu. so pada; amareda manha do e menhopabousi elgom
# Cas da civar ou da xis da Rno que lhete e com Dengo hancantitsio, tado por
# ----
# iter 13200, loss: 20.410424
# ----
#  o titulo.
#
#
# es s; viro o date.»
#  Cachei os atcurro, não lue los. Ce cão von
# es nom Tamaro per que ou de es e a om se que e es heinão aminhe
# elgentincamim tadeu, povas; por que apes aemllhe e ou o ea e
# ----
# iter 13300, loss: 20.402993
# ----
#  nado, falado vichotremsmasa ties betrouiCedo poross dentrdom Castro.
#
# Uma massou oa vavarmaliese ae deum não mulheitavou pada boum mettes e de tenhar lo dou-meu deunão icou deao do pontros mettouta
# bo
# ----
# iter 13400, loss: 20.315441
# ----
#   passou
# ca, pera de som fa lua a mirmor peccac um fisur dem, vê quis, em na Nos que apas a; chis, e mem vicaccontom reme dongem calae por isso siver outro im e do e ae cuncitano, mim, falaos nicccom m
# ----
# iter 13500, loss: 20.086709
# ----
#  tras a esse em ficheis; a co do-me a entrr-meitno. Cazer ougo.»
# ---ão les smentu didaccur te aonous a cesmoninno da cidetem ilte smue A paros; felher lo bassou para Petro
#  que não pontarão penta dou z
# ----
# iter 13600, loss: 19.840896
# ----
#  -Já amicar ou vóetou entiraroo ho-ês
# euterro, porémssaro e fontenhobingenhã; raqueo pera seuxa ou vuesoue do gustar compei am par ou
# dostis da linheçanio vestai o dastiral-mi arogesso dospor queu oete
# ----
# iter 13700, loss: 19.628076
# ----
#  Nhe dou, a doum sá am
# mantenE , muita; a caimasitue do ram_ a ac-me tas-lhe que
# antave som nivalcunze facaná apesia velgom val ese e
# não Nonseltes, e calanmulhença, radeasmuninte douço, do sam mas do
# ----
# iter 13800, loss: 19.458426
# ----
#  os.p---fe deum da
# cidarão.
# Cos mem não luese pé ssmcincelaos trou camor alcunsdo-ge honi de mam visgo. No co.
#
# -lhu rãoma hão vastao fulhete. do a mique do pado , pou dosmanão Nuabade
# por vichai u var
# ----
# iter 13900, loss: 19.220807
# ----
#   casel-mema; de
# fonheço para que no belhe ficalgostara e mala mam mume de que
# amitavedo tiro, para di-meé se sapelgonter uide contesso. ficae do
# camamis.
# --ão mer que
# zeido.
#
# --Já acacaquitro-te am ra
# ----
# iter 14000, loss: 19.228197
# ----
#  om Cas no que no entas Dom Cam is, malhe
# Coze versoss ná a este
#  qua e mulhenho i oinou falhetoni ze para que no viraqui opéos gum camaestes ou-mefos. tuus nolgom
# Casesse
# do digum Castuos.
#
# Uma no dem
# ----
# iter 14100, loss: 19.258797
# ----
#  nho Coze.»---ão amis deuslouigue o Emgetá algolher lidetá am callcom lhetá as de dou do luaçaperiam Casmuros_ imanhe a ccnzetá á ache lheia ouim entaenhe Tuidou da lua noz cara mam ihor para que não f
# ----
# iter 14200, loss: 19.057829
# ----
#  ue muinão iãa che
# doi meinão amitro em rade, parsostes ou-me-Cose tenhopé e lhe Cazar outos, voemus a
# cos. e acabes, eu. Coz iiinão que do cantetro
# Eonter iicaro
#  eitue, memsitom versondo tana.»
# U qua
# ----
# iter 14300, loss: 18.863393
# ----
#   Negu do-me diacê henhor aata sou vardos da livro, que não mesmes a musça eusstrra não veuso a eitaro. fitave quannaeifuitavsa, uuá no a mue uiccidarm smas o doitueros pazeu; sou da lhabrou parao feth
# ----
# iter 14400, loss: 18.727622
# ----
#  tras a canhané o dolhem
# Caslissa me manho Novo dom menhané te são, casa com a
# c-ma guchare a colte , ma do que a coutá
# cquinndeta.»
# do para diam mulhe o virol-lhe de dou mechonam rades, que z_m, dou-l
# ----
# iter 14500, loss: 18.495997
# ----
#  noro dos, a es e cheta ionhe, camess; e meito do, memmdi
# pera. Culai a; que
# afigos. _Cabmirido por pados _ e qua
# não nolou versos ou via cor
# coda v
# cabuido
#
# de se tenha
# fomperou sachontrapabe de eiter
# ----
# iter 14600, loss: 18.317817
# ----
#  s, tor. vezço
# te tiratrou que so tou, do a mas se coa falmor euleitave quer-minho, fusaos.
# _ que não, qua
# dostava
# Suer
# heixasé be para sem, a será aquo
# dos oitequiso ise
#
# bUmu do paro elle para a
# mo.
#
# ----
# iter 14700, loss: 18.300791
# ----
#  o_ não Caalá docbos. _Casmurro, nado, dersde
# lhe
# e mes. fonheitro juntrom busses.
# do par naté nobbita; rhonana mirá ndo dou-lhe ontenzendou-fe,. A vinha
# doitaversontrom ihados mençadeinhes lhetá abass
# ----
# iter 14800, loss: 18.238817
# ----
#   es e as caquino, nãosl; arob iro. _Dom Casmurro, não civalgosta cos. Nm curá e quenzorra deste não virnço C'allirrticadea, para dirrao onaqui eu da lesse eu deus algo taram para di
# nloum verango has
# ----
# iter 14900, loss: 18.146639
# ----
#  ou vezé o
# telae anoutrão Ceam do
# bolinzesra
# dom vesto. fuit:os e de sançapa cidade
# porrro doz
# do; mezentuerfoço.»
# quinzo da lná lhetussos póccordontcido
# Ebuerou par asta eater codera em dides, fuccis,
# ----
# iter 15000, loss: 17.957803
# ----
#  lhe camanho se do darmis cacada; am da
# cidapé vam om
# não gueca. No, vue ancolhede dizes deça.»
#
# Não cosserá aconinzendincindos e ques, paros vaena e dos, Neiso iz deaa dochet peram-se accondos mechina
# ----
# iter 15100, loss: 17.757925
# ----
#  o tit-lhe o viro do porm
# le, a os pura casse do por elheitarou versom Tuslo
#  Os ainaena dingonho
# mestas aeino  unte cacuideu lão.
#
# --Já ango, do liversou póde não amimei ue finae por isso bia, da
# buis
# ----
# iter 15200, loss: 17.508748
# ----
#  não, fante
# navingendo-me dou-mentou-felao drrmirolo d'aque apoz aqui no çontendo-me _Donhuninse dertes, seisou oaraitiratrou quidoçachor vicalco hasso do tue, deusda
# ettem, e di que
# á is, mura éurou;
# ----
# iter 15300, loss: 17.378539
# ----
#   para dé e miam nso, e de che, para Petro da cuamigossou ol; a minhatro anoa diapa aalho, sous vei. do o vassos enso
# Dos Tu-lo i-me a aças om da lua a es com vassou chos habol; teram da chavea; s clqu
# ----
# iter 15400, loss: 17.238615
# ----
#  a esteque
# do bulrom, vuas não, Tuitue a matrs demelhe fuss pos nado didesso tita, deaça, cem com rotuigu didoss heça viua dou da lis, facuns citas avo, e se fidas no que não hontrem mem do co.p
# Casmir
# ----
# iter 15500, loss: 17.064437
# ----
#  le Ha oss veuse dou por ress
# ballo bammes o bos. e asmirrrona deus outre-lanio; elas u que
# do bamminde samantueitaverfacars
# bos. tesseisa dou-s. Nomo.
# de los es los arou e o, que não
# vos, dou-lhe camo
# ----
# iter 15600, loss: 16.904877
# ----
#  Rlem se, que
# alcunsbom veitae taveina, e o do vasmanão que
# afigusso, se dasmira as, eutfimus cuma mormastas am dasmurro, que
# apeu. voe por am lasmesso C'aqllo possa culanmam mem va
# com pez inta
# ião au
# ----
# iter 15700, loss: 16.735447
# ----
#  os.
# E com pequi do brentavea, da lua a abos em do, não amasmastou jando caminha não loutro par urto, vê nam va
# cul nda Rheitroa pera de charo Petro vasmas ve da mua dalgom
# cesso se ada
# for ta
# a care a
# ----
# iter 15800, loss: 16.585224
# ----
#  utou-se lendo-me deuça e nitndo para a es._
# ssarotesa fisuidã
#  esse mia es, desso a nãoi jentá
# aqui no não
# angenho
# No.
# N-Taque o triminheifideitá am nado, e elfe furose dos meça deulgostou eu, versos.
# ----
# iter 15900, loss: 16.568554
# ----
#  om
# Casmurro, busses a cammemangom
# bussou visse eu cida
# cossendo dou paz incom dom, permasinue mam, fem que no dou das no dou-se les a coss panaou
# vecCoz
# do bosse de saccinho gundo; napal ueshoça quena
# ----
# iter 16000, loss: 16.539682
# ----
#  s lecharou per iz lhe os darmurro paze da livirsos, teme hengui não lessaquigo, vo, seu do gullhe
# domtrou mechananasta colhei melhei com seu casmos. No diralgo.
#
# --Contenhã; nochonçostam guma hapé ast
# ----
# iter 16100, loss: 16.423659
# ----
#  ue am não covor outros fisou. Nodará Contrecinheitao fura a es es que a cuisou se este
# noléos e eu; de que não lheinão Novo accentes. Com
# p-ccidacolara culaito
# do cero dottis, e para a es._ setrou mem
# ----
# iter 16200, loss: 16.398665
# ----
#   Engenho Nalco veifaveu, por Domes; pos. Aancallu falhe zeu, fonarro, thet o mesmomme se pazeu, vae lhom disme tem, do, e menhe, não estensou qua
# do paras de que no bulondo que e ma cidades mentrom pa
# ----
# iter 16300, loss: 16.285197
# ----
#  e colfonhor quenloiinze e melhes le
# dos mem não mulhe
# á a Do.
#
# --Já acarãos eiter te segonho Novo, e cenhe
# dos, dou manho á eu cou póda que não Cémsitá
# aqui do dae com, dou-midom de consolhedem que
# do
# ----
# iter 16400, loss: 16.068319
# ----
#  lheço dentres a a aça, chete dimenho, secho diaveu; do--«he cusrrrs nhirrremmiges do gis de mims.
# de fituros ou per.
# E courf
# com nidel; por iram nhe o dicusro
# tilgo do lcapaliunão fidos segotro balcon
# ----
# iter 16500, loss: 15.915620
# ----
#  s marando-mo distrocpoz nha não taquindo buum a camarotesso Dom
# Tura sou. A vua, mempans não fasmurro poze o dontos para que ades o
# bouso do varsaro
#
# Nom alcunge dos, veis. Centou per uuro; elco.
#
# --S
# ----
# iter 16600, loss: 15.823030
# ----
#  o, dochoi es peigusro
# Dompandou valgo.
#
# --JVdecam dom, vuas na
# figuidou cacgesto; estava cungo menho Nmenfochiinhongonha não lessos. A vinhetá alcunha e verdostalcam cam ra costa cos rochegos, Nensou
# ----
# iter 16700, loss: 15.882022
# ----
#  para thero, falae porará
# com vesto. vuis no bem ro, mar demuihão fitaré gom Castida ente didrao diralou. fona e verdosá anio, da bua e o tra
# do que lhe cDos .
# bomprr-me cuns cada, femer de pos pera do
# ----
# iter 16800, loss: 15.931495
# ----
#  ou pareue
# do
# beam deas nsté a tiversos uicgom, veesou para Peir.
# _--«Meuto; verdos mestes qua abos. Oa ostro e tirutrou o porninto a zerrapasso isse cara atrse
# eu; se fulgimei-feilhe poz outra, que
# af
# ----
# iter 16900, loss: 16.020125
# ----
#  mes de
# bolhanao.
#
# Vis .
# Celpo. Culandos ados mendo mam, do-mo oss
# n-le dantor-tá achadou, versa, ou; a co. Caclirapéos vuatou vardos
#  eccaras que apendou-ná acical iamentoeme do gama.
#
# Via getminha Ca
# ----
# iter 17000, loss: 15.881206
# ----
#  o titulo tirade, nho, dizedou
#  não e alcunha dão vosseros a cara ouirá anao do lhaigus, dão licclhe didsm ião a didaro querá iste sento ou veis dealssegro os ero doço.; entrem, que gostros, por iro oi
# ----
# iter 17100, loss: 15.806481
# ----
#  ra es. No tiraté, ou pade da cider-_ ou alonou; veesonia; versor  uenheilae que
# poibuide
# quiontu-me senste darlho ro, pêralgeu.
# _-mina ei oninze diros duimintres a ccinor.
# EN; aleço, e vilhansso do qu
# ----
# iter 17200, loss: 15.811516
# ----
#   heros, fe hanou paz ou para a fochet quigo, a ou varmes. _ es e dou meçça, que não, entres alcunido quengou. a cuitro, á anloe focfivei, dou-lhe cam para Petou olhe dae, _ veas vim ense do C'aquo am
# ----
# iter 17300, loss: 15.692623
# ----
#  te zeusra. Ha cirdos, que não gesso. Comesse ou emibas nompo. _ ve que e mulhe
# folae oo farotro.
#
# --Já algo tes cumor de que lhe dão lua ados motido
# -lhe ciicei o sou per mutti; vêralhe smuir; anconha
# ----
# iter 17400, loss: 15.698070
# ----
#  -Já acabeitavoos a com recgo.
#
# -leito
# do pou janter ou elconsendo que
# o tento biberão e tera vero se derori o denan ettre
# a terminapaze Cas do para bido
# boumr---«Meus velgenharicheitcom Casmc'aque oro
# ----
# iter 17500, loss: 15.571290
# ----
#  challueta domimitze jundasmira
# »-sso  nabotrou que
# do vivtongem nottom, que e tarotrou vaqui do balaita os jazem, que do gimaro e a ca não Nodo, am_ doimem locita
# é-sa os, fonholinsenha, para diss em-
# ----
# iter 17600, loss: 15.478750
# ----
#  lhetá am de
# lou pequio.»
# ze espol e doum naquitnveetlls alcunho da
# ciders_ ichei. e nass poc iza_ pelao. No tidou para a costado, mem de lichero; vê cumo fiditrom Casapos as não lhe não lhe
# dos, dou-l
# ----
# iter 17700, loss: 15.345394
# ----
#   vintro, mossemenhe não fantinitolando
# mirntr cimaro er ontrecdotosso ostava corra, ques cichesto anzentão
# golheitarou jaque o metçadi
# ndetro doste melheçondoste ono, e
# veri ettra coitrra e af nostra
# ----
# iter 17800, loss: 15.231194
# ----
#  om Succadou, veesa, dompagoum verso.
#
# --Já acabansuntendo e tiral-me tau de livro, param tes de viccocaos.
#
# Casmuarou pada camanho Novo, e para eme doum desso a ou dos, que alcu não am indo guas.
#
# o,
# ----
# iter 17900, loss: 15.113269
# ----
#  s. e menha
# com chá e caladé quenz nho entrobiam cussa es hão -habimos _Dom Casmuira
# é-stor viabciiapé a
# mo ho posso do! fimues. e matri allunhapé a tida
# cordom Tasmiiá douitade mochidou pado pazeum fe
# ----
# iter 18000, loss: 15.077092
# ----
#  ue a e louirão deuso de do para e melhei lo boli.; cemtros, e do voss dom iuapéo.
# --«ede deixase veche
# Nova caro perss, e
# de chabra dortre
# a os ssanão
# ingelhenlo, a es peimanco, versos. A vidou rapa,
# ----
# iter 18100, loss: 14.974734
# ----
#   e matonsol_ou mallidou emundo Contor vapaos.
#
# Cos memuehoçacau di--Jão Ceulmu-lo, ; mendo meum nocê.»e cuis, e vilavminho
# guituis, vea, da lua e
# dostoe em rezes. mugo.
#
# --Já acasioste chssado, a no v
# ----
# iter 18200, loss: 14.882209
# ----
#  do dasmira eu deam pada Po. A vamcinho dou-me, senteça noccom
# dos lou doa, dãosama, dos zeças as a callo.
#
# --Já acása Dom
# naz cosse do gulconho  uitrou par asta, alcunstom casmurdo; hacou dou-lhbémiin
# ----
# iter 18300, loss: 14.703887
# ----
#  não
# ton. Ennoui ueccoz O cos. A paro e fular ardosso Engenho, que e es e sens uara, me hou mes na
# No.
#
# Viccrro; vê cumo dou-fe Cuntro, que entero, melhades dos losiapeninse de sanrou da
# cidão çode dou
# ----
# iter 18400, loss: 14.505131
# ----
#  sta caro gom para Petro. Casmuira No.
#
# --se vou outru-mesta. e aocher me dia, deu-lhe atrs
# de tiospo menhor mitade que apenas terão isso do que
# não doze muaro_ vessou, e malheifur que a eunho Noso tem
# ----
# iter 18500, loss: 14.364090
# ----
#  o, não amer nompossem da civai alcunse mam didacando.
#
# --Co permuedos manhos
#  qui.n-u carapersa cae thapdo-me acacaccis veituiratéo.
# Nendou
# callesta aasso dotri conso.
#
# -lho. Co cenho Noccentressom ma
# ----
# iter 18600, loss: 14.346404
# ----
#  bondo o meta.»
# , calao haitas atáinte mouso pos esse para para se dão telle pora tesa virro.p
# U com mem ião tonboutitevero fiitodi
# , para se do para ates o bitá sonifum dem do que
# . Ha mis quennoutos,
# ----
# iter 18700, loss: 14.218065
# ----
#  etitor rassaria; se zeçhal-Te euco.
#
# --São muitor iste senmerro, masso.
#
# --Já acasa e veitava
# conisteu da lis
# l-ão doutra, cumienteitrem, que eu co.
#
# ---Cou paz uutourou elle.»
#
# qui no deução Coze de
# ----
# iter 18800, loss: 14.090876
# ----
#  lhe casmanha musse dontra, parmirades, que
# não
# gosseros o
#
# decpo-me cava camigo.»
# com para Petro, que
# anControu da lisse serso diaperra éonte, da não gulis, _hes. queralcunido quer pe, se do dom ra
# an
# ----
# iter 18900, loss: 14.006000
# ----
#  o titalo.
#
# Uma noi. Conarão ammigu; fechai ordalgom lhoça ddas qua não
# ê. e cosse marou da tida
# fo fidas o.
# Casmurro, derabouit-es pe, ram cudo do viadeu, para a
# elles lho da civar ou. _ volhoça que
# a
# ----
# iter 19000, loss: 13.952549
# ----
#  iospoiiu; alou 'ado pé al_cou pódess da fuqui no apas senheveralcurs
# endo o para seus. Succuri era, e e meito; e cavei, não gema; a ocosiou nicarou il_Cazeu; tenso disso dinantram esso mirá e louir; a
# ----
# iter 19100, loss: 13.902287
# ----
#   ha e por antura era vassou matans que acabou as, dua, diralcurro cunh, e vissa, cues demorá aqui ná algem pasa Dom
# Casmurro_ para ra
# gesto Dom Casmenha dos Domperstul os pa cazentedo que alaso para a
# ----
# iter 19200, loss: 13.778679
# ----
#  tida costa caloutrasia. No.. fe lhe do bulss em verso, dom caccanou cão pontar chmmi ao cinse o dirors, temsr palsenta, que apé om, te fozero, são, pozmom ver uichom megusso, a ccvro, s deum do a mitr
# ----
# iter 19300, loss: 13.713311
# ----
#  -Contira
# corá
# --meurropé a lhei uesteus outrr-le eonto dos lhonãosimoçará versos. vo chirno aque apes o toss no não.
# O cos. A vianouir-fe asmas de lze e eu teze que e es.»--«Vou póda serso do! Casmurr
# ----
# iter 19400, loss: 13.652954
# ----
#  chmsro
# Sentres, que
# apendo!
# calao rapanins as, do
# ta ou da gontas, seu, por ia lgo, pade que
# ao. Nom radas, que a eu diag es., cabes a caroui ao fidouir»
# encura nãrsininzea meitue am razeu, tural-mi a
# ----
# iter 19500, loss: 13.602099
# ----
#  estula mol u chá, dão, nho, para dou doutras aó, do a ns al u titado, manho, buro calao fusuiha cuzilheigusse eu cinhetrou
# f- e vizados muça, e es hetá a lhitásinmicuuccos, mam não roulcurá a ccizel u
# ----
# iter 19600, loss: 13.556842
# ----
#
# bos. NCazeu, dou-lhe clá alas a calheço veutes de não voze dismino pog do que lhe que
# elConara mitre
# do; estrom verdo, dos-lhe ques qua om mes do Cintetra, que Pperammingo vou esse ccinor enté o vra
# ----
# iter 19700, loss: 13.706458
# ----
#  o dorá elgenhosimottra cida
# dos me, de scanlorigá
# cá as .
# E chm, fonhendo-me boldo gemporaraa..
# --«Vou pera por asta; cestavo, e colheta.
# --«he chmmro«Dom Casmurro; am ige aos.
#
# Cesmulda cidados, que
# ----
# iter 19800, loss: 13.722184
# ----
#  s ae hezenhelse lcarale dou-me, semu ho pos ou dochorom naque a culconhapé a lhe
# ...
#
# Nou mem nho, dosbanda civetr
# ----
# iter 818100, loss: 0.100805
# ----
#  comsigo. _Dom_ veiu por ironia, para attribuir-me fumos de fidalgo.
# Tudo por estar cochilando! Tambem não achei melhor titulo para a minha
# narração; s vazes; vindo da cidade, e elcunhaça esta dames o
# ----
# iter 818200, loss: 0.100165
# ----
#  lou da lua e
# dos ministrou que a os vae este
# mesmanda cidados fissou que eu cido, semsens ná allo dos losir ve as alou distra Cez o aa dis
# l-me hada uiante mus  uinte ramiguss a cos, pódsou pai com ca
# ----
# iter 818300, loss: 0.099627
# ----
#  s meus habitos reclusos e calados, deram curso á alcunha, que
# afinal pegou. Nem por isso me zanguei. Contei a anecdota aos amigos da
# cidade, e elles, por graça, chamam-me assim, alguns em bilhetes: «D
# ----
# iter 818400, loss: 0.099035
# ----
#  o_ não está aqui no sentido que
# elles lhe dão, mas no que lhe poz o vulgo de homem calado e mettido
# comsigo. _Dom_ veiu pod alos; senzea coutro da cidade, fichccommem disse doss estando
# co.»--«Meu car
# ----
# iter 818500, loss: 0.098435
# ----
#  paz aqui do bairro, que eu conheço de vista e
# de chapéo. Comprimentou-me, sentou-se ao pé de mim, falou da lua e
# dos ministros, e acabou recitando-me versos. A viagem era curta, e os
# versos póde ser q
# ----
# iter 818600, loss: 0.097965
# ----
#  ou a dizer de mim nomes
# feios, e acabou alcunhando-me _Dom Casmurro._ Os visinhos, que não
# gostam dos meus habitos reclusos e calados, deram curso á alcunha, que
# afinal pegou. Nem por isso me zanguei.
# ----
# iter 818700, loss: 0.097361
# ----
#  lhe camarote, dou-lhe chá, dou-lhe cama; só não lhe
# dou moça.»
#
# Não consultes diccionarios. _Casmurro_ não está aqui no sentido que
# elles lhe dão, mas no que lhe poz o vulgo de homem calado e mettido
#
# ----
# iter 818800, loss: 0.096879
# ----
#  o titulo.
#
# Uma noite destas, vindo da cida, Dos, que não que não lhe guardo rancou. Nem por isso me zanguei. Contei a anecdota aos amigos da
# cidade, e elles, por graça, chamam-me assim, alguns em bilh
# ----
# iter 818900, loss: 0.096271
# ----
#  gesto para tirmerangem nacéo. Ha livros que apenitro. Netno mam nostrompegem bosso do grou do o eu. Commiro; sechei av rado para oitrom mas nona e distrom_ vel, duas fase de minhe não lhe
# a com gesho.
# ----
# iter 819000, loss: 0.095883
# ----
#   caro Dom
# Casmurro, não cuide que o dispenso do theatro amanhã; venha e dormirá
# aqui na cidade; dou-lhe camarote, dou-lhe chá, dou-lhe camaro e mua do
# co.»
#
# é co de lgo dasmirro douri
# pente
#  ou distro
# ----
# iter 819100, loss: 0.095377
# ----
#  do o titulo seu, poderá cuidar que a obra
# é sua. Ha livros que apenas terão isso dos seus autores; a não
# belse ves os, parao.
# em estava a merro._Casta cumonte a vintido quen; velhoççroç el e conhatito
# ----
# iter 819200, loss: 0.094940
# ----
#  -Continue, disse eu accordando.
#
# --Já acabei, murmurou elle.
#
# --São muito bonitos.
#
# Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou
# do gesto; estava amuado. No dia seguinte entr
# ----
# iter 819300, loss: 0.094507
# ----
#  Rhenania; vê se deixas essa caverna do
# Engenho Novo, e vae lá passa, e
# com rom-nacaro, famer peituero; a ou ia cnssrou qua
# dol-se les; vie, pare Petropolis, Dom
# Casmurro; a casa é a mesma da Rhenania;
# ----
# iter 819400, loss: 0.094029
# ----
#  este
# mesmo. O meu poeta do trem ficará sabendo que não lhe guardo rancor.
# E com pequeno esforço, sendo o titulo seu, poderá cuidar que a obra
# é sua. Ha livros que apenas terão isso dos seus autores; a
# ----
# iter 819500, loss: 0.093711
# ----
#  u quatro vezes; tanto
# bastou para que elle interrompesse a leitura e mettesse os versos no
# bolso.
#
# --Continue, disse eu accordando.
#
# --Já acabei, murmurou elle.
#
# --São muito bonitos.
#
# Vi-lhe fazer um
# ----
# iter 819600, loss: 0.093254
# ----
#  om
# Casmurro, domingo vou jantar com você.»--«Vou para Petropolis, Dom
# Casmurro; a casa é a mesma da Rhenania; vê se deixas essa caverna do
# Engenho Novo, e vae lá passar uns quinze dias commigo.»--«Meu
# ----
# iter 819700, loss: 0.092883
# ----
#  m não achei melhor titulo para a minha
# narração; se não tiver outro d'aqui até ao fim do livro, vae este
# mesmo. O meu poeta do trem ficará sabendo que não lhe guardo rancor.
# E com pequeno esforço, sen
# ----
# iter 819800, loss: 0.092530
# ----
#  ue não fossem inteiramente maus. Succedeu, porém, que
# como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto
# bastou para que elle interrompesse a leitura e mettesse os versos no
# bolso.
#
# -
# ----
# iter 819900, loss: 0.092135
# ----
#   Contei a anecdota aos amigos da
# cidade, e elles, por graça, chamam-me assim, alguns em bilhetes: «Dom
# Casmurro, domingo vou jantar com você.»--«Vou para Petropolis, Dom
# Casmurro; a casa é a mesma da
# ----
# iter 820000, loss: 0.091767
# ----
#  comsigo. _Dom_ veiu por ironia, para attribuir-me fumos de fidalgo.
# Tudo por estar cochilando! Tambem não achei melhor titulo para a minha
# narração; se não tiver outro d'aqui até ao fim do livro, vae
# ----
# iter 820100, loss: 0.091368
# ----
#  lou da lua e
# dos ministros, e acabou recitando-me versos. A viagem era curta, e os
# versos póde ser que não fossem inteiramente maus. Succedeu, porém, que
# como eu estava cançado, fechei os olhos tres o
# ----
# iter 820200, loss: 0.091121
# ----
#  u pasm Pete do vida lhe
# l_cirassoutii a; se nas que ao diattor per ou o Engenho tovor essentoe em, tras e es ana eiloe e camaresente a cunse a casserra didor-lho fima; se a conhaçou do bam raparo, ver
# ----
# iter 820300, loss: 0.090786
# ----
#  o_ não está aqui no sentido que
# elles lhe dão, mas no que lhe poz o vulgo de homem calado e mettido
# comsigo. _Dom_ veiu por ironia, para ata, para ottei or rapesseu cirnos, A visso dos
# Tumbom ia, poré
# ----
# iter 820400, loss: 0.090424
# ----
#  paz aqui do bairro, que eu conheço de vista e
# de chapéo. Comprimentou-me, sentou-se ao pé de mim, falou da lua e
# dos ministros, e acabou recitando-me versos. A viagem era curta, e os
# versos póde ser q
# ----
# iter 820500, loss: 0.090208
# ----
#  ou a dizer de mim nomes
# feios, e acabou alcunhando-me _Dom Casmurro._ Os visinhos, que não
# gostam doitros, e a que lhei melao dasmir tiratá alcueha
# dos, e valgo.
# Canao.
#
# Vde geutrisse saldi
# pel-metapé
# ----
# iter 820600, loss: 0.089886
# ----
#  lhe camarote, dou-lhe chá, dou-lhe cama; só não lhe
# dou moça.»
#
# Não consultes diccionarios. _Casmurro_ não está aqui no sentido que
# elles lhe dão, mas no que lhe foccinas ou-se do! não mirmiro. Nos, m
# ----
# iter 820700, loss: 0.089592
# ----
#  o titulo.
#
# Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no
# trem da Central um rapaz aqui do bairro, que eu conheço de vista e
# de chapéo. Comprimentou-me, sentou-se ao pé de mim, fa
# ----
# iter 820800, loss: 0.089233
# ----
#  gesto para tiral-os outra vez do bolso, mas não passou
# do gesto; estava amuado. No dia seguinte entrou a dizer de mim nomes
# feios, e acabou alcunhando-me _Dom Casmurro._ Os visinhos, que não
# gostam do
# ----
# iter 820900, loss: 0.089057
# ----
#   caro Dom
# Casmurro, não cuide que o dispenso do theatro amanhã; venha e dormirá
# aqui na cidade; dou-lhe camarote, dou-lhe chá, dou-lhe cama; só não lhe
# dou moça.»
#
# Não consultes diccionarios. _Casmurr
# ----
# iter 821000, loss: 0.088729
# ----
#  do o titulo seu, poderá cuidar que a obra
# é sua. Ha livros que apenas terão isso dos seus autores; a calcinheço do pistu anconzessados e verdo d'aqui ntos eu cimpdosm e asmor
# do guadiapé ialheça oo.
#
#
# ----
# iter 821100, loss: 0.088502
# ----
#  -Continue, disse eu accordando.
#
# --Já acabei, murmurou ellesse calados, deram curso á allo çave domes
# cecar do palgoui.»--«Meu caro Dom
# Casmurro, não cuide que o dispenso do theatro amanhã; venha e do
# ----
# iter 821200, loss: 0.088262
# ----
#  Rhenania; vê se deixas essa caverna do
# Engenho Nov racou de pol elando-me eue, e
# com ema, para nadotre porritou gema; só mulheça.»
#
# Não consultes de lispariante maus. Succedeu, porém, que
# como eu esta
# ----
# iter 821300, loss: 0.087915
# ----
#  este
# mesmo. O meu poeta do trem ficará sabendo que não lhe guardo rancor.
# E com pequeno esforço, sendo o titulo seu, poderá cuidar que a obra
# é sua. Ha livros que apenas terão isso dos seus autores; a
# ----
# iter 821400, loss: 0.087780
# ----
#  u quatro vezes; tanto
# bastou para que elle interrompesse a leitura e mettesse os versos no
# bolso.
#
# --Continue, disse eu accordando.
#
# --Já acabei, por eiter auinnou vae es por semssa, que
# afinatteu par
# ----
# iter 821500, loss: 0.087488
# ----
#  om
# Casmurro, domingo vou jantar com você.»--«Vou para Petropolis, Dom
# Casmurro; a casa é a mesma da Rhenania; vê se deixas essa caverna do
# Engenho Novo, e vae lá passar uns quinze dias commigo.»--«Meu
# ----
# iter 821600, loss: 0.087236
# ----
#  m não achei melhor titulo para a minha
# narração; se não tiver outro d'aqui até ao fim do livro, messo. Castrraperia de anos versos noc-manhoptro, dos meus habitos reclusos em, do-morz o dastis veisso
# ----
# iter 821700, loss: 0.087023
# ----
#  ue não fossem inteiramente maus. Succedeu, porém, que
# como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto
# bastou para que elle interrompesse a leitura e mettesse os versos no
# bolso.
#
# -
# ----
# iter 821800, loss: 0.086762
# ----
#   Contei a anecdota aos amigos da
# cidade, e elles, por graça, chamam-me assim, alguns em bilhetes: «Dom
# Casmurro, domingo vou jantar com você.»--«Vou para Petropolis, Dom
# Casmurro; a casa é a mesma da
# ----
# iter 821900, loss: 0.086527
# ----
#  comsigo. _Dom_ veiu por ironia, para attribuir-me fumos de fidalgo.
# Tudo por estar cochilando! Tambem não achei melhor titulo para a minha
# narração; se que não fossem, dou com
# do go. O masso do bondo
#
# ----
# iter 822000, loss: 0.086241
# ----
#  laom no poz rocê Pelcunidas pei., sindeus autorá
# alcumiro. Ha cidostrom mas da livros mento
# nabotrom
# nos, e e tatalhoçha, que
# não lhe
# por iros. Aevem, que
# afinal pegou. Nem por isso me para os fanges
#
# ----
# iter 822100, loss: 0.086105
# ----
#  s meus habitos reclusos e calados, deram curso á alcunha, que
# afinal pegou. Nem por isso me zanguei. Contei a anecdota aos amigos da
# cidade, e elles, por graça, chamam-me ass: «Dou para que elle inter
# ----
# iter 822200, loss: 0.085873
# ----
#  o_ não está aqui no sentido que
# elles lhe dão, mas no que lhe poz o vulgo de homem calado e mettido
# comsigo. _Dom_ veiu por ironia, para attribuir-me fumos de fidalgo.
# Tudo por estar cochilando! Tambe
# ----
# iter 822300, loss: 0.085613
# ----
#  paz aqui do bairro, que eu conheço de vista e
# de chapéo. Comprimentou-me, sentou-se ao pé de mim, falou da lua e
# dos ministros, e acabou recitando-me fulhe ficalcoui.»--«Vou para Petropolis, Dom
# Casmu
# ----
# iter 822400, loss: 0.085493
# ----
#  ou a dizer de mim nomes
# feios, e acabou alcunhando-me _Dom Casmurro._ Os visinhos, que não
# gostam dor-midospendo que não fossem inteiramente mauinno gos. por graça, chamam-me ase eu pera ou qua. tes q
# ----
# iter 822500, loss: 0.085280
# ----
#  lhe camarote, dou-lhe chá, dou-lhe cama; só não lhe
# dou moça.»
#
# Não consultes diccionarios. _Casmurro_ não está aqui no sentido que
# elles lhe dão, mas no que lhe poz o vulgo de homem calado e mettido
#
# ----
# iter 822600, loss: 0.085062
# ----
#  o titulo.
#
# Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no
# trem da Central um rapaz aqui do bairro, que eu conheço de vista e
# de chapéo. Comprimentou-me, sentou-se ao pé de mim, fa
# ----
# iter 822700, loss: 0.084808
# ----
#  gesto para tiral-os outra vez do gulheçou da cisse dou casa foldimor Osmarou elle.
#
# --São muito bonitos.
#
# Vi-lhe fazes om nacéos docgesta angenho Novo, e calados, deram curso á allo.
#
# --São muito boni
# ----
# iter 822800, loss: 0.084705
# ----
#   caro Dom
# Casmurro, não cuide que o dispenso do theatro amanhã; venha e dormirá
# aqui na cidade; dou-lhe camarote, dou-lhe chá, dou-lhe cama; só não lhe
# dou moça.»
#
# Não consultes diccionarios. _Casmurr
# ----
# iter 822900, loss: 0.084453
# ----
#  do o titulo seu, poderá cuidar que a obra
# é sua. Ha livros que apenas terão isso dos seus autores; a não se ados, dasso do bua da lha gessa mará e cuido. No, porém, que
# locirrania, poram rado, ficalhe
# ----
# iter 823000, loss: 0.084317
# ----
#  -Continue, disse eu accordando.
#
# --Já acabei, murmurou elle.
#
# --São muito bonitos.
#
# Vi-lhe fazer um gesto para tiral-os outra vez do bolso, mas não passou
# do gesto; estava amuado. No dia seguinte entr
# ----
# iter 823100, loss: 0.084144
# ----
#  Rhenas não acabenda cidade do que o dispenso do theatro amanhã; venha e dormirá
# aqui na cidade; dou-lhe camarote, dou-lhe chá, dou-lhe cama; só não lhe
# dou moça.»
#
# Não consultes diccionarios. _Casmurr
# ----
# iter 823200, loss: 0.083863
# ----
#  este
# mesmo. O meu poeta do trem ficará sabendo que não lhe guardo rancor.
# E com pequeno esforço, sena locgura cava, peré o Em recgestessou quo atos tesso. Compossenz tital-se tiista; do antá
# mqua do p
# ----
# iter 823300, loss: 0.083806
# ----
#  u quatro vezes; tanto
# bastou para que elle interrompesse a leitura e mettesse os versos no
# bolso.
#
# --Continue, disse eu accordando.
#
# --Já acabei, murmurou elle.
#
# --São muito bonitos., palao dessou e c
# ----
# iter 823400, loss: 0.083581
# ----
#  om
# Casmurro, domingo vou jantar com você.»--«Vou para Petropolis, Dom
# Casmurro; a casa é a mesma da Rhenas noccontei ae meam dom, turoquinze masmurra; alcunhanana em o. osta do tira cosse cammom póde
# ----
# iter 823500, loss: 0.083388
# ----
#  m não achei melhor titulo para a minha
# narração; se não tiver outro d'aqui até ao fim do livro, vae este
# mesmo. O meu poeta do trem ficará sabendo que não lhe guardo rancor.
# E com pequeno esforço, sen
# ----
# iter 823600, loss: 0.083238
# ----
#  ue não fossem inteiramente maus. Succedeu, porém, que
# como eu estava cançado, fechei os olhos tres ou quatro vezes; tanto
# bastou para que elle interrompesse a leitura e mettesse os versos no
# bolso.
#
# -
# ----
# iter 823700, loss: 0.083039
# ----
#   Contei a anecdota aos amigos da
# cidade, e elles, por graça, chamam-me assim, alguns em bilhetes: «Dom
# Casmurro, domingo vou jantar com você.»--«Vou para Petropolis, Dom
# Casmurro; a casa é a mesma da
# ----
# iter 823800, loss: 0.082868
# ----
#  ndapque a vernos pessa dou da livros que eu cidalgo.
# Tudo por estar cochilando! Tambem não achei melhor titulo para a minha
# narração; se não tivpé; sechotrom Cos. Aeve
# do do que o dispenso do tousia d
# ----
# iter 823900, loss: 0.082640
# ----
#  lou da lua e
# dos ministros, e acabou recitando-me versos. A viagem era curta, e os
# versos póde ser que não fossem inteiramente maus. Succedeu, porém, que
# como eu estava cançado, fechei os olhos tres o
# ----
# iter 824000, loss: 0.082553
# ----
#  s meus habitos reclusos e calados, deram curso á alcunha, que
# afinal pegou. Nem por isso me zanguei. Contei a anecdota aos aminto guido
# como te esselcalhe
# maçando passo.
#
# --Contidei eo para Petropolis
# ----
# iter 824100, loss: 0.082373
# ----
#  o_ não está aqui no sentido que
# elles lhe dão, mas no que lhe poz o vulgo de homem calado e mettido
# comsigo. _Dom_ veiu por ironia, para attribuir-me fumos de fidalgo.
# Tudo por estar cochilando! Tambe
# ----
# iter 824200, loss: 0.082162
# ----
#  paz aqui do bairro, que eu conheço de vista e
# de chapéo. Comprimentou-me, sentou-se ao pé de mim, falou da lua e
# dos ministros, e acabou recitando-me versos. A viagem era curta, e os
# versos póde ser q
# ----
# iter 824300, loss: 0.082091
# ----
#  ou a dizer de mim nomes
# feios, e acabou alcunhando-me _Dom Casmurro._ Os visinhos, que não
# gostam dos meus habitos reclusos e calados, deram curso á alcunha, alcuntrom Casmurro._ Os visinhos, que não
#
# ----
# iter 824400, loss: 0.081934
# ----
#  lhe camarote, dou-lhe chá, dou-lhe cama; só não lhe
# dou moça.»
#
# Não consultes diccionarios. _Casmurro_ não está aqui no sentido que
# elles lhe dão, mas no que lhe poz o vulgo de homem calado e mettido
#
# ----
# iter 824500, loss: 0.081751
# ----
#  o titulo.
#
# Uma noite destas, vindo da cidade para o Engenho Novo, encontrei no
# trem da Central um rapaz aqui do bairro, que eu conheço de vista e
# de chapéo. Comprimentou-me, sentou-se ao pé de mim, fa
# ----
# iter 824600, loss: 0.081553
# ----
#  gesto para tiral-os outra vez do bolso, mas não passou
# do gesto; estava amuado. No dia seguinte entrou a dizer de mim nomes
# feios, e acabou alcunhando-me _Dom Casmurro._ Os visinhos, que não
# gostam do
# ----
# iter 824700, loss: 0.081492
