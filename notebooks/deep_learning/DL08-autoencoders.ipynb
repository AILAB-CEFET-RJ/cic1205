# %% [markdown]
# # Introduction
#
# An **Autoencoder** is a type of neural network used for **unsupervised learning**, primarily aimed at learning efficient codings of input data. Its architecture is typically composed of two main parts: Encoder and Decoder.
#
# <center><img src='https://buffml.com/wp-content/uploads/2021/05/autoencoder-feature-img.png'></center>
#
# ### 1. Encoder
#
# * **Purpose**: Compresses the input data into a lower-dimensional representation (called the **latent space** or **bottleneck**).
# * **Structure**: A series of layers (often fully connected or convolutional) that reduce the input dimensionality.
# * **Output**: A latent vector `z` that summarizes the most important features of the input `x`.
#
# ### 2. Latent Space (Bottleneck)
#
# * **Purpose**: Acts as a compressed summary of the input data.
# * **Size**: Much smaller than the input dimension, enforcing the model to learn meaningful patterns.
#
# ### 3. Decoder
#
# * **Purpose**: Reconstructs the input data from the latent vector `z`.
# * **Structure**: A mirrored architecture of the encoder that attempts to invert the compression process.
# * **Output**: A reconstructed input `x'` that ideally resembles the original input `x`.
#
# ### Training an Autoencoder
#
# When training an autoencoder, the objecti is to minimize the **reconstruction loss**, commonly measured using:
#
# * **Mean Squared Error (MSE)** for continuous data,
# * **Binary Cross-Entropy** for binary input.
#
# $$
# \mathcal{L}(x, x') = \|x - x'\|^2
# $$
#
#
# ### **Applications**
#
# * Dimensionality reduction
# * Anomaly detection
# * Image denoising
# * Data compression

# %% [markdown]
# # Vanilla Autoencoder
#
# The code below show a complete PyTorch example illustrating how to train an *autoencoder on the MNIST dataset. It includes:
#
# * Data loading
# * Encoder and decoder definition
# * Training loop
# * Visualization of reconstruction results
#
# Requirements:
#
# ```bash
# pip install torch torchvision matplotlib
# ```

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# MNIST dataset
transform = transforms.ToTensor()
train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)

# Autoencoder architecture
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28 * 28, 128),
            nn.ReLU(),
            nn.Linear(128, 32)
        )
        self.decoder = nn.Sequential(
            nn.Linear(32, 128),
            nn.ReLU(),
            nn.Linear(128, 28 * 28),
            nn.Sigmoid(),
            nn.Unflatten(1, (1, 28, 28))
        )

    def forward(self, x):
        z = self.encoder(x)
        x_recon = self.decoder(z)
        return x_recon

model = Autoencoder().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# Training loop
num_epochs = 5
for epoch in range(num_epochs):
    for imgs, _ in train_loader:
        imgs = imgs.to(device)
        outputs = model(imgs)
        loss = criterion(outputs, imgs)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")

# Visualization
def show_reconstructions(model, n=10):
    model.eval()
    test_imgs, _ = next(iter(train_loader))
    test_imgs = test_imgs[:n].to(device)
    with torch.no_grad():
        recon = model(test_imgs)

    fig, axes = plt.subplots(2, n, figsize=(n*1.5, 3))
    for i in range(n):
        axes[0, i].imshow(test_imgs[i].cpu().squeeze(), cmap='gray')
        axes[0, i].axis('off')
        axes[1, i].imshow(recon[i].cpu().squeeze(), cmap='gray')
        axes[1, i].axis('off')
    plt.suptitle("Top: Original | Bottom: Reconstruction")
    plt.show()

show_reconstructions(model)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:01<00:00, 5680601.82it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 224688.19it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:02<00:00, 740001.36it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2044925.80it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Epoch [1/5], Loss: 0.0242
# Epoch [2/5], Loss: 0.0160
# Epoch [3/5], Loss: 0.0134
# Epoch [4/5], Loss: 0.0121
# Epoch [5/5], Loss: 0.0106

# %% [markdown]
# ### Visualization of the Latent Space
#
# This code builds a visualization of the **latent space** of the autoencoder using the MNIST dataset. This example projects the 32D latent vectors into 2D using **t-SNE**, colored by digit class.
#
# What This Shows:
#
# * Each point is the latent representation of a digit image.
# * Colors represent digit classes (0–9).
# * Clusters suggest that the encoder learned class-discriminative features, even though training was **unsupervised**.

# %%
from sklearn.manifold import TSNE

def visualize_latent_space(model, data_loader, n_samples=2000):
    model.eval()
    latents = []
    labels = []

    with torch.no_grad():
        for imgs, lbls in data_loader:
            imgs = imgs.to(device)
            z = model.encoder(imgs)
            latents.append(z.cpu())
            labels.append(lbls)
            if len(torch.cat(latents)) > n_samples:
                break

    latents = torch.cat(latents)[:n_samples]
    labels = torch.cat(labels)[:n_samples]

    # Reduce to 2D with t-SNE
    tsne = TSNE(n_components=2, init='pca', learning_rate='auto', random_state=42)
    latents_2d = tsne.fit_transform(latents)

    # Plot
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(latents_2d[:, 0], latents_2d[:, 1], c=labels, cmap='tab10', s=10)
    plt.legend(*scatter.legend_elements(), title="Digits", loc="best")
    plt.title("t-SNE projection of latent space")
    plt.xlabel("Latent dimension 1")
    plt.ylabel("Latent dimension 2")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Call the function on training data
visualize_latent_space(model, train_loader)
# Out:
# /Users/ebezerra/miniconda3/envs/cic1205/lib/python3.12/site-packages/threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# # Denoising Autoencoder

# %% [markdown]
# **Créditos**
#
# O código apresentado neste notebook e uma adaptação do original produzido por Eugenia Anello quando da escrita do artigo [Denoising Autoencoder in Pytorch on MNIST dataset](https://ai.plainenglish.io/denoising-autoencoder-in-pytorch-on-mnist-dataset-a76b8824e57e).

# %%
import matplotlib.pyplot as plt
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd # this module is useful to work with tabular data
import random # this module will be used to select random samples from a collection
import os # this module will be used just to create directories in the local filesystem
from tqdm import tqdm # this module is useful to plot progress bars
import plotly.io as pio

import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.manifold import TSNE
import plotly.express as px

# %%
data_dir = 'dataset'
# With these commands the train and test datasets are automatically
# downloaded and stored in the local "data_dir" directory.
train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to dataset/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:01<00:00, 5839637.14it/s]
# Extracting dataset/MNIST/raw/train-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 224459.62it/s]
# Extracting dataset/MNIST/raw/train-labels-idx1-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 2063683.17it/s]
# Extracting dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2965062.84it/s]
# Extracting dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw

# %%
fig, axs = plt.subplots(5, 5, figsize=(8,8))
for ax in axs.flatten():
    # random.choice allows to randomly sample from a list-like 
    # object (basically anything that can be accessed with an index, 
    # like our dataset)
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
train_transform = transforms.Compose([
    transforms.ToTensor(),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Set the train transform
train_dataset.transform = train_transform
# Set the test transform
test_dataset.transform = test_transform

# %%
m=len(train_dataset)

#random_split randomly split a dataset into non-overlapping new datasets of given lengths
#train (55,000 images), val split (5,000 images)
train_data, val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)])

batch_size=256

# The dataloaders handle shuffling, batching, etc...
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,shuffle=True)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# ## Definição do codificador e do decodificador
#
# Nesta seção, as classes do codificador e do decodificador são definidas. Esses dois componentes contêm 3 camadas convolucionais e 2 camadas totalmente conectadas. A diferença é que o decodificador usa camadas de [convolução transposta](https://github.com/vdumoulin/conv_arithmetic).

# %%
class Encoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        
        ### Convolutional section
        self.encoder_cnn = nn.Sequential(
            # First convolutional layer
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            #nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Second convolutional layer
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Third convolutional layer
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            #nn.BatchNorm2d(32),
            nn.ReLU(True)
        )
        
        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        ### Linear section
        self.encoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, encoded_space_dim)
        )
        
    def forward(self, x):
        # Apply convolutions
        x = self.encoder_cnn(x)
        # Flatten
        x = self.flatten(x)
        # # Apply linear layers
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()

        ### Linear section
        self.decoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        ### Unflatten
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))

        ### Convolutional section
        self.decoder_conv = nn.Sequential(
            # First transposed convolution
            nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Second transposed convolution
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Third transposed convolution
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )
        
    def forward(self, x):
        # Apply linear layers
        x = self.decoder_lin(x)
        # Unflatten
        x = self.unflatten(x)
        # Apply transposed convolutions
        x = self.decoder_conv(x)
        # Apply a sigmoid to force the output to be between 0 and 1 (valid pixel values)
        x = torch.sigmoid(x)
        return x

# %% [markdown]
# ## Construção do modelo
#
# Agora, os componentes codificador e decodificador são iniciados. São também definidos a função de custo, o otimizador e o dispositivo para usar GPU.
#
# Repare que a dimensão da camada do código é definida como igual a 4.

# %%
### Set the random seed for reproducible results
torch.manual_seed(0)

### Initialize the two networks
d = 4

encoder = Encoder(encoded_space_dim=d, fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=d, fc2_input_dim=128)

# %%
### Define the loss function
loss_fn = torch.nn.MSELoss()

### Define an optimizer (both for the encoder and the decoder!)
lr= 0.001 # Learning rate


params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

optim = torch.optim.Adam(params_to_optimize, lr=lr)

# Move both the encoder and the decoder to the selected device
encoder.to(device)
decoder.to(device)
#model.to(device)
# Out:
# Selected device: cpu
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %% [markdown]
# ## Treinamento do modelo

# %% [markdown]
# A função a seguir aplica um ruído aleatório na imagem de entrada. O resultado dessa função é que será usado como entrada para o treinamento.
#
# Essa função realiza duas etapas para transformar a imagem de entrada:
#
# - `torch.randn_like` para criar um tensor ruidoso do mesmo tamanho da entrada
# - `torch.clip(min=0.,max=1.)` para limitar o intervalo entre 0 e 1

# %%
def add_noise(inputs,noise_factor=0.3):
     noise = inputs + torch.randn_like(inputs)*noise_factor
     noise = torch.clip(noise, 0., 1.)
     return noise

# %% [markdown]
# Agora, o código de treinamento de modelo é apresentado.
#
# Há uma função para realizar o treinamento (`train_epoch_den`) e outra para a validação (`test_epoch_den`). Ambas são chamadas em  cada época de treinamento.
#
# Na função `train_epoch_den`, repare que
#
# 1. cada imagem do lote é distorcida antes de ser passada para o modelo;
# 2. a função de custo é avaliada computando o erro (diferença) entre a imagem gerada pelo modelo (`encoded_data`) e a imagem distorcida apresentada na entrada (`image_noisy`).

# %%
### Training function
def train_epoch_den(encoder, decoder, device, dataloader, loss_fn, optimizer,noise_factor=0.3):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        image_noisy = add_noise(image_batch,noise_factor)
        image_noisy = image_noisy.to(device)    
        # Encode data
        encoded_data = encoder(image_noisy)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_noisy)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)

# %%
### Testing function
def test_epoch_den(encoder, decoder, device, dataloader, loss_fn,noise_factor=0.3):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            # Move tensor to the proper device
            image_noisy = add_noise(image_batch,noise_factor)
            image_noisy = image_noisy.to(device)
            # Encode data
            encoded_data = encoder(image_noisy)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %% [markdown]
# A função a seguir é definida com o propósito de permitir acompanhar o aprendizado do modelo. Essa função é chamada no fim de cada época de treinamento. Para as cinco primeiras imagens do conjunto de teste, essa função apresenta três visualizações:
#
# - a imagem de entrada original,
# - a imagem após a aplicação do ruído,
# - a imagem reconstruída pelo modelo.

# %%
def plot_ae_outputs_den(encoder,decoder,n=5,noise_factor=0.3):
    plt.figure(figsize=(10,4.5))
    for i in range(n):

      ax = plt.subplot(3,n,i+1)
      img = test_dataset[i][0].unsqueeze(0)
      image_noisy = add_noise(img, noise_factor)     
      image_noisy = image_noisy.to(device)

      encoder.eval()
      decoder.eval()

      with torch.no_grad():
         rec_img  = decoder(encoder(image_noisy))

      plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
        ax.set_title('Original images')
      ax = plt.subplot(3, n, i + 1 + n)
      plt.imshow(image_noisy.cpu().squeeze().numpy(), cmap='gist_gray')
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
        ax.set_title('Corrupted images')

      ax = plt.subplot(3, n, i + 1 + n + n)
      plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')  
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
         ax.set_title('Reconstructed images')
    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.7, 
                    top=0.9, 
                    wspace=0.3, 
                    hspace=0.3)     
    plt.show()

# %% [markdown]
# O código a seguir realiza o treinamento. Após 30 épocas, o autoencoder parece reconstruir imagens semelhantes às observadas na entrada. Ainda existem algumas imperfeições, mas há uma clara melhoria em comparação às primeiras épocas, em que o autoencoder ainda não captura as informações mais relevantes para realizar as reconstruções.

# %%
### Training cycle
noise_factor = 0.3
num_epochs = 30
history_da={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    print('EPOCH %d/%d' % (epoch + 1, num_epochs))
    ### Training (use the training function)
    train_loss = train_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=train_loader, 
        loss_fn=loss_fn, 
        optimizer=optim,
        noise_factor=noise_factor)
    ### Validation  (use the testing function)
    val_loss = test_epoch_den(
        encoder=encoder, 
        decoder=decoder, 
        device=device, 
        dataloader=valid_loader, 
        loss_fn=loss_fn,
        noise_factor=noise_factor)
    # Print Validationloss
    history_da['train_loss'].append(train_loss)
    history_da['val_loss'].append(val_loss)
    print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
    plot_ae_outputs_den(encoder,decoder,noise_factor=noise_factor)
# Out:
# EPOCH 1/30
# 	 partial train loss (single batch): 0.189575
# 	 partial train loss (single batch): 0.184301
# 	 partial train loss (single batch): 0.178877
# 	 partial train loss (single batch): 0.175887
# 	 partial train loss (single batch): 0.172570
# 	 partial train loss (single batch): 0.169789
# 	 partial train loss (single batch): 0.167634
# 	 partial train loss (single batch): 0.165034
# 	 partial train loss (single batch): 0.163262
# 	 partial train loss (single batch): 0.161971
# 	 partial train loss (single batch): 0.160059
# 	 partial train loss (single batch): 0.158411
# 	 partial train loss (single batch): 0.156744
# 	 partial train loss (single batch): 0.155488
# 	 partial train loss (single batch): 0.153867
# 	 partial train loss (single batch): 0.152160
# 	 partial train loss (single batch): 0.150732
# 	 partial train loss (single batch): 0.149429
# 	 partial train loss (single batch): 0.148297
# 	 partial train loss (single batch): 0.146653
# 	 partial train loss (single batch): 0.145197
# 	 partial train loss (single batch): 0.144071
# 	 partial train loss (single batch): 0.142304
# 	 partial train loss (single batch): 0.141357
# 	 partial train loss (single batch): 0.140177
# 	 partial train loss (single batch): 0.139290
# 	 partial train loss (single batch): 0.138090
# 	 partial train loss (single batch): 0.136839
# 	 partial train loss (single batch): 0.134993
# 	 partial train loss (single batch): 0.134086
# 	 partial train loss (single batch): 0.132920
# 	 partial train loss (single batch): 0.132052
# 	 partial train loss (single batch): 0.131014
# 	 partial train loss (single batch): 0.130234
# 	 partial train loss (single batch): 0.129032
# 	 partial train loss (single batch): 0.127924
# 	 partial train loss (single batch): 0.126930
# 	 partial train loss (single batch): 0.126192
# 	 partial train loss (single batch): 0.124957
# 	 partial train loss (single batch): 0.124013
# 	 partial train loss (single batch): 0.123239
# 	 partial train loss (single batch): 0.121898
# 	 partial train loss (single batch): 0.121550
# 	 partial train loss (single batch): 0.120637
# 	 partial train loss (single batch): 0.119661
# 	 partial train loss (single batch): 0.118757
# 	 partial train loss (single batch): 0.117516
# 	 partial train loss (single batch): 0.117125
# 	 partial train loss (single batch): 0.115737
# 	 partial train loss (single batch): 0.115699
# 	 partial train loss (single batch): 0.114801
# 	 partial train loss (single batch): 0.113652
# 	 partial train loss (single batch): 0.113205
# 	 partial train loss (single batch): 0.112022
# 	 partial train loss (single batch): 0.111176
# 	 partial train loss (single batch): 0.110768
# 	 partial train loss (single batch): 0.110036
# 	 partial train loss (single batch): 0.109221
# 	 partial train loss (single batch): 0.108984
# 	 partial train loss (single batch): 0.107850
# 	 partial train loss (single batch): 0.107395
# 	 partial train loss (single batch): 0.106036
# 	 partial train loss (single batch): 0.105684
# 	 partial train loss (single batch): 0.105201
# 	 partial train loss (single batch): 0.103917
# 	 partial train loss (single batch): 0.103458
# 	 partial train loss (single batch): 0.103362
# 	 partial train loss (single batch): 0.102597
# 	 partial train loss (single batch): 0.101697
# 	 partial train loss (single batch): 0.100997
# 	 partial train loss (single batch): 0.100237
# 	 partial train loss (single batch): 0.100419
# 	 partial train loss (single batch): 0.099683
# 	 partial train loss (single batch): 0.098373
# 	 partial train loss (single batch): 0.097846
# 	 partial train loss (single batch): 0.097651
# 	 partial train loss (single batch): 0.097490
# 	 partial train loss (single batch): 0.096742
# 	 partial train loss (single batch): 0.095871
# 	 partial train loss (single batch): 0.095771
# 	 partial train loss (single batch): 0.094916
# 	 partial train loss (single batch): 0.094418
# 	 partial train loss (single batch): 0.094037
# 	 partial train loss (single batch): 0.093497
# 	 partial train loss (single batch): 0.093083
# 	 partial train loss (single batch): 0.092848
# 	 partial train loss (single batch): 0.091815
# 	 partial train loss (single batch): 0.091318
# 	 partial train loss (single batch): 0.091728
# 	 partial train loss (single batch): 0.090923
# 	 partial train loss (single batch): 0.090643
# 	 partial train loss (single batch): 0.089955
# 	 partial train loss (single batch): 0.089681
# 	 partial train loss (single batch): 0.089315
# 	 partial train loss (single batch): 0.088765
# 	 partial train loss (single batch): 0.087763
# 	 partial train loss (single batch): 0.087412
# 	 partial train loss (single batch): 0.087585
# 	 partial train loss (single batch): 0.086477
# 	 partial train loss (single batch): 0.086868
# 	 partial train loss (single batch): 0.086252
# 	 partial train loss (single batch): 0.085943
# 	 partial train loss (single batch): 0.084685
# 	 partial train loss (single batch): 0.084933
# 	 partial train loss (single batch): 0.084575
# 	 partial train loss (single batch): 0.084055
# 	 partial train loss (single batch): 0.083435
# 	 partial train loss (single batch): 0.083570
# 	 partial train loss (single batch): 0.083230
# 	 partial train loss (single batch): 0.083006
# 	 partial train loss (single batch): 0.082838
# 	 partial train loss (single batch): 0.082665
# 	 partial train loss (single batch): 0.082592
# 	 partial train loss (single batch): 0.081448
# 	 partial train loss (single batch): 0.081726
# 	 partial train loss (single batch): 0.081234
# 	 partial train loss (single batch): 0.080099
# 	 partial train loss (single batch): 0.080349
# 	 partial train loss (single batch): 0.080050
# 	 partial train loss (single batch): 0.080230
# 	 partial train loss (single batch): 0.079227
# 	 partial train loss (single batch): 0.080073
# 	 partial train loss (single batch): 0.079528
# 	 partial train loss (single batch): 0.078911
# 	 partial train loss (single batch): 0.078271
# 	 partial train loss (single batch): 0.077947
# 	 partial train loss (single batch): 0.078421
# 	 partial train loss (single batch): 0.078017
# 	 partial train loss (single batch): 0.077184
# 	 partial train loss (single batch): 0.077352
# 	 partial train loss (single batch): 0.077242
# 	 partial train loss (single batch): 0.076636
# 	 partial train loss (single batch): 0.076496
# 	 partial train loss (single batch): 0.076878
# 	 partial train loss (single batch): 0.075637
# 	 partial train loss (single batch): 0.075708
# 	 partial train loss (single batch): 0.075844
# 	 partial train loss (single batch): 0.075212
# 	 partial train loss (single batch): 0.075332
# 	 partial train loss (single batch): 0.074664
# 	 partial train loss (single batch): 0.075380
# 	 partial train loss (single batch): 0.074469
# 	 partial train loss (single batch): 0.074549
# 	 partial train loss (single batch): 0.074184
# 	 partial train loss (single batch): 0.074046
# 	 partial train loss (single batch): 0.073452
# 	 partial train loss (single batch): 0.073625
# 	 partial train loss (single batch): 0.073499
# 	 partial train loss (single batch): 0.073658
# 	 partial train loss (single batch): 0.072907
# 	 partial train loss (single batch): 0.072453
# 	 partial train loss (single batch): 0.073682
# 	 partial train loss (single batch): 0.073072
# 	 partial train loss (single batch): 0.072086
# 	 partial train loss (single batch): 0.071968
# 	 partial train loss (single batch): 0.071921
# 	 partial train loss (single batch): 0.071689
# 	 partial train loss (single batch): 0.072548
# 	 partial train loss (single batch): 0.071064
# 	 partial train loss (single batch): 0.070788
# 	 partial train loss (single batch): 0.072460
# 	 partial train loss (single batch): 0.071613
# 	 partial train loss (single batch): 0.070461
# 	 partial train loss (single batch): 0.070420
# 	 partial train loss (single batch): 0.071030
# 	 partial train loss (single batch): 0.069497
# 	 partial train loss (single batch): 0.070156
# 	 partial train loss (single batch): 0.070416
# 	 partial train loss (single batch): 0.070741
# 	 partial train loss (single batch): 0.070503
# 	 partial train loss (single batch): 0.069540
# 	 partial train loss (single batch): 0.069609
# 	 partial train loss (single batch): 0.069531
# 	 partial train loss (single batch): 0.069994
# 	 partial train loss (single batch): 0.069223
# 	 partial train loss (single batch): 0.069490
# 	 partial train loss (single batch): 0.068775
# 	 partial train loss (single batch): 0.068675
# 	 partial train loss (single batch): 0.069040
# 	 partial train loss (single batch): 0.068335
# 	 partial train loss (single batch): 0.068279
# 	 partial train loss (single batch): 0.068259
# 	 partial train loss (single batch): 0.067897
# 	 partial train loss (single batch): 0.068014
# 	 partial train loss (single batch): 0.067851
# 	 partial train loss (single batch): 0.067484
# 	 partial train loss (single batch): 0.067712
# 	 partial train loss (single batch): 0.067182
#
#  EPOCH 1/30 	 train loss 0.099 	 val loss 0.072
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# EPOCH 2/30
# 	 partial train loss (single batch): 0.067397
# 	 partial train loss (single batch): 0.067356
# 	 partial train loss (single batch): 0.067136
# 	 partial train loss (single batch): 0.067220
# 	 partial train loss (single batch): 0.065795
# 	 partial train loss (single batch): 0.067147
# 	 partial train loss (single batch): 0.066527
# 	 partial train loss (single batch): 0.068525
# 	 partial train loss (single batch): 0.067042
# 	 partial train loss (single batch): 0.066409
# 	 partial train loss (single batch): 0.067146
# 	 partial train loss (single batch): 0.066053
# 	 partial train loss (single batch): 0.066684
# 	 partial train loss (single batch): 0.066443
# 	 partial train loss (single batch): 0.065332
# 	 partial train loss (single batch): 0.066446
# 	 partial train loss (single batch): 0.065697
# 	 partial train loss (single batch): 0.065317
# 	 partial train loss (single batch): 0.064980
# 	 partial train loss (single batch): 0.065377
# 	 partial train loss (single batch): 0.065854
# 	 partial train loss (single batch): 0.065273
# 	 partial train loss (single batch): 0.066269
# 	 partial train loss (single batch): 0.065272
# 	 partial train loss (single batch): 0.065008
# 	 partial train loss (single batch): 0.065041
# 	 partial train loss (single batch): 0.064700
# 	 partial train loss (single batch): 0.065664
# 	 partial train loss (single batch): 0.064632
# 	 partial train loss (single batch): 0.065361
# 	 partial train loss (single batch): 0.065199
# 	 partial train loss (single batch): 0.065864
# 	 partial train loss (single batch): 0.065764
# 	 partial train loss (single batch): 0.065258
# 	 partial train loss (single batch): 0.063871
# 	 partial train loss (single batch): 0.064684
# 	 partial train loss (single batch): 0.064683
# 	 partial train loss (single batch): 0.066183
# 	 partial train loss (single batch): 0.064921
# 	 partial train loss (single batch): 0.063382
# 	 partial train loss (single batch): 0.064092
# 	 partial train loss (single batch): 0.064484
# 	 partial train loss (single batch): 0.064714
# 	 partial train loss (single batch): 0.064175
# 	 partial train loss (single batch): 0.063238
# 	 partial train loss (single batch): 0.063581
# 	 partial train loss (single batch): 0.064809
# 	 partial train loss (single batch): 0.064273
# 	 partial train loss (single batch): 0.063756
# 	 partial train loss (single batch): 0.064614
# 	 partial train loss (single batch): 0.064021
# 	 partial train loss (single batch): 0.063400
# 	 partial train loss (single batch): 0.063904
# 	 partial train loss (single batch): 0.063328
# 	 partial train loss (single batch): 0.063859
# 	 partial train loss (single batch): 0.065146
# 	 partial train loss (single batch): 0.063063
# 	 partial train loss (single batch): 0.063392
# 	 partial train loss (single batch): 0.064344
# 	 partial train loss (single batch): 0.063260
# 	 partial train loss (single batch): 0.063975
# 	 partial train loss (single batch): 0.063828
# 	 partial train loss (single batch): 0.063356
# 	 partial train loss (single batch): 0.063072
# 	 partial train loss (single batch): 0.064300
# 	 partial train loss (single batch): 0.063436
# 	 partial train loss (single batch): 0.061992
# 	 partial train loss (single batch): 0.062430
# 	 partial train loss (single batch): 0.063052
# 	 partial train loss (single batch): 0.063608
# 	 partial train loss (single batch): 0.063365
# 	 partial train loss (single batch): 0.062962
# 	 partial train loss (single batch): 0.062974
# 	 partial train loss (single batch): 0.062491
# 	 partial train loss (single batch): 0.062711
# 	 partial train loss (single batch): 0.062903
# 	 partial train loss (single batch): 0.062742
# 	 partial train loss (single batch): 0.063187
# 	 partial train loss (single batch): 0.062661
# 	 partial train loss (single batch): 0.062039
# 	 partial train loss (single batch): 0.062677
# 	 partial train loss (single batch): 0.062173
# 	 partial train loss (single batch): 0.062349
# 	 partial train loss (single batch): 0.061783
# 	 partial train loss (single batch): 0.063017
# 	 partial train loss (single batch): 0.062617
# 	 partial train loss (single batch): 0.062112
# 	 partial train loss (single batch): 0.062204
# 	 partial train loss (single batch): 0.062570
# 	 partial train loss (single batch): 0.062257
# 	 partial train loss (single batch): 0.061898
# 	 partial train loss (single batch): 0.061494
# 	 partial train loss (single batch): 0.062129
# 	 partial train loss (single batch): 0.062797
# 	 partial train loss (single batch): 0.062261
# 	 partial train loss (single batch): 0.062684
# 	 partial train loss (single batch): 0.062547
# 	 partial train loss (single batch): 0.061665
# 	 partial train loss (single batch): 0.061754
# 	 partial train loss (single batch): 0.062204
# 	 partial train loss (single batch): 0.062952
# 	 partial train loss (single batch): 0.062467
# 	 partial train loss (single batch): 0.062332
# 	 partial train loss (single batch): 0.061757
# 	 partial train loss (single batch): 0.061524
# 	 partial train loss (single batch): 0.060881
# 	 partial train loss (single batch): 0.061987
# 	 partial train loss (single batch): 0.062310
# 	 partial train loss (single batch): 0.062286
# 	 partial train loss (single batch): 0.060966
# 	 partial train loss (single batch): 0.062436
# 	 partial train loss (single batch): 0.061647
# 	 partial train loss (single batch): 0.061356
# 	 partial train loss (single batch): 0.061690
# 	 partial train loss (single batch): 0.059891
# 	 partial train loss (single batch): 0.062101
# 	 partial train loss (single batch): 0.061517
# 	 partial train loss (single batch): 0.060797
# 	 partial train loss (single batch): 0.060666
# 	 partial train loss (single batch): 0.061058
# 	 partial train loss (single batch): 0.060736
# 	 partial train loss (single batch): 0.061224
# 	 partial train loss (single batch): 0.061650
# 	 partial train loss (single batch): 0.060657
# 	 partial train loss (single batch): 0.063095
# 	 partial train loss (single batch): 0.061010
# 	 partial train loss (single batch): 0.061988
# 	 partial train loss (single batch): 0.061531
# 	 partial train loss (single batch): 0.060105
# 	 partial train loss (single batch): 0.062188
# 	 partial train loss (single batch): 0.061990
# 	 partial train loss (single batch): 0.061780
# 	 partial train loss (single batch): 0.062071
# 	 partial train loss (single batch): 0.061360
# 	 partial train loss (single batch): 0.062493
# 	 partial train loss (single batch): 0.060882
# 	 partial train loss (single batch): 0.060942
# 	 partial train loss (single batch): 0.060922
# 	 partial train loss (single batch): 0.061093
# 	 partial train loss (single batch): 0.061021
# 	 partial train loss (single batch): 0.059787
# 	 partial train loss (single batch): 0.060644
# 	 partial train loss (single batch): 0.060116
# 	 partial train loss (single batch): 0.061436
# 	 partial train loss (single batch): 0.060807
# 	 partial train loss (single batch): 0.059434
# 	 partial train loss (single batch): 0.060609
# 	 partial train loss (single batch): 0.061161
# 	 partial train loss (single batch): 0.059751
# 	 partial train loss (single batch): 0.060925
# 	 partial train loss (single batch): 0.061227
# 	 partial train loss (single batch): 0.060321
# 	 partial train loss (single batch): 0.060330
# 	 partial train loss (single batch): 0.060592
# 	 partial train loss (single batch): 0.060947
# 	 partial train loss (single batch): 0.060346
# 	 partial train loss (single batch): 0.060994
# 	 partial train loss (single batch): 0.060887
# 	 partial train loss (single batch): 0.059359
# 	 partial train loss (single batch): 0.061105
# 	 partial train loss (single batch): 0.060270
# 	 partial train loss (single batch): 0.060315
# 	 partial train loss (single batch): 0.060150
# 	 partial train loss (single batch): 0.060837
# 	 partial train loss (single batch): 0.060863
# 	 partial train loss (single batch): 0.059664
# 	 partial train loss (single batch): 0.059614
# 	 partial train loss (single batch): 0.059739
# 	 partial train loss (single batch): 0.060069
# 	 partial train loss (single batch): 0.060830
# 	 partial train loss (single batch): 0.059334
# 	 partial train loss (single batch): 0.059989
# 	 partial train loss (single batch): 0.059230
# 	 partial train loss (single batch): 0.059561
# 	 partial train loss (single batch): 0.059570
# 	 partial train loss (single batch): 0.059974
# 	 partial train loss (single batch): 0.059894
# 	 partial train loss (single batch): 0.059313
# 	 partial train loss (single batch): 0.059717
# 	 partial train loss (single batch): 0.060286
# 	 partial train loss (single batch): 0.059874
# 	 partial train loss (single batch): 0.059242
# 	 partial train loss (single batch): 0.060005
# 	 partial train loss (single batch): 0.059734
# 	 partial train loss (single batch): 0.060407
# 	 partial train loss (single batch): 0.059647
# 	 partial train loss (single batch): 0.058631
# 	 partial train loss (single batch): 0.058871
#
#  EPOCH 2/30 	 train loss 0.063 	 val loss 0.056
# EPOCH 3/30
# 	 partial train loss (single batch): 0.060514
# 	 partial train loss (single batch): 0.059062
# 	 partial train loss (single batch): 0.059320
# 	 partial train loss (single batch): 0.059802
# 	 partial train loss (single batch): 0.060701
# 	 partial train loss (single batch): 0.060053
# 	 partial train loss (single batch): 0.059173
# 	 partial train loss (single batch): 0.059700
# 	 partial train loss (single batch): 0.059580
# 	 partial train loss (single batch): 0.059186
# 	 partial train loss (single batch): 0.060156
# 	 partial train loss (single batch): 0.059690
# 	 partial train loss (single batch): 0.059829
# 	 partial train loss (single batch): 0.057953
# 	 partial train loss (single batch): 0.058245
# 	 partial train loss (single batch): 0.058615
# 	 partial train loss (single batch): 0.059427
# 	 partial train loss (single batch): 0.058818
# 	 partial train loss (single batch): 0.058823
# 	 partial train loss (single batch): 0.059522
# 	 partial train loss (single batch): 0.058070
# 	 partial train loss (single batch): 0.058127
# 	 partial train loss (single batch): 0.058960
# 	 partial train loss (single batch): 0.058340
# 	 partial train loss (single batch): 0.058477
# 	 partial train loss (single batch): 0.058725
# 	 partial train loss (single batch): 0.058825
# 	 partial train loss (single batch): 0.058539
# 	 partial train loss (single batch): 0.058759
# 	 partial train loss (single batch): 0.059417
# 	 partial train loss (single batch): 0.057748
# 	 partial train loss (single batch): 0.058368
# 	 partial train loss (single batch): 0.058923
# 	 partial train loss (single batch): 0.058490
# 	 partial train loss (single batch): 0.059571
# 	 partial train loss (single batch): 0.058734
# 	 partial train loss (single batch): 0.058546
# 	 partial train loss (single batch): 0.058080
# 	 partial train loss (single batch): 0.058999
# 	 partial train loss (single batch): 0.059698
# 	 partial train loss (single batch): 0.058904
# 	 partial train loss (single batch): 0.059019
# 	 partial train loss (single batch): 0.058347
# 	 partial train loss (single batch): 0.058059
# 	 partial train loss (single batch): 0.059340
# 	 partial train loss (single batch): 0.059383
# 	 partial train loss (single batch): 0.059205
# 	 partial train loss (single batch): 0.058529
# 	 partial train loss (single batch): 0.058024
# 	 partial train loss (single batch): 0.059406
# 	 partial train loss (single batch): 0.058638
# 	 partial train loss (single batch): 0.057641
# 	 partial train loss (single batch): 0.058624
# 	 partial train loss (single batch): 0.058799
# 	 partial train loss (single batch): 0.058098
# 	 partial train loss (single batch): 0.057691
# 	 partial train loss (single batch): 0.058286
# 	 partial train loss (single batch): 0.058565
# 	 partial train loss (single batch): 0.057654
# 	 partial train loss (single batch): 0.057123
# 	 partial train loss (single batch): 0.057628
# 	 partial train loss (single batch): 0.058929
# 	 partial train loss (single batch): 0.058097
# 	 partial train loss (single batch): 0.058376
# 	 partial train loss (single batch): 0.057744
# 	 partial train loss (single batch): 0.056619
# 	 partial train loss (single batch): 0.058598
# 	 partial train loss (single batch): 0.058056
# 	 partial train loss (single batch): 0.057937
# 	 partial train loss (single batch): 0.057531
# 	 partial train loss (single batch): 0.057110
# 	 partial train loss (single batch): 0.056925
# 	 partial train loss (single batch): 0.057440
# 	 partial train loss (single batch): 0.057415
# 	 partial train loss (single batch): 0.057652
# 	 partial train loss (single batch): 0.058072
# 	 partial train loss (single batch): 0.056633
# 	 partial train loss (single batch): 0.057721
# 	 partial train loss (single batch): 0.057861
# 	 partial train loss (single batch): 0.057079
# 	 partial train loss (single batch): 0.056334
# 	 partial train loss (single batch): 0.057560
# 	 partial train loss (single batch): 0.057909
# 	 partial train loss (single batch): 0.056904
# 	 partial train loss (single batch): 0.057890
# 	 partial train loss (single batch): 0.059028
# 	 partial train loss (single batch): 0.057404
# 	 partial train loss (single batch): 0.056993
# 	 partial train loss (single batch): 0.057611
# 	 partial train loss (single batch): 0.057910
# 	 partial train loss (single batch): 0.056867
# 	 partial train loss (single batch): 0.057971
# 	 partial train loss (single batch): 0.056137
# 	 partial train loss (single batch): 0.057000
# 	 partial train loss (single batch): 0.056815
# 	 partial train loss (single batch): 0.057594
# 	 partial train loss (single batch): 0.057466
# 	 partial train loss (single batch): 0.056988
# 	 partial train loss (single batch): 0.056868
# 	 partial train loss (single batch): 0.057469
# 	 partial train loss (single batch): 0.056553
# 	 partial train loss (single batch): 0.056663
# 	 partial train loss (single batch): 0.057676
# 	 partial train loss (single batch): 0.055848
# 	 partial train loss (single batch): 0.055979
# 	 partial train loss (single batch): 0.055823
# 	 partial train loss (single batch): 0.056343
# 	 partial train loss (single batch): 0.057481
# 	 partial train loss (single batch): 0.057594
# 	 partial train loss (single batch): 0.057232
# 	 partial train loss (single batch): 0.056720
# 	 partial train loss (single batch): 0.056529
# 	 partial train loss (single batch): 0.056422
# 	 partial train loss (single batch): 0.057564
# 	 partial train loss (single batch): 0.056946
# 	 partial train loss (single batch): 0.057328
# 	 partial train loss (single batch): 0.056559
# 	 partial train loss (single batch): 0.057911
# 	 partial train loss (single batch): 0.056270
# 	 partial train loss (single batch): 0.055983
# 	 partial train loss (single batch): 0.056448
# 	 partial train loss (single batch): 0.056889
# 	 partial train loss (single batch): 0.057062
# 	 partial train loss (single batch): 0.055164
# 	 partial train loss (single batch): 0.056407
# 	 partial train loss (single batch): 0.056121
# 	 partial train loss (single batch): 0.056194
# 	 partial train loss (single batch): 0.055732
# 	 partial train loss (single batch): 0.055196
# 	 partial train loss (single batch): 0.057183
# 	 partial train loss (single batch): 0.056806
# 	 partial train loss (single batch): 0.055817
# 	 partial train loss (single batch): 0.056632
# 	 partial train loss (single batch): 0.056475
# 	 partial train loss (single batch): 0.056815
# 	 partial train loss (single batch): 0.055575
# 	 partial train loss (single batch): 0.055865
# 	 partial train loss (single batch): 0.056230
# 	 partial train loss (single batch): 0.055581
# 	 partial train loss (single batch): 0.055781
# 	 partial train loss (single batch): 0.056084
# 	 partial train loss (single batch): 0.055748
# 	 partial train loss (single batch): 0.057073
# 	 partial train loss (single batch): 0.056507
# 	 partial train loss (single batch): 0.055408
# 	 partial train loss (single batch): 0.055438
# 	 partial train loss (single batch): 0.056295
# 	 partial train loss (single batch): 0.055802
# 	 partial train loss (single batch): 0.054740
# 	 partial train loss (single batch): 0.056793
# 	 partial train loss (single batch): 0.056155
# 	 partial train loss (single batch): 0.055818
# 	 partial train loss (single batch): 0.055793
# 	 partial train loss (single batch): 0.056245
# 	 partial train loss (single batch): 0.055810
# 	 partial train loss (single batch): 0.055684
# 	 partial train loss (single batch): 0.055467
# 	 partial train loss (single batch): 0.057101
# 	 partial train loss (single batch): 0.056060
# 	 partial train loss (single batch): 0.055266
# 	 partial train loss (single batch): 0.056546
# 	 partial train loss (single batch): 0.055906
# 	 partial train loss (single batch): 0.055135
# 	 partial train loss (single batch): 0.055156
# 	 partial train loss (single batch): 0.056491
# 	 partial train loss (single batch): 0.055026
# 	 partial train loss (single batch): 0.056401
# 	 partial train loss (single batch): 0.055859
# 	 partial train loss (single batch): 0.056098
# 	 partial train loss (single batch): 0.054796
# 	 partial train loss (single batch): 0.055080
# 	 partial train loss (single batch): 0.055235
# 	 partial train loss (single batch): 0.055459
# 	 partial train loss (single batch): 0.054932
# 	 partial train loss (single batch): 0.055214
# 	 partial train loss (single batch): 0.055257
# 	 partial train loss (single batch): 0.056718
# 	 partial train loss (single batch): 0.055079
# 	 partial train loss (single batch): 0.055290
# 	 partial train loss (single batch): 0.054972
# 	 partial train loss (single batch): 0.055226
# 	 partial train loss (single batch): 0.055193
# 	 partial train loss (single batch): 0.055863
# 	 partial train loss (single batch): 0.054124
# 	 partial train loss (single batch): 0.055388
# 	 partial train loss (single batch): 0.055456
# 	 partial train loss (single batch): 0.055277
# 	 partial train loss (single batch): 0.055095
#
#  EPOCH 3/30 	 train loss 0.057 	 val loss 0.048
# EPOCH 4/30
# 	 partial train loss (single batch): 0.055138
# 	 partial train loss (single batch): 0.055341
# 	 partial train loss (single batch): 0.055499
# 	 partial train loss (single batch): 0.054201
# 	 partial train loss (single batch): 0.055211
# 	 partial train loss (single batch): 0.055657
# 	 partial train loss (single batch): 0.055304
# 	 partial train loss (single batch): 0.053986
# 	 partial train loss (single batch): 0.054938
# 	 partial train loss (single batch): 0.055059
# 	 partial train loss (single batch): 0.055849
# 	 partial train loss (single batch): 0.054757
# 	 partial train loss (single batch): 0.055346
# 	 partial train loss (single batch): 0.054630
# 	 partial train loss (single batch): 0.054621
# 	 partial train loss (single batch): 0.054439
# 	 partial train loss (single batch): 0.055595
# 	 partial train loss (single batch): 0.055136
# 	 partial train loss (single batch): 0.055727
# 	 partial train loss (single batch): 0.055793
# 	 partial train loss (single batch): 0.053567
# 	 partial train loss (single batch): 0.054760
# 	 partial train loss (single batch): 0.054756
# 	 partial train loss (single batch): 0.054790
# 	 partial train loss (single batch): 0.054611
# 	 partial train loss (single batch): 0.054847
# 	 partial train loss (single batch): 0.054101
# 	 partial train loss (single batch): 0.057074
# 	 partial train loss (single batch): 0.054612
# 	 partial train loss (single batch): 0.055311
# 	 partial train loss (single batch): 0.054139
# 	 partial train loss (single batch): 0.054531
# 	 partial train loss (single batch): 0.055044
# 	 partial train loss (single batch): 0.054046
# 	 partial train loss (single batch): 0.055508
# 	 partial train loss (single batch): 0.055751
# 	 partial train loss (single batch): 0.054286
# 	 partial train loss (single batch): 0.054810
# 	 partial train loss (single batch): 0.053813
# 	 partial train loss (single batch): 0.055252
# 	 partial train loss (single batch): 0.055473
# 	 partial train loss (single batch): 0.055070
# 	 partial train loss (single batch): 0.055612
# 	 partial train loss (single batch): 0.053882
# 	 partial train loss (single batch): 0.054905
# 	 partial train loss (single batch): 0.055071
# 	 partial train loss (single batch): 0.053267
# 	 partial train loss (single batch): 0.054919
# 	 partial train loss (single batch): 0.054462
# 	 partial train loss (single batch): 0.054669
# 	 partial train loss (single batch): 0.055173
# 	 partial train loss (single batch): 0.055454
# 	 partial train loss (single batch): 0.055024
# 	 partial train loss (single batch): 0.054656
# 	 partial train loss (single batch): 0.054936
# 	 partial train loss (single batch): 0.053703
# 	 partial train loss (single batch): 0.054966
# 	 partial train loss (single batch): 0.053395
# 	 partial train loss (single batch): 0.053710
# 	 partial train loss (single batch): 0.054642
# 	 partial train loss (single batch): 0.054036
# 	 partial train loss (single batch): 0.054773
# 	 partial train loss (single batch): 0.053711
# 	 partial train loss (single batch): 0.054574
# 	 partial train loss (single batch): 0.054380
# 	 partial train loss (single batch): 0.053433
# 	 partial train loss (single batch): 0.055110
# 	 partial train loss (single batch): 0.053611
# 	 partial train loss (single batch): 0.054773
# 	 partial train loss (single batch): 0.054206
# 	 partial train loss (single batch): 0.054310
# 	 partial train loss (single batch): 0.053751
# 	 partial train loss (single batch): 0.053516
# 	 partial train loss (single batch): 0.054354
# 	 partial train loss (single batch): 0.053822
# 	 partial train loss (single batch): 0.054863
# 	 partial train loss (single batch): 0.054641
# 	 partial train loss (single batch): 0.054426
# 	 partial train loss (single batch): 0.054087
# 	 partial train loss (single batch): 0.053451
# 	 partial train loss (single batch): 0.053765
# 	 partial train loss (single batch): 0.053739
# 	 partial train loss (single batch): 0.054142
# 	 partial train loss (single batch): 0.053965
# 	 partial train loss (single batch): 0.053498
# 	 partial train loss (single batch): 0.053924
# 	 partial train loss (single batch): 0.055589
# 	 partial train loss (single batch): 0.053869
# 	 partial train loss (single batch): 0.054799
# 	 partial train loss (single batch): 0.054011
# 	 partial train loss (single batch): 0.054243
# 	 partial train loss (single batch): 0.053580
# 	 partial train loss (single batch): 0.055078
# 	 partial train loss (single batch): 0.055658
# 	 partial train loss (single batch): 0.054669
# 	 partial train loss (single batch): 0.054035
# 	 partial train loss (single batch): 0.054085
# 	 partial train loss (single batch): 0.055660
# 	 partial train loss (single batch): 0.054868
# 	 partial train loss (single batch): 0.054967
# 	 partial train loss (single batch): 0.053566
# 	 partial train loss (single batch): 0.053993
# 	 partial train loss (single batch): 0.053434
# 	 partial train loss (single batch): 0.054308
# 	 partial train loss (single batch): 0.053518
# 	 partial train loss (single batch): 0.054770
# 	 partial train loss (single batch): 0.053433
# 	 partial train loss (single batch): 0.053277
# 	 partial train loss (single batch): 0.053898
# 	 partial train loss (single batch): 0.054265
# 	 partial train loss (single batch): 0.053902
# 	 partial train loss (single batch): 0.054134
# 	 partial train loss (single batch): 0.054074
# 	 partial train loss (single batch): 0.052850
# 	 partial train loss (single batch): 0.054725
# 	 partial train loss (single batch): 0.054009
# 	 partial train loss (single batch): 0.054061
# 	 partial train loss (single batch): 0.054101
# 	 partial train loss (single batch): 0.053885
# 	 partial train loss (single batch): 0.053888
# 	 partial train loss (single batch): 0.053616
# 	 partial train loss (single batch): 0.053788
# 	 partial train loss (single batch): 0.054842
# 	 partial train loss (single batch): 0.054541
# 	 partial train loss (single batch): 0.053497
# 	 partial train loss (single batch): 0.053154
# 	 partial train loss (single batch): 0.054367
# 	 partial train loss (single batch): 0.054251
# 	 partial train loss (single batch): 0.054216
# 	 partial train loss (single batch): 0.052193
# 	 partial train loss (single batch): 0.054495
# 	 partial train loss (single batch): 0.053147
# 	 partial train loss (single batch): 0.053828
# 	 partial train loss (single batch): 0.053847
# 	 partial train loss (single batch): 0.052910
# 	 partial train loss (single batch): 0.053901
# 	 partial train loss (single batch): 0.052518
# 	 partial train loss (single batch): 0.054847
# 	 partial train loss (single batch): 0.055669
# 	 partial train loss (single batch): 0.054088
# 	 partial train loss (single batch): 0.053068
# 	 partial train loss (single batch): 0.053586
# 	 partial train loss (single batch): 0.053215
# 	 partial train loss (single batch): 0.053884
# 	 partial train loss (single batch): 0.052854
# 	 partial train loss (single batch): 0.054798
# 	 partial train loss (single batch): 0.053798
# 	 partial train loss (single batch): 0.052642
# 	 partial train loss (single batch): 0.053780
# 	 partial train loss (single batch): 0.054223
# 	 partial train loss (single batch): 0.055039
# 	 partial train loss (single batch): 0.053618
# 	 partial train loss (single batch): 0.054233
# 	 partial train loss (single batch): 0.053487
# 	 partial train loss (single batch): 0.052971
# 	 partial train loss (single batch): 0.053615
# 	 partial train loss (single batch): 0.054188
# 	 partial train loss (single batch): 0.053422
# 	 partial train loss (single batch): 0.053707
# 	 partial train loss (single batch): 0.053984
# 	 partial train loss (single batch): 0.054114
# 	 partial train loss (single batch): 0.053525
# 	 partial train loss (single batch): 0.054388
# 	 partial train loss (single batch): 0.052695
# 	 partial train loss (single batch): 0.052617
# 	 partial train loss (single batch): 0.053773
# 	 partial train loss (single batch): 0.054684
# 	 partial train loss (single batch): 0.053711
# 	 partial train loss (single batch): 0.053748
# 	 partial train loss (single batch): 0.054678
# 	 partial train loss (single batch): 0.053340
# 	 partial train loss (single batch): 0.054183
# 	 partial train loss (single batch): 0.053173
# 	 partial train loss (single batch): 0.054251
# 	 partial train loss (single batch): 0.053287
# 	 partial train loss (single batch): 0.054177
# 	 partial train loss (single batch): 0.053862
# 	 partial train loss (single batch): 0.054559
# 	 partial train loss (single batch): 0.053446
# 	 partial train loss (single batch): 0.053555
# 	 partial train loss (single batch): 0.053011
# 	 partial train loss (single batch): 0.053195
# 	 partial train loss (single batch): 0.053038
# 	 partial train loss (single batch): 0.053549
# 	 partial train loss (single batch): 0.053493
# 	 partial train loss (single batch): 0.052444
# 	 partial train loss (single batch): 0.053190
# 	 partial train loss (single batch): 0.051832
#
#  EPOCH 4/30 	 train loss 0.054 	 val loss 0.044
# EPOCH 5/30
# 	 partial train loss (single batch): 0.052851
# 	 partial train loss (single batch): 0.053440
# 	 partial train loss (single batch): 0.052695
# 	 partial train loss (single batch): 0.052803
# 	 partial train loss (single batch): 0.054326
# 	 partial train loss (single batch): 0.052848
# 	 partial train loss (single batch): 0.054101
# 	 partial train loss (single batch): 0.052766
# 	 partial train loss (single batch): 0.055008
# 	 partial train loss (single batch): 0.053039
# 	 partial train loss (single batch): 0.053261
# 	 partial train loss (single batch): 0.053085
# 	 partial train loss (single batch): 0.054242
# 	 partial train loss (single batch): 0.054081
# 	 partial train loss (single batch): 0.054068
# 	 partial train loss (single batch): 0.054410
# 	 partial train loss (single batch): 0.053197
# 	 partial train loss (single batch): 0.053111
# 	 partial train loss (single batch): 0.054261
# 	 partial train loss (single batch): 0.052573
# 	 partial train loss (single batch): 0.052646
# 	 partial train loss (single batch): 0.053177
# 	 partial train loss (single batch): 0.053137
# 	 partial train loss (single batch): 0.053488
# 	 partial train loss (single batch): 0.053283
# 	 partial train loss (single batch): 0.053362
# 	 partial train loss (single batch): 0.052874
# 	 partial train loss (single batch): 0.054662
# 	 partial train loss (single batch): 0.052694
# 	 partial train loss (single batch): 0.053434
# 	 partial train loss (single batch): 0.052786
# 	 partial train loss (single batch): 0.053359
# 	 partial train loss (single batch): 0.052294
# 	 partial train loss (single batch): 0.053884
# 	 partial train loss (single batch): 0.053277
# 	 partial train loss (single batch): 0.053955
# 	 partial train loss (single batch): 0.054108
# 	 partial train loss (single batch): 0.053592
# 	 partial train loss (single batch): 0.053510
# 	 partial train loss (single batch): 0.054047
# 	 partial train loss (single batch): 0.053770
# 	 partial train loss (single batch): 0.053739
# 	 partial train loss (single batch): 0.053999
# 	 partial train loss (single batch): 0.053923
# 	 partial train loss (single batch): 0.052761
# 	 partial train loss (single batch): 0.053065
# 	 partial train loss (single batch): 0.052431
# 	 partial train loss (single batch): 0.053610
# 	 partial train loss (single batch): 0.053685
# 	 partial train loss (single batch): 0.053484
# 	 partial train loss (single batch): 0.053052
# 	 partial train loss (single batch): 0.053327
# 	 partial train loss (single batch): 0.053951
# 	 partial train loss (single batch): 0.054459
# 	 partial train loss (single batch): 0.053277
# 	 partial train loss (single batch): 0.053485
# 	 partial train loss (single batch): 0.053367
# 	 partial train loss (single batch): 0.053981
# 	 partial train loss (single batch): 0.053196
# 	 partial train loss (single batch): 0.052794
# 	 partial train loss (single batch): 0.054001
# 	 partial train loss (single batch): 0.052303
# 	 partial train loss (single batch): 0.052968
# 	 partial train loss (single batch): 0.052633
# 	 partial train loss (single batch): 0.052403
# 	 partial train loss (single batch): 0.052642
# 	 partial train loss (single batch): 0.052821
# 	 partial train loss (single batch): 0.052934
# 	 partial train loss (single batch): 0.053374
# 	 partial train loss (single batch): 0.053140
# 	 partial train loss (single batch): 0.052626
# 	 partial train loss (single batch): 0.052961
# 	 partial train loss (single batch): 0.053053
# 	 partial train loss (single batch): 0.054521
# 	 partial train loss (single batch): 0.052015
# 	 partial train loss (single batch): 0.052954
# 	 partial train loss (single batch): 0.053051
# 	 partial train loss (single batch): 0.053275
# 	 partial train loss (single batch): 0.052349
# 	 partial train loss (single batch): 0.052594
# 	 partial train loss (single batch): 0.053540
# 	 partial train loss (single batch): 0.052700
# 	 partial train loss (single batch): 0.052562
# 	 partial train loss (single batch): 0.053363
# 	 partial train loss (single batch): 0.053644
# 	 partial train loss (single batch): 0.053301
# 	 partial train loss (single batch): 0.053601
# 	 partial train loss (single batch): 0.053083
# 	 partial train loss (single batch): 0.053615
# 	 partial train loss (single batch): 0.053067
# 	 partial train loss (single batch): 0.054128
# 	 partial train loss (single batch): 0.051464
# 	 partial train loss (single batch): 0.052566
# 	 partial train loss (single batch): 0.053767
# 	 partial train loss (single batch): 0.052043
# 	 partial train loss (single batch): 0.053204
# 	 partial train loss (single batch): 0.053139
# 	 partial train loss (single batch): 0.053331
# 	 partial train loss (single batch): 0.053498
# 	 partial train loss (single batch): 0.053419
# 	 partial train loss (single batch): 0.053133
# 	 partial train loss (single batch): 0.052212
# 	 partial train loss (single batch): 0.052731
# 	 partial train loss (single batch): 0.052395
# 	 partial train loss (single batch): 0.052628
# 	 partial train loss (single batch): 0.053007
# 	 partial train loss (single batch): 0.054039
# 	 partial train loss (single batch): 0.051727
# 	 partial train loss (single batch): 0.052928
# 	 partial train loss (single batch): 0.052272
# 	 partial train loss (single batch): 0.053148
# 	 partial train loss (single batch): 0.053740
# 	 partial train loss (single batch): 0.053305
# 	 partial train loss (single batch): 0.053639
# 	 partial train loss (single batch): 0.052725
# 	 partial train loss (single batch): 0.053492
# 	 partial train loss (single batch): 0.053235
# 	 partial train loss (single batch): 0.053329
# 	 partial train loss (single batch): 0.053643
# 	 partial train loss (single batch): 0.051955
# 	 partial train loss (single batch): 0.054176
# 	 partial train loss (single batch): 0.053072
# 	 partial train loss (single batch): 0.053466
# 	 partial train loss (single batch): 0.052684
# 	 partial train loss (single batch): 0.053518
# 	 partial train loss (single batch): 0.052497
# 	 partial train loss (single batch): 0.052406
# 	 partial train loss (single batch): 0.052309
# 	 partial train loss (single batch): 0.052222
# 	 partial train loss (single batch): 0.053371
# 	 partial train loss (single batch): 0.053473
# 	 partial train loss (single batch): 0.052305
# 	 partial train loss (single batch): 0.052264
# 	 partial train loss (single batch): 0.051639
# 	 partial train loss (single batch): 0.053334
# 	 partial train loss (single batch): 0.052565
# 	 partial train loss (single batch): 0.053745
# 	 partial train loss (single batch): 0.051835
# 	 partial train loss (single batch): 0.052740
# 	 partial train loss (single batch): 0.052748
# 	 partial train loss (single batch): 0.053196
# 	 partial train loss (single batch): 0.052513
# 	 partial train loss (single batch): 0.052426
# 	 partial train loss (single batch): 0.054044
# 	 partial train loss (single batch): 0.053145
# 	 partial train loss (single batch): 0.053222
# 	 partial train loss (single batch): 0.052463
# 	 partial train loss (single batch): 0.052096
# 	 partial train loss (single batch): 0.052723
# 	 partial train loss (single batch): 0.052921
# 	 partial train loss (single batch): 0.052769
# 	 partial train loss (single batch): 0.054022
# 	 partial train loss (single batch): 0.052074
# 	 partial train loss (single batch): 0.052200
# 	 partial train loss (single batch): 0.052567
# 	 partial train loss (single batch): 0.051221
# 	 partial train loss (single batch): 0.052414
# 	 partial train loss (single batch): 0.052653
# 	 partial train loss (single batch): 0.053340
# 	 partial train loss (single batch): 0.053356
# 	 partial train loss (single batch): 0.052864
# 	 partial train loss (single batch): 0.053030
# 	 partial train loss (single batch): 0.051784
# 	 partial train loss (single batch): 0.052451
# 	 partial train loss (single batch): 0.052512
# 	 partial train loss (single batch): 0.054176
# 	 partial train loss (single batch): 0.052350
# 	 partial train loss (single batch): 0.052475
# 	 partial train loss (single batch): 0.053725
# 	 partial train loss (single batch): 0.051892
# 	 partial train loss (single batch): 0.052583
# 	 partial train loss (single batch): 0.053474
# 	 partial train loss (single batch): 0.052739
# 	 partial train loss (single batch): 0.052321
# 	 partial train loss (single batch): 0.052696
# 	 partial train loss (single batch): 0.052822
# 	 partial train loss (single batch): 0.053311
# 	 partial train loss (single batch): 0.053288
# 	 partial train loss (single batch): 0.052693
# 	 partial train loss (single batch): 0.052595
# 	 partial train loss (single batch): 0.053041
# 	 partial train loss (single batch): 0.052741
# 	 partial train loss (single batch): 0.052799
# 	 partial train loss (single batch): 0.051340
# 	 partial train loss (single batch): 0.053291
# 	 partial train loss (single batch): 0.052598
# 	 partial train loss (single batch): 0.053104
# 	 partial train loss (single batch): 0.053594
#
#  EPOCH 5/30 	 train loss 0.053 	 val loss 0.043
# EPOCH 6/30
# 	 partial train loss (single batch): 0.053459
# 	 partial train loss (single batch): 0.052398
# 	 partial train loss (single batch): 0.052056
# 	 partial train loss (single batch): 0.053037
# 	 partial train loss (single batch): 0.053273
# 	 partial train loss (single batch): 0.052861
# 	 partial train loss (single batch): 0.052254
# 	 partial train loss (single batch): 0.053153
# 	 partial train loss (single batch): 0.052778
# 	 partial train loss (single batch): 0.052079
# 	 partial train loss (single batch): 0.053012
# 	 partial train loss (single batch): 0.053232
# 	 partial train loss (single batch): 0.053717
# 	 partial train loss (single batch): 0.051766
# 	 partial train loss (single batch): 0.053724
# 	 partial train loss (single batch): 0.052156
# 	 partial train loss (single batch): 0.052915
# 	 partial train loss (single batch): 0.053036
# 	 partial train loss (single batch): 0.053011
# 	 partial train loss (single batch): 0.051881
# 	 partial train loss (single batch): 0.053125
# 	 partial train loss (single batch): 0.052065
# 	 partial train loss (single batch): 0.052640
# 	 partial train loss (single batch): 0.052247
# 	 partial train loss (single batch): 0.052882
# 	 partial train loss (single batch): 0.052294
# 	 partial train loss (single batch): 0.052603
# 	 partial train loss (single batch): 0.054084
# 	 partial train loss (single batch): 0.052124
# 	 partial train loss (single batch): 0.053949
# 	 partial train loss (single batch): 0.052906
# 	 partial train loss (single batch): 0.051727
# 	 partial train loss (single batch): 0.052570
# 	 partial train loss (single batch): 0.053108
# 	 partial train loss (single batch): 0.051814
# 	 partial train loss (single batch): 0.053174
# 	 partial train loss (single batch): 0.052860
# 	 partial train loss (single batch): 0.053127
# 	 partial train loss (single batch): 0.051677
# 	 partial train loss (single batch): 0.053072
# 	 partial train loss (single batch): 0.052794
# 	 partial train loss (single batch): 0.051786
# 	 partial train loss (single batch): 0.052520
# 	 partial train loss (single batch): 0.051622
# 	 partial train loss (single batch): 0.053342
# 	 partial train loss (single batch): 0.051717
# 	 partial train loss (single batch): 0.051637
# 	 partial train loss (single batch): 0.053045
# 	 partial train loss (single batch): 0.052480
# 	 partial train loss (single batch): 0.052787
# 	 partial train loss (single batch): 0.052496
# 	 partial train loss (single batch): 0.051776
# 	 partial train loss (single batch): 0.052664
# 	 partial train loss (single batch): 0.051971
# 	 partial train loss (single batch): 0.052187
# 	 partial train loss (single batch): 0.052409
# 	 partial train loss (single batch): 0.052180
# 	 partial train loss (single batch): 0.052470
# 	 partial train loss (single batch): 0.052510
# 	 partial train loss (single batch): 0.053530
# 	 partial train loss (single batch): 0.052528
# 	 partial train loss (single batch): 0.052570
# 	 partial train loss (single batch): 0.052939
# 	 partial train loss (single batch): 0.051275
# 	 partial train loss (single batch): 0.051414
# 	 partial train loss (single batch): 0.051930
# 	 partial train loss (single batch): 0.052842
# 	 partial train loss (single batch): 0.052540
# 	 partial train loss (single batch): 0.052382
# 	 partial train loss (single batch): 0.051909
# 	 partial train loss (single batch): 0.052167
# 	 partial train loss (single batch): 0.052933
# 	 partial train loss (single batch): 0.052149
# 	 partial train loss (single batch): 0.052052
# 	 partial train loss (single batch): 0.052517
# 	 partial train loss (single batch): 0.051904
# 	 partial train loss (single batch): 0.051426
# 	 partial train loss (single batch): 0.052824
# 	 partial train loss (single batch): 0.052146
# 	 partial train loss (single batch): 0.052451
# 	 partial train loss (single batch): 0.052656
# 	 partial train loss (single batch): 0.053109
# 	 partial train loss (single batch): 0.052566
# 	 partial train loss (single batch): 0.051808
# 	 partial train loss (single batch): 0.052232
# 	 partial train loss (single batch): 0.052833
# 	 partial train loss (single batch): 0.053075
# 	 partial train loss (single batch): 0.052456
# 	 partial train loss (single batch): 0.053081
# 	 partial train loss (single batch): 0.052703
# 	 partial train loss (single batch): 0.052711
# 	 partial train loss (single batch): 0.051868
# 	 partial train loss (single batch): 0.053600
# 	 partial train loss (single batch): 0.052545
# 	 partial train loss (single batch): 0.053865
# ...
# 	 partial train loss (single batch): 0.049701
# 	 partial train loss (single batch): 0.049079
# 	 partial train loss (single batch): 0.049901
# 	 partial train loss (single batch): 0.049749
# 	 partial train loss (single batch): 0.051348
# 	 partial train loss (single batch): 0.049278
# 	 partial train loss (single batch): 0.049106
# 	 partial train loss (single batch): 0.049488
# 	 partial train loss (single batch): 0.049900
# 	 partial train loss (single batch): 0.049719
# 	 partial train loss (single batch): 0.048939
# 	 partial train loss (single batch): 0.049615
# 	 partial train loss (single batch): 0.049543
# 	 partial train loss (single batch): 0.049399
# 	 partial train loss (single batch): 0.049597
# 	 partial train loss (single batch): 0.049821
# 	 partial train loss (single batch): 0.049869
# 	 partial train loss (single batch): 0.048755
# 	 partial train loss (single batch): 0.050404
# 	 partial train loss (single batch): 0.049531
# 	 partial train loss (single batch): 0.049593
# 	 partial train loss (single batch): 0.051335
# 	 partial train loss (single batch): 0.049768
# 	 partial train loss (single batch): 0.049775
# 	 partial train loss (single batch): 0.048988
# 	 partial train loss (single batch): 0.048266
# 	 partial train loss (single batch): 0.049100
# 	 partial train loss (single batch): 0.050163
# 	 partial train loss (single batch): 0.048558
# 	 partial train loss (single batch): 0.050116
# 	 partial train loss (single batch): 0.048766
# 	 partial train loss (single batch): 0.049758
# 	 partial train loss (single batch): 0.050528
# 	 partial train loss (single batch): 0.049987
# 	 partial train loss (single batch): 0.049812
# 	 partial train loss (single batch): 0.049714
# 	 partial train loss (single batch): 0.050276
# 	 partial train loss (single batch): 0.049433
# 	 partial train loss (single batch): 0.049781
# 	 partial train loss (single batch): 0.050044
# 	 partial train loss (single batch): 0.049958
# 	 partial train loss (single batch): 0.049614
# 	 partial train loss (single batch): 0.050433
# 	 partial train loss (single batch): 0.050026
# 	 partial train loss (single batch): 0.049703
# 	 partial train loss (single batch): 0.049062
# 	 partial train loss (single batch): 0.049919
# 	 partial train loss (single batch): 0.050749
# 	 partial train loss (single batch): 0.050485
# 	 partial train loss (single batch): 0.049043
# 	 partial train loss (single batch): 0.050168
# 	 partial train loss (single batch): 0.049656
# 	 partial train loss (single batch): 0.048758
# 	 partial train loss (single batch): 0.049813
# 	 partial train loss (single batch): 0.050282
# 	 partial train loss (single batch): 0.050592
# 	 partial train loss (single batch): 0.049078
# 	 partial train loss (single batch): 0.049141
# 	 partial train loss (single batch): 0.049481
# 	 partial train loss (single batch): 0.049024
# 	 partial train loss (single batch): 0.049736
# 	 partial train loss (single batch): 0.050465
# 	 partial train loss (single batch): 0.049889
# 	 partial train loss (single batch): 0.049954
# 	 partial train loss (single batch): 0.048806
# 	 partial train loss (single batch): 0.050252
# 	 partial train loss (single batch): 0.049679
# 	 partial train loss (single batch): 0.050659
# 	 partial train loss (single batch): 0.048248
# 	 partial train loss (single batch): 0.050506
# 	 partial train loss (single batch): 0.050099
# 	 partial train loss (single batch): 0.049441
# 	 partial train loss (single batch): 0.049718
# 	 partial train loss (single batch): 0.049566
# 	 partial train loss (single batch): 0.049755
# 	 partial train loss (single batch): 0.049377
# 	 partial train loss (single batch): 0.049900
# 	 partial train loss (single batch): 0.049212
# 	 partial train loss (single batch): 0.049489
# 	 partial train loss (single batch): 0.049824
# 	 partial train loss (single batch): 0.049749
# 	 partial train loss (single batch): 0.048698
# 	 partial train loss (single batch): 0.049814
# 	 partial train loss (single batch): 0.049454
# 	 partial train loss (single batch): 0.049910
# 	 partial train loss (single batch): 0.049088
# 	 partial train loss (single batch): 0.049178
# 	 partial train loss (single batch): 0.049846
# 	 partial train loss (single batch): 0.049153
# 	 partial train loss (single batch): 0.049221
# 	 partial train loss (single batch): 0.050379
# 	 partial train loss (single batch): 0.049933
# 	 partial train loss (single batch): 0.049575
# 	 partial train loss (single batch): 0.049720
# 	 partial train loss (single batch): 0.049261
# 	 partial train loss (single batch): 0.049423
# 	 partial train loss (single batch): 0.049361
# 	 partial train loss (single batch): 0.049984
# 	 partial train loss (single batch): 0.049615
# 	 partial train loss (single batch): 0.049594
# 	 partial train loss (single batch): 0.049740
# 	 partial train loss (single batch): 0.049014
# 	 partial train loss (single batch): 0.048582
# 	 partial train loss (single batch): 0.050564
# 	 partial train loss (single batch): 0.050169
# 	 partial train loss (single batch): 0.051214
# 	 partial train loss (single batch): 0.051286
# 	 partial train loss (single batch): 0.049674
# 	 partial train loss (single batch): 0.049393
# 	 partial train loss (single batch): 0.048903
# 	 partial train loss (single batch): 0.050116
# 	 partial train loss (single batch): 0.048699
# 	 partial train loss (single batch): 0.048998
# 	 partial train loss (single batch): 0.048191
# 	 partial train loss (single batch): 0.048975
# 	 partial train loss (single batch): 0.049198
# 	 partial train loss (single batch): 0.049369
# 	 partial train loss (single batch): 0.049184
# 	 partial train loss (single batch): 0.049533
# 	 partial train loss (single batch): 0.048779
# 	 partial train loss (single batch): 0.049637
# 	 partial train loss (single batch): 0.050074
# 	 partial train loss (single batch): 0.048252
# 	 partial train loss (single batch): 0.049281
# 	 partial train loss (single batch): 0.049699
# 	 partial train loss (single batch): 0.049820
# 	 partial train loss (single batch): 0.050296
# 	 partial train loss (single batch): 0.050400
# 	 partial train loss (single batch): 0.049811
# 	 partial train loss (single batch): 0.050105
# 	 partial train loss (single batch): 0.050034
# 	 partial train loss (single batch): 0.049253
# 	 partial train loss (single batch): 0.050523
# 	 partial train loss (single batch): 0.050286
# 	 partial train loss (single batch): 0.049330
# 	 partial train loss (single batch): 0.049623
# 	 partial train loss (single batch): 0.049063
# 	 partial train loss (single batch): 0.049607
# 	 partial train loss (single batch): 0.049967
# 	 partial train loss (single batch): 0.049162
# 	 partial train loss (single batch): 0.050219
# 	 partial train loss (single batch): 0.049502
# 	 partial train loss (single batch): 0.048891
# 	 partial train loss (single batch): 0.049225
# 	 partial train loss (single batch): 0.048980
# 	 partial train loss (single batch): 0.049902
# 	 partial train loss (single batch): 0.049414
# 	 partial train loss (single batch): 0.048876
# 	 partial train loss (single batch): 0.051067
# 	 partial train loss (single batch): 0.049789
# 	 partial train loss (single batch): 0.049969
# 	 partial train loss (single batch): 0.049685
# 	 partial train loss (single batch): 0.049667
# 	 partial train loss (single batch): 0.050510
# 	 partial train loss (single batch): 0.049738
# 	 partial train loss (single batch): 0.049565
# 	 partial train loss (single batch): 0.050206
#
#  EPOCH 29/30 	 train loss 0.050 	 val loss 0.039
# EPOCH 30/30
# 	 partial train loss (single batch): 0.049297
# 	 partial train loss (single batch): 0.050754
# 	 partial train loss (single batch): 0.049464
# 	 partial train loss (single batch): 0.050455
# 	 partial train loss (single batch): 0.048918
# 	 partial train loss (single batch): 0.050138
# 	 partial train loss (single batch): 0.049038
# 	 partial train loss (single batch): 0.048976
# 	 partial train loss (single batch): 0.050264
# 	 partial train loss (single batch): 0.048518
# 	 partial train loss (single batch): 0.049689
# 	 partial train loss (single batch): 0.049920
# 	 partial train loss (single batch): 0.049628
# 	 partial train loss (single batch): 0.049245
# 	 partial train loss (single batch): 0.050717
# 	 partial train loss (single batch): 0.050503
# 	 partial train loss (single batch): 0.050430
# 	 partial train loss (single batch): 0.049409
# 	 partial train loss (single batch): 0.050473
# 	 partial train loss (single batch): 0.049519
# 	 partial train loss (single batch): 0.049813
# 	 partial train loss (single batch): 0.049323
# 	 partial train loss (single batch): 0.050043
# 	 partial train loss (single batch): 0.050401
# 	 partial train loss (single batch): 0.049496
# 	 partial train loss (single batch): 0.049030
# 	 partial train loss (single batch): 0.049235
# 	 partial train loss (single batch): 0.049760
# 	 partial train loss (single batch): 0.050057
# 	 partial train loss (single batch): 0.049886
# 	 partial train loss (single batch): 0.049302
# 	 partial train loss (single batch): 0.050681
# 	 partial train loss (single batch): 0.050180
# 	 partial train loss (single batch): 0.049360
# 	 partial train loss (single batch): 0.049098
# 	 partial train loss (single batch): 0.048705
# 	 partial train loss (single batch): 0.050012
# 	 partial train loss (single batch): 0.050036
# 	 partial train loss (single batch): 0.049357
# 	 partial train loss (single batch): 0.049684
# 	 partial train loss (single batch): 0.050266
# 	 partial train loss (single batch): 0.049264
# 	 partial train loss (single batch): 0.049041
# 	 partial train loss (single batch): 0.049168
# 	 partial train loss (single batch): 0.049781
# 	 partial train loss (single batch): 0.049870
# 	 partial train loss (single batch): 0.048795
# 	 partial train loss (single batch): 0.049795
# 	 partial train loss (single batch): 0.048902
# 	 partial train loss (single batch): 0.049918
# 	 partial train loss (single batch): 0.049827
# 	 partial train loss (single batch): 0.049335
# 	 partial train loss (single batch): 0.049312
# 	 partial train loss (single batch): 0.049053
# 	 partial train loss (single batch): 0.049394
# 	 partial train loss (single batch): 0.049889
# 	 partial train loss (single batch): 0.050990
# 	 partial train loss (single batch): 0.049504
# 	 partial train loss (single batch): 0.049569
# 	 partial train loss (single batch): 0.049400
# 	 partial train loss (single batch): 0.050385
# 	 partial train loss (single batch): 0.049854
# 	 partial train loss (single batch): 0.049307
# 	 partial train loss (single batch): 0.049173
# 	 partial train loss (single batch): 0.049557
# 	 partial train loss (single batch): 0.049260
# 	 partial train loss (single batch): 0.049985
# 	 partial train loss (single batch): 0.049822
# 	 partial train loss (single batch): 0.050711
# 	 partial train loss (single batch): 0.050658
# 	 partial train loss (single batch): 0.049075
# 	 partial train loss (single batch): 0.050166
# 	 partial train loss (single batch): 0.051020
# 	 partial train loss (single batch): 0.049718
# 	 partial train loss (single batch): 0.049431
# 	 partial train loss (single batch): 0.049306
# 	 partial train loss (single batch): 0.049221
# 	 partial train loss (single batch): 0.049988
# 	 partial train loss (single batch): 0.049422
# 	 partial train loss (single batch): 0.050523
# 	 partial train loss (single batch): 0.048812
# 	 partial train loss (single batch): 0.049102
# 	 partial train loss (single batch): 0.049734
# 	 partial train loss (single batch): 0.049938
# 	 partial train loss (single batch): 0.050065
# 	 partial train loss (single batch): 0.049354
# 	 partial train loss (single batch): 0.050466
# 	 partial train loss (single batch): 0.049161
# 	 partial train loss (single batch): 0.048145
# 	 partial train loss (single batch): 0.049748
# 	 partial train loss (single batch): 0.049838
# 	 partial train loss (single batch): 0.049619
# 	 partial train loss (single batch): 0.050532
# 	 partial train loss (single batch): 0.050429
# 	 partial train loss (single batch): 0.048410
# 	 partial train loss (single batch): 0.049328
# 	 partial train loss (single batch): 0.049820
# 	 partial train loss (single batch): 0.049227
# 	 partial train loss (single batch): 0.049625
# 	 partial train loss (single batch): 0.049155
# 	 partial train loss (single batch): 0.049586
# 	 partial train loss (single batch): 0.048243
# 	 partial train loss (single batch): 0.049245
# 	 partial train loss (single batch): 0.049517
# 	 partial train loss (single batch): 0.049631
# 	 partial train loss (single batch): 0.049950
# 	 partial train loss (single batch): 0.048746
# 	 partial train loss (single batch): 0.049796
# 	 partial train loss (single batch): 0.049600
# 	 partial train loss (single batch): 0.050086
# 	 partial train loss (single batch): 0.049203
# 	 partial train loss (single batch): 0.049373
# 	 partial train loss (single batch): 0.049891
# 	 partial train loss (single batch): 0.049315
# 	 partial train loss (single batch): 0.049629
# 	 partial train loss (single batch): 0.049816
# 	 partial train loss (single batch): 0.048939
# 	 partial train loss (single batch): 0.048143
# 	 partial train loss (single batch): 0.048437
# 	 partial train loss (single batch): 0.049772
# 	 partial train loss (single batch): 0.049989
# 	 partial train loss (single batch): 0.049031
# 	 partial train loss (single batch): 0.049832
# 	 partial train loss (single batch): 0.048994
# 	 partial train loss (single batch): 0.049752
# 	 partial train loss (single batch): 0.049779
# 	 partial train loss (single batch): 0.050065
# 	 partial train loss (single batch): 0.049966
# 	 partial train loss (single batch): 0.049003
# 	 partial train loss (single batch): 0.048898
# 	 partial train loss (single batch): 0.049157
# 	 partial train loss (single batch): 0.048965
# 	 partial train loss (single batch): 0.049636
# 	 partial train loss (single batch): 0.048964
# 	 partial train loss (single batch): 0.051050
# 	 partial train loss (single batch): 0.049490
# 	 partial train loss (single batch): 0.049614
# 	 partial train loss (single batch): 0.049402
# 	 partial train loss (single batch): 0.050324
# 	 partial train loss (single batch): 0.049940
# 	 partial train loss (single batch): 0.048852
# 	 partial train loss (single batch): 0.049622
# 	 partial train loss (single batch): 0.050052
# 	 partial train loss (single batch): 0.049426
# 	 partial train loss (single batch): 0.049329
# 	 partial train loss (single batch): 0.049824
# 	 partial train loss (single batch): 0.050390
# 	 partial train loss (single batch): 0.048903
# 	 partial train loss (single batch): 0.049661
# 	 partial train loss (single batch): 0.049695
# 	 partial train loss (single batch): 0.049785
# 	 partial train loss (single batch): 0.048193
# 	 partial train loss (single batch): 0.049116
# 	 partial train loss (single batch): 0.048938
# 	 partial train loss (single batch): 0.048662
# 	 partial train loss (single batch): 0.049848
# 	 partial train loss (single batch): 0.049495
# 	 partial train loss (single batch): 0.048885
# 	 partial train loss (single batch): 0.049631
# 	 partial train loss (single batch): 0.048980
# 	 partial train loss (single batch): 0.049350
# 	 partial train loss (single batch): 0.049501
# 	 partial train loss (single batch): 0.048865
# 	 partial train loss (single batch): 0.050364
# 	 partial train loss (single batch): 0.049043
# 	 partial train loss (single batch): 0.048756
# 	 partial train loss (single batch): 0.049569
# 	 partial train loss (single batch): 0.049366
# 	 partial train loss (single batch): 0.048505
# 	 partial train loss (single batch): 0.049457
# 	 partial train loss (single batch): 0.048522
# 	 partial train loss (single batch): 0.048697
# 	 partial train loss (single batch): 0.050053
# 	 partial train loss (single batch): 0.049624
# 	 partial train loss (single batch): 0.049745
# 	 partial train loss (single batch): 0.049107
# 	 partial train loss (single batch): 0.049330
# 	 partial train loss (single batch): 0.050644
# 	 partial train loss (single batch): 0.049401
# 	 partial train loss (single batch): 0.049991
# 	 partial train loss (single batch): 0.049521
# 	 partial train loss (single batch): 0.049270
# 	 partial train loss (single batch): 0.049376
# 	 partial train loss (single batch): 0.050333
# 	 partial train loss (single batch): 0.049922
# 	 partial train loss (single batch): 0.051207
# 	 partial train loss (single batch): 0.049131
# 	 partial train loss (single batch): 0.050332
#
#  EPOCH 30/30 	 train loss 0.050 	 val loss 0.039

# %%
test_epoch_den(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.038527458906173706

# %% [markdown]
# ## Avaliação do modelo

# %% [markdown]
# ### Geração de novas imagens

# %% [markdown]
# Uma forma de avaliar o desempenho do autoencoder é por meio da geração de novas imagens a partir de códigos latentes produzidos de forma aleatória.
#
# Algumas imagens resultantes apresentam dígitos que parecem bem nítidos, como os correspondentes ao 4 e ao 9. Outras imagens não têm sentido, pois o espaço latente permanece irregular.

# %%
def show_image(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

encoder.eval()
decoder.eval()

with torch.no_grad():
    # calculate mean and std of latent code, generated taking in test images as inputs 
    images, labels = iter(test_loader).next()
    images = images.to(device)
    latent = encoder(images)
    latent = latent.cpu()

    mean = latent.mean(dim=0)
    print(mean)
    std = (latent - mean).pow(2).mean(dim=0).sqrt()
    print(std)

    # sample latent vectors from the normal distribution
    latent = torch.randn(128, d)*std + mean

    # reconstruct images from the random latent vectors
    latent = latent.to(device)
    img_recon = decoder(latent)
    img_recon = img_recon.cpu()

    fig, ax = plt.subplots(figsize=(20, 8.5))
    show_image(torchvision.utils.make_grid(img_recon[:100],10,5))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 10
#       6 decoder.eval()
#       8 with torch.no_grad():
#       9     # calculate mean and std of latent code, generated taking in test images as inputs
# ---> 10     images, labels = iter(test_loader).next()
#      11     images = images.to(device)
#      12     latent = encoder(images)
#
# AttributeError: '_SingleProcessDataLoaderIter' object has no attribute 'next'

# %% [markdown]
# ### Visualização do espaço latente
#
# Podemos também obter uma visualização (de um subespaço) do espaço latente aprendido pelo modelo.

# %%
encoded_samples = []
for sample in tqdm(test_dataset):
    img = sample[0].unsqueeze(0).to(device)
    label = sample[1]
    # Encode image
    encoder.eval()
    with torch.no_grad():
        encoded_img  = encoder(img)
    # Append to list
    encoded_img = encoded_img.flatten().cpu().numpy()
    encoded_sample = {f"Enc. Variable {i}": enc for i, enc in enumerate(encoded_img)}
    encoded_sample['label'] = label
    encoded_samples.append(encoded_sample)
# Out:
# 100%|██████████| 10000/10000 [00:12<00:00, 796.61it/s]

# %%
encoded_samples = pd.DataFrame(encoded_samples)
encoded_samples
# Out:
#       Enc. Variable 0  Enc. Variable 1  Enc. Variable 2  Enc. Variable 3  label
# 0           -2.240910         2.034981         0.372571        -1.720647      7
# 1            0.200876         0.526066         1.202599         0.652493      2
# 2            0.196210         2.005375        -0.489884         0.456262      1
# 3           -0.210009        -0.962749        -0.215851         0.036340      0
# 4            0.348812        -0.106136        -1.052809        -0.922085      4
# ...               ...              ...              ...              ...    ...
# 9995        -0.962719         0.624966         1.339632         0.411555      2
# 9996         0.430324         0.028879         1.263772         0.390703      3
# 9997        -0.168513         0.801560        -1.622523        -0.535899      4
# 9998        -0.332767         0.062890        -0.579878         0.690341      5
# 9999         1.563799        -1.145094        -0.453813         0.997899      6
#
# [10000 rows x 5 columns]

# %%
px.scatter(encoded_samples, x='Enc. Variable 0', y='Enc. Variable 1', color=encoded_samples.label.astype(str), opacity=0.7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bb6c4ef2-10ac-481a-88d7-e54ad85eb7ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb6c4ef2-10ac-481a-88d7-e54ad85eb7ce")) {                    Plotly.newPlot(                        "bb6c4ef2-10ac-481a-88d7-e54ad85eb7ce",                        [{"hovertemplate":"color=7<br>Enc. Variable 0=%{x}<br>Enc. Variable 1=%{y}<extra></extra>","legendgroup":"7","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"7","showlegend":true,"x":[-2.240910291671753,-2.476318120956421,-0.8309210538864136,-1.6599541902542114,-1.5668587684631348,-1.2414757013320923,-1.1063672304153442,-1.9775925874710083,-2.7384908199310303,-0.45190274715423584,-1.70441472530365,-0.08073434233665466,-0.34437328577041626,-1.0899769067764282,-0.4305456876754761,-0.569709837436676,-0.7259925007820129,-0.6412935256958008,-0.8093847036361694,-1.2803736925125122,-0.8042629957199097,-1.3568129539489746,-1.6704431772232056,-0.17715485394001007,-0.4492657482624054,-1.8549050092697144,-1.2354124784469604,-0.8718838691711426,-0.21052420139312744,-1.182286024093628,-0.6095815896987915,-0.642078161239624,-0.7144361138343811,-0.3342948257923126,-0.6332175731658936,-0.4504598379135132,-0.46629849076271057,-1.6550967693328857,0.5025046467781067,-0.6021897792816162,-1.4835546016693115,-0.5790767073631287,-0.5866908431053162,-1.228192925453186,-0.6472300887107849,-1.1185438632965088,-1.279482126235962,-1.7080940008163452,-1.596337080001831,-1.9287302494049072,-0.5411214232444763,-0.8627766370773315,-0.03973937779664993,-1.4709397554397583,-0.47677910327911377,-0.9335099458694458,-1.0361226797103882,-1.049655556678772,-1.143322229385376,-1.6548248529434204,-1.8905839920043945,-0.7767093777656555,-0.7174892425537109,-0.8722360134124756,-0.7745705246925354,-0.272998183965683,-1.9267053604125977,-0.729511022567749,0.0019473833963274956,-0.10069368034601212,-1.139374852180481,-0.5380106568336487,-0.6080960035324097,0.11755366623401642,-0.8774682879447937,-0.39461836218833923,-1.2679282426834106,-0.41115057468414307,-1.3566386699676514,-2.1411726474761963,-0.7224820256233215,-0.3383583426475525,-1.075973629951477,-1.532580852508545,-0.7048537135124207,-1.2455670833587646,-1.3385181427001953,-0.34054693579673767,-2.808659076690674,-0.3574445843696594,-0.6618033647537231,-1.061718463897705,-1.0964990854263306,-0.15279026329517365,-1.528029203414917,-0.6049086451530457,-1.2472844123840332,-0.43173468112945557,-0.49742546677589417,-0.3970603942871094,-0.08366823941469193,-2.790720224380493,0.7081677317619324,-0.0459112785756588,-0.7479037642478943,-0.30934423208236694,-0.6331912875175476,-1.1167659759521484,-1.6620925664901733,-2.231633424758911,-1.316556692123413,-1.6180419921875,-1.3672481775283813,-1.5242935419082642,-0.8305481672286987,-0.6991056799888611,-1.0533661842346191,-0.25046026706695557,-0.49534350633621216,-0.5277072787284851,-0.47711384296417236,-0.6059921979904175,-1.0267579555511475,-1.0085930824279785,-1.1873587369918823,-0.7013372182846069,-0.31444692611694336,-2.0022482872009277,-0.6012994647026062,0.3619079887866974,-0.7924503087997437,-1.2070627212524414,-0.7092517018318176,-1.528076171875,-0.11442775279283524,-0.9133844971656799,-0.5229182243347168,-0.804931104183197,-1.5551512241363525,-0.9665506482124329,-0.4448637366294861,-1.214147686958313,-2.223252773284912,-2.094350814819336,-0.555324912071228,-0.5964030027389526,0.06619724631309509,-0.30043765902519226,-2.206738233566284,-1.4102814197540283,0.09307890385389328,-0.7499437928199768,-0.8936027884483337,-2.5939276218414307,0.1726161390542984,-1.1681265830993652,-0.9633055925369263,-0.914068341255188,-0.9883668422698975,-0.8587952256202698,-0.21061481535434723,-1.2987552881240845,-1.06907 ...

# %% [markdown]
# Para fins de comparação, o código a seguir realiza uma redução de dimensionalidade como um método bastante eficiente conhecido como t-SNE.

# %%
tsne = TSNE(n_components=2)
tsne_results = tsne.fit_transform(encoded_samples.drop(['label'],axis=1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.

# %%
fig = px.scatter(tsne_results, x=0, y=1, color=encoded_samples.label.astype(str),labels={'0': 'tsne-2d-one', '1': 'tsne-2d-two'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6fcbdac1-2553-4c59-bf16-25dc7bc0c562" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fcbdac1-2553-4c59-bf16-25dc7bc0c562")) {                    Plotly.newPlot(                        "6fcbdac1-2553-4c59-bf16-25dc7bc0c562",                        [{"hovertemplate":"color=7<br>tsne-2d-one=%{x}<br>tsne-2d-two=%{y}<extra></extra>","legendgroup":"7","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"7","showlegend":true,"x":[-27.828962326049805,-28.302494049072266,-30.85662269592285,-14.563026428222656,-25.970951080322266,-21.289640426635742,-32.085105895996094,-16.115772247314453,-27.71346092224121,-7.593967914581299,-6.14454984664917,-17.153636932373047,-17.90204620361328,-7.874198913574219,-0.06882409006357193,1.4390032291412354,-1.9290767908096313,-26.76123809814453,43.9879150390625,-23.121292114257812,-31.849077224731445,-14.631985664367676,-10.976689338684082,54.17601776123047,-19.28493309020996,-17.67137908935547,-23.063024520874023,-2.3451168537139893,-5.029861927032471,-26.57822608947754,-2.59220552444458,-26.889156341552734,-10.54204273223877,-1.5052709579467773,-1.815515160560608,-0.28149092197418213,-0.09439779818058014,-26.75457191467285,19.341087341308594,-25.066743850708008,-27.768234252929688,-20.854869842529297,0.7049229145050049,-27.286359786987305,-15.773473739624023,-17.951311111450195,5.296449184417725,-30.370691299438477,-21.979633331298828,-15.597643852233887,-23.329456329345703,-11.392526626586914,-1.6028976440429688,-13.73592758178711,-3.5917062759399414,-17.628751754760742,-27.121408462524414,5.970411777496338,-1.7943785190582275,-17.031349182128906,-25.146146774291992,-26.73838996887207,-23.066251754760742,-20.37639045715332,-14.170804023742676,54.04185485839844,-18.754783630371094,-2.2810347080230713,-79.13883209228516,-8.054372787475586,-3.467393159866333,-1.7823376655578613,-10.140950202941895,-5.9546217918396,-20.650449752807617,-8.880444526672363,-24.580524444580078,-14.438337326049805,-2.316113233566284,-27.064260482788086,-22.475177764892578,-7.46614933013916,-30.108869552612305,-24.084848403930664,-6.500493049621582,-29.491161346435547,5.892149448394775,-11.492718696594238,-28.124019622802734,-0.932579517364502,-32.58649444580078,-5.528740406036377,-28.473358154296875,36.755558013916016,-25.783935546875,-6.464971542358398,45.927391052246094,0.7919417023658752,-9.444096565246582,-9.15952205657959,-5.34885835647583,-23.803974151611328,16.494354248046875,33.15305709838867,-15.826436996459961,-2.9074547290802,-20.11982536315918,-25.865785598754883,-24.379375457763672,-28.439348220825195,6.977595329284668,30.917577743530273,-28.069263458251953,-25.962955474853516,-8.071056365966797,-3.3725106716156006,-5.310035705566406,-6.970602035522461,-19.201894760131836,-9.557090759277344,3.175100803375244,-10.216145515441895,-30.64586639404297,3.3326375484466553,30.649587631225586,-16.274574279785156,72.39996337890625,-6.739209175109863,-4.82193660736084,34.63621139526367,-24.764835357666016,6.740657806396484,-9.864364624023438,31.025732040405273,5.0496649742126465,-15.144784927368164,-15.651834487915039,-16.126855850219727,-24.61969566345215,-11.601482391357422,-8.717081069946289,-16.212617874145508,-28.350540161132812,-6.922569751739502,-14.921622276306152,-12.811586380004883,2.3816776275634766,-5.736819744110107,-24.937347412109375,-24.092416763305664,29.46988296508789,-2.1070024967193604,-11.310640335083008,-8.065508842468262,-5.825143814086914,-31.427513122558594,-20.699817657470703,-27.676895141601562,-13.893338203430176,-13.541945457458496,-7.74861478805542,-25.045642852783203,5.506871700286865,-2.5709850788116455,-27.691234588623047,-13.93401050567627,-10.431151390075684,-17.53238868713379, ...
