# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# Define column names for the dataset
column_names = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# Load the Pima Indians Diabetes dataset.
dataset = pd.read_csv('../data/pima-indians-diabetes.csv', names=column_names, header=0)

# %%
dataset.shape
# Out:
# (767, 9)

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.351   31        0
# 1                     0.672   32        1
# 2                     0.167   21        0
# 3                     2.288   33        1
# 4                     0.201   30        0

# %%
from sklearn.neighbors import KNeighborsClassifier

# Split the dataset into features (X) and the target variable (y)
X = dataset.drop('Outcome', axis=1)
y = dataset['Outcome']

# Split the data into a training set and a testing set (e.g., 70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Create and train the logistic regression model
model = LogisticRegression(solver='liblinear', random_state=42)
# model = KNeighborsClassifier()
# model.fit(X_train, y_train)

pipeline = Pipeline(steps=[('t', trans), ('m', model)])

# evaluate the pipeline
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report pipeline performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.770 (0.040)

# %% [markdown]
# You can use `PolynomialFeatures` from scikit-learn to generate polynomial features for your dataset. The code below provides an example. In this code, we first apply `PolynomialFeatures` to generate polynomial features of the desired degree (in this case, 2) and then proceed with the standard scaling and logistic regression as before. The polynomial features allow you to capture non-linear relationships in your data, which can be helpful in certain scenarios. Adjust the `degree` parameter in `PolynomialFeatures` as needed based on your specific dataset and problem requirements.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Split the dataset into features (X) and the target variable (y)
X = dataset.drop('Outcome', axis=1)
y = dataset['Outcome']

# Split the data into a training set and a testing set (e.g., 70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create and fit the PolynomialFeatures transformer to generate polynomial features
poly = PolynomialFeatures(degree=9)  # You can change the degree as needed
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# Scale the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_poly)
X_test_scaled = scaler.transform(X_test_poly)

# Create and train the logistic regression model
# model = LogisticRegression(solver='lbfgs', random_state=42)
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy * 100:.2f}%")
print("Confusion Matrix:\n", confusion)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 70.56%
# Confusion Matrix:
#  [[126  25]
#  [ 43  37]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79       151
#            1       0.60      0.46      0.52        80
#
#     accuracy                           0.71       231
#    macro avg       0.67      0.65      0.65       231
# weighted avg       0.69      0.71      0.70       231

# %%
# evaluate knn on the sonar dataset with polynomial features transform
from numpy import mean
from numpy import std
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from matplotlib import pyplot
# load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv"
dataset = read_csv(url, header=None)
data = dataset.values
# separate into input and output columns
X, y = data[:, :-1], data[:, -1]
# ensure inputs are floats and output is an integer label
X = X.astype('float32')
y = LabelEncoder().fit_transform(y.astype('str'))
# define the pipeline
trans = PolynomialFeatures(degree=3)
model = KNeighborsClassifier()
pipeline = Pipeline(steps=[('t', trans), ('m', model)])
# evaluate the pipeline
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report pipeline performance
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# Accuracy: 0.800 (0.077)

# %%
np.logspace(-4, 1, 6)
# Out:
# array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01])

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# Split the dataset into features (X) and the target variable (y)
X = dataset.drop('Outcome', axis=1)
y = dataset['Outcome']

pipe = Pipeline([
        ('scale', StandardScaler()),
        ('reduce_dims', PCA()),
        ('clf', SVC())])

param_grid = dict(reduce_dims__n_components=[4,6,8],
                  clf__C=np.logspace(-4, 1, 6),
                  clf__kernel=['rbf','linear'])

grid = GridSearchCV(pipe, param_grid=param_grid, cv=3, n_jobs=1, verbose=2, scoring= 'accuracy')
grid.fit(X, y)

# print("Best Hyperparameters: ", best_params)
print("Best Accuracy: ", grid.best_score_)
print("Best params: ", grid.best_params_)

# print(grid.best_score_)
# print(grid.cv_results_)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.0001, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.001, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.01, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=0.1, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=1.0, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=rbf, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=4; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=6; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# [CV] END clf__C=10.0, clf__kernel=linear, reduce_dims__n_components=8; total time=   0.0s
# Best Accuracy:  0.7705780228758169
# Best params:  {'clf__C': 1.0, 'clf__kernel': 'rbf', 'reduce_dims__n_components': 8}

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.12.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /home/ebezerra/anaconda3/envs/cic1205/lib/python3.12/site-packages (from optuna) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/ebezerra/anaconda3/envs/cic1205/lib/python3.12/site-packages (from optuna) (23.2)
# Collecting sqlalchemy>=1.3.0 (from optuna)
#   Downloading SQLAlchemy-2.0.23-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting tqdm (from optuna)
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.2 MB/s eta 0:00:00ta 0:00:01
# Collecting PyYAML (from optuna)
#   Downloading PyYAML-6.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /home/ebezerra/anaconda3/envs/cic1205/lib/python3.12/site-packages (from alembic>=1.5.0->optuna) (4.8.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.3.0->optuna)
#   Downloading greenlet-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting MarkupSafe>=0.9.2 (from Mako->alembic>=1.5.0->optuna)
#   Downloading MarkupSafe-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Downloading optuna-3.4.0-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 34.6 MB/s eta 0:00:00
# Downloading alembic-1.12.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 5.5 MB/s eta 0:00:00:00:01
# Downloading SQLAlchemy-2.0.23-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 33.1 MB/s eta 0:00:0000:0100:01
# Downloading PyYAML-6.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (724 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.0/725.0 kB 24.8 MB/s eta 0:00:00
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 3.1 MB/s eta 0:00:00
# Downloading greenlet-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (620 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.8/620.8 kB 26.2 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Installing collected packages: tqdm, PyYAML, MarkupSafe, greenlet, colorlog, sqlalchemy, Mako, alembic, optuna
# Successfully installed Mako-1.2.4 MarkupSafe-2.1.3 PyYAML-6.0.1 alembic-1.12.1 colorlog-6.7.0 greenlet-3.0.1 optuna-3.4.0 sqlalchemy-2.0.23 tqdm-4.66.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris
from sklearn.metrics import make_scorer

# Split the dataset into features (X) and the target variable (y)
X = dataset.drop('Outcome', axis=1)
y = dataset['Outcome']

def objective(trial):
    # Define the hyperparameters to search for
    reduce_dims_n_components = trial.suggest_int('reduce_dims__n_components', 2, 8)
    clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
    clf_kernel = trial.suggest_categorical('clf__kernel', ['rbf', 'linear'])

    # Create the pipeline with the suggested hyperparameters
    pipe = Pipeline([
        ('scale', StandardScaler()),
        ('reduce_dims', PCA(n_components=reduce_dims_n_components)),
        ('clf', SVC(C=clf_C, kernel=clf_kernel))])

    # Use cross-validation to evaluate the pipeline's performance
    scoring = make_scorer(accuracy_score)  # You can change the scoring method here
    scores = cross_val_score(pipe, X, y, cv=3, scoring=scoring)

    # Return the negative mean accuracy, as Optuna minimizes the objective function
    return -scores.mean()

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=500)

# Print the best hyperparameters and the corresponding accuracy
best_params = study.best_params
best_score = -study.best_value
print("Best Hyperparameters: ", best_params)
print("Best Accuracy: ", best_score)
# Out:
# [I 2023-11-07 11:29:08,454] A new study created in memory with name: no-name-b1e5cea2-186d-4849-9248-40fd2ba4af28
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,509] Trial 0 finished with value: -0.7640369689542483 and parameters: {'reduce_dims__n_components': 6, 'clf__C': 1.8996478873044031, 'clf__kernel': 'linear'}. Best is trial 0 with value: -0.7640369689542483.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,554] Trial 1 finished with value: -0.7157832924836601 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.07699879975341176, 'clf__kernel': 'rbf'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,601] Trial 2 finished with value: -0.766641135620915 and parameters: {'reduce_dims__n_components': 8, 'clf__C': 0.18418048862295408, 'clf__kernel': 'rbf'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,638] Trial 3 finished with value: -0.7666462418300654 and parameters: {'reduce_dims__n_components': 7, 'clf__C': 0.3422813299548372, 'clf__kernel': 'linear'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,690] Trial 4 finished with value: -0.7223345588235294 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 4.312167814309713, 'clf__kernel': 'linear'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,737] Trial 5 finished with value: -0.757531658496732 and parameters: {'reduce_dims__n_components': 8, 'clf__C': 1.454602029527419, 'clf__kernel': 'linear'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,787] Trial 6 finished with value: -0.7562142565359476 and parameters: {'reduce_dims__n_components': 6, 'clf__C': 0.22079698050395036, 'clf__kernel': 'rbf'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,831] Trial 7 finished with value: -0.7288449754901961 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.8594255493855947, 'clf__kernel': 'rbf'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,879] Trial 8 finished with value: -0.7183925653594772 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.14591729406085577, 'clf__kernel': 'rbf'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,924] Trial 9 finished with value: -0.7197048611111111 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.20551653108794618, 'clf__kernel': 'rbf'}. Best is trial 1 with value: -0.7157832924836601.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:08,976] Trial 10 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.004108366352378055, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,029] Trial 11 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.006181606816572824, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,083] Trial 12 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.004355544872094711, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,133] Trial 13 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0006685606951703567, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,189] Trial 14 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.010596867749659619, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,239] Trial 15 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0003286319966822658, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,293] Trial 16 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.0016713877088878133, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,347] Trial 17 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.021383671213529066, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,388] Trial 18 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.00013309629133249218, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,443] Trial 19 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.004559381059578233, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,498] Trial 20 finished with value: -0.6531913807189542 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.04104413476122771, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,553] Trial 21 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.0035754977431234256, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,605] Trial 22 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.01491892287169691, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,658] Trial 23 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.005808609238659079, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,713] Trial 24 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.0014154984725377182, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,768] Trial 25 finished with value: -0.6662122140522876 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.038441074323896124, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,811] Trial 26 finished with value: -0.7053615196078432 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.008015735311893453, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,867] Trial 27 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 6, 'clf__C': 0.0022522436211483434, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,920] Trial 28 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.00946193480835901, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:09,964] Trial 29 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 7, 'clf__C': 0.000758947736063192, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,019] Trial 30 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.020217698770552205, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,069] Trial 31 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0007954302801207733, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,121] Trial 32 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0031230480017069005, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,172] Trial 33 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0009264311914407295, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,225] Trial 34 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.004757439356963055, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,275] Trial 35 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0022942563622552615, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,316] Trial 36 finished with value: -0.7197099673202615 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.007219993422124149, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,395] Trial 37 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0005460547158542209, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,449] Trial 38 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 7, 'clf__C': 0.00034388694532737606, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,494] Trial 39 finished with value: -0.6623059640522876 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0027756185639001797, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,547] Trial 40 finished with value: -0.7118719362745098 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.06700321102036831, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,602] Trial 41 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.01153880781643996, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,655] Trial 42 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.012165336037378339, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,713] Trial 43 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 6, 'clf__C': 0.005225673846329429, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,780] Trial 44 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.0015679881822870964, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,834] Trial 45 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.017151046665164368, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,890] Trial 46 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 8, 'clf__C': 0.007621760936550276, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,944] Trial 47 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.028262427668016614, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:10,990] Trial 48 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.0012642388818408024, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,043] Trial 49 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.00369356607466488, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,097] Trial 50 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.0028430810074684923, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,150] Trial 51 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.00028873213614408216, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,204] Trial 52 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0001500724784053537, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,257] Trial 53 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0016180898916220397, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,310] Trial 54 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0004653806457847228, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,367] Trial 55 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.005204000096794526, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,423] Trial 56 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.011470640718590351, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,476] Trial 57 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0010721114598751167, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,532] Trial 58 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.0019380930005324537, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,573] Trial 59 finished with value: -0.7210171568627451 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.024704639542664292, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,626] Trial 60 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.003683315041450437, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,681] Trial 61 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.0019932948317015723, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,738] Trial 62 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 6, 'clf__C': 0.007054830028759312, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,794] Trial 63 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.0007654225443848749, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,849] Trial 64 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.0012900793711163399, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,902] Trial 65 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.004152344965507427, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:11,960] Trial 66 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.01712086342614103, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,016] Trial 67 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.0025439111776811353, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,070] Trial 68 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.009049355112533526, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,116] Trial 69 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.0011000435598837205, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,169] Trial 70 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.00536475825724817, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,222] Trial 71 finished with value: -0.6818627450980391 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.04261731478046755, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,276] Trial 72 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.009923989212874611, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,331] Trial 73 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.013254033272422769, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,385] Trial 74 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.006555173756340974, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,449] Trial 75 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.019269036897680298, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,503] Trial 76 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0034606329728542307, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,559] Trial 77 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0017730225946135255, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,617] Trial 78 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 6, 'clf__C': 0.0006675768719089271, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,663] Trial 79 finished with value: -0.6557955473856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0024311376641424263, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,722] Trial 80 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.004296664650387124, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,768] Trial 81 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.00010149950748613127, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,811] Trial 82 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.00041063467955482837, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,856] Trial 83 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0002585669524144433, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,899] Trial 84 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.0005762467741335428, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:12,956] Trial 85 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 5, 'clf__C': 0.0009152311692560105, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:13,001] Trial 86 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 2, 'clf__C': 0.00017090038916195693, 'clf__kernel': 'linear'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:13,058] Trial 87 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 7, 'clf__C': 0.009075369188045707, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:13,114] Trial 88 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 4, 'clf__C': 0.014678439484467199, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:13,168] Trial 89 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.005810888300473425, 'clf__kernel': 'rbf'}. Best is trial 10 with value: -0.6518892973856208.
# ...
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,395] Trial 470 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0013192422191851062, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,446] Trial 471 finished with value: -0.7249336192810457 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.042381525367030486, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,496] Trial 472 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0008664733912534549, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,544] Trial 473 finished with value: -0.6505872140522876 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0017117234554949587, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,600] Trial 474 finished with value: -0.7249387254901961 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.05320237740076974, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,651] Trial 475 finished with value: -0.6636080473856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.002921600111706549, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,701] Trial 476 finished with value: -0.6544934640522876 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.002080038001090907, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,750] Trial 477 finished with value: -0.7223243464052288 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.12579591354644215, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,800] Trial 478 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0013474676723978425, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,851] Trial 479 finished with value: -0.6505872140522876 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0016308723914582794, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,904] Trial 480 finished with value: -0.7249336192810457 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.21752208399241565, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:34,953] Trial 481 finished with value: -0.7210171568627451 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.03096488111535575, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,004] Trial 482 finished with value: -0.6857485702614379 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0034335447454919735, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,052] Trial 483 finished with value: -0.6570976307189542 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.002449598495193302, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,107] Trial 484 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.00010056011816725352, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,160] Trial 485 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0010736820331336315, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,215] Trial 486 finished with value: -0.7249387254901961 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 1.0382042683593404, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,275] Trial 487 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.002007209654122135, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,350] Trial 488 finished with value: -0.7223345588235294 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 3.139783613498641, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,405] Trial 489 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0015578645270501942, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,458] Trial 490 finished with value: -0.6597017973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0026673045389960853, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,516] Trial 491 finished with value: -0.7249336192810457 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.21122354061029147, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,565] Trial 492 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0012672916319404698, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,642] Trial 493 finished with value: -0.7223345588235294 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 9.793304148581889, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,694] Trial 494 finished with value: -0.6505872140522876 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0019333650949486757, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,752] Trial 495 finished with value: -0.6883629493464052 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.00360902218748331, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,807] Trial 496 finished with value: -0.7249387254901961 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.964206251778319, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,856] Trial 497 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0008855470754831604, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,906] Trial 498 finished with value: -0.6570976307189542 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.0023049596555690904, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# /tmp/ipykernel_8718/2662201998.py:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   clf_C = trial.suggest_loguniform('clf__C', 1e-4, 1e1)
# [I 2023-11-07 11:29:35,956] Trial 499 finished with value: -0.6518892973856208 and parameters: {'reduce_dims__n_components': 3, 'clf__C': 0.001448534571242541, 'clf__kernel': 'linear'}. Best is trial 318 with value: -0.6505872140522876.
# Best Hyperparameters:  {'reduce_dims__n_components': 3, 'clf__C': 0.0017944133277856945, 'clf__kernel': 'linear'}
# Best Accuracy:  0.6505872140522876
